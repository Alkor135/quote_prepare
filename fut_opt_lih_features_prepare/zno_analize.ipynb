# %%
import sqlite3
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
from pathlib import Path
from torch.utils.data import Dataset, DataLoader

# %%
# === 1. ЗАГРУЗКА ДАННЫХ ===
db_path = Path(r'C:\Users\Alkor\gd\data_quote_db\RTS_futures_options_day.db')

with sqlite3.connect(db_path) as conn:
    df_fut = pd.read_sql_query(
        "SELECT TRADEDATE, OPEN, LOW, HIGH, CLOSE, VOLUME FROM Futures",
        conn
    )

df_fut
# Out:
#        TRADEDATE      OPEN       LOW      HIGH     CLOSE  VOLUME
# 0     2015-01-05   76930.0   72470.0   78980.0   74600.0  372848
# 1     2015-01-06   74470.0   71200.0   74610.0   73480.0  319307
# 2     2015-01-08   73490.0   71000.0   81380.0   79980.0  537469
# 3     2015-01-09   79950.0   74450.0   81050.0   77650.0  592715
# 4     2015-01-12   77210.0   73180.0   77550.0   73900.0  440908
# ...          ...       ...       ...       ...       ...     ...
# 2537  2025-02-12   98600.0   98120.0  101480.0  100700.0  124069
# 2538  2025-02-13  100570.0  100080.0  111010.0  109930.0  247083
# 2539  2025-02-14  109750.0  106470.0  114130.0  108620.0  282242
# 2540  2025-02-17  108960.0  108050.0  115370.0  115170.0  183356
# 2541  2025-02-18  115100.0  112020.0  116500.0  112250.0  246559
#
# [2542 rows x 6 columns]

# %%
# === 2. ФУНКЦИЯ КОДИРОВАНИЯ СВЕЧЕЙ (ЛИХОВИДОВ) ===
def encode_candle(row):
    open_, low, high, close = row['OPEN'], row['LOW'], row['HIGH'], row['CLOSE']

    if close > open_:
        direction = 1  
    elif close < open_:
        direction = 0  
    else:
        direction = 2  

    upper_shadow = high - max(open_, close)
    lower_shadow = min(open_, close) - low
    body = abs(close - open_)

    def classify_shadow(shadow, body):
        if shadow < 0.1 * body:
            return 0  
        elif shadow < 0.5 * body:
            return 1  
        else:
            return 2  

    upper_code = classify_shadow(upper_shadow, body)
    lower_code = classify_shadow(lower_shadow, body)

    return f"{direction}{upper_code}{lower_code}"

df_fut['CANDLE_CODE'] = df_fut.apply(encode_candle, axis=1)

# === 3. ПОДГОТОВКА ДАННЫХ ===
unique_codes = sorted(df_fut['CANDLE_CODE'].unique())
code_to_int = {code: i for i, code in enumerate(unique_codes)}
df_fut['CANDLE_INT'] = df_fut['CANDLE_CODE'].map(code_to_int)

df_fut['direction_candle_code'] = np.nan

df_fut
# Out:
#        TRADEDATE      OPEN       LOW      HIGH     CLOSE  VOLUME CANDLE_CODE  \
# 0     2015-01-05   76930.0   72470.0   78980.0   74600.0  372848         022
# 1     2015-01-06   74470.0   71200.0   74610.0   73480.0  319307         012
# 2     2015-01-08   73490.0   71000.0   81380.0   79980.0  537469         111
# 3     2015-01-09   79950.0   74450.0   81050.0   77650.0  592715         012
# 4     2015-01-12   77210.0   73180.0   77550.0   73900.0  440908         011
# ...          ...       ...       ...       ...       ...     ...         ...
# 2537  2025-02-12   98600.0   98120.0  101480.0  100700.0  124069         111
# 2538  2025-02-13  100570.0  100080.0  111010.0  109930.0  247083         110
# 2539  2025-02-14  109750.0  106470.0  114130.0  108620.0  282242         022
# 2540  2025-02-17  108960.0  108050.0  115370.0  115170.0  183356         101
# 2541  2025-02-18  115100.0  112020.0  116500.0  112250.0  246559         010
#
#       CANDLE_INT  direction_candle_code
# 0              8                    NaN
# 1              5                    NaN
# 2             13                    NaN
# 3              5                    NaN
# 4              4                    NaN
# ...          ...                    ...
# 2537          13                    NaN
# 2538          12                    NaN
# 2539           8                    NaN
# 2540          10                    NaN
# 2541           3                    NaN
#
# [2542 rows x 9 columns]

# %%
# Сохранение в список
trade_dates = df_fut['TRADEDATE'].tolist()

print(trade_dates)
# Out:
# ['2015-01-05', '2015-01-06', '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13', '2015-01-14', '2015-01-15', '2015-01-16', '2015-01-19', '2015-01-20', '2015-01-21', '2015-01-22', '2015-01-23', '2015-01-26', '2015-01-27', '2015-01-28', '2015-01-29', '2015-01-30', '2015-02-02', '2015-02-03', '2015-02-04', '2015-02-05', '2015-02-06', '2015-02-09', '2015-02-10', '2015-02-11', '2015-02-12', '2015-02-13', '2015-02-16', '2015-02-17', '2015-02-18', '2015-02-19', '2015-02-20', '2015-02-24', '2015-02-25', '2015-02-26', '2015-02-27', '2015-03-02', '2015-03-03', '2015-03-04', '2015-03-05', '2015-03-06', '2015-03-10', '2015-03-11', '2015-03-12', '2015-03-13', '2015-03-16', '2015-03-17', '2015-03-18', '2015-03-19', '2015-03-20', '2015-03-23', '2015-03-24', '2015-03-25', '2015-03-26', '2015-03-27', '2015-03-30', '2015-03-31', '2015-04-01', '2015-04-02', '2015-04-03', '2015-04-06', '2015-04-07', '2015-04-08', '2015-04-09', '2015-04-10', '2015-04-13', '2015-04-14', '2015-04-15', '2015-04-16', '2015-04-17', '2015-04-20', '2015-04-21', '2015-04-22', '2015-04-23', '2015-04-24', '2015-04-27', '2015-04-28', '2015-04-29', '2015-04-30', '2015-05-05', '2015-05-06', '2015-05-07', '2015-05-08', '2015-05-12', '2015-05-13', '2015-05-14', '2015-05-15', '2015-05-18', '2015-05-19', '2015-05-20', '2015-05-21', '2015-05-22', '2015-05-25', '2015-05-26', '2015-05-27', '2015-05-28', '2015-05-29', '2015-06-01', '2015-06-02', '2015-06-03', '2015-06-04', '2015-06-05', '2015-06-08', '2015-06-09', '2015-06-10', '2015-06-11', '2015-06-15', '2015-06-16', '2015-06-17', '2015-06-18', '2015-06-19', '2015-06-22', '2015-06-23', '2015-06-24', '2015-06-25', '2015-06-26', '2015-06-29', '2015-06-30', '2015-07-01', '2015-07-02', '2015-07-03', '2015-07-06', '2015-07-07', '2015-07-08', '2015-07-09', '2015-07-10', '2015-07-13', '2015-07-14', '2015-07-15', '2015-07-16', '2015-07-17', '2015-07-20', '2015-07-21', '2015-07-22', '2015-07-23', '2015-07-24', '2015-07-27', '2015-07-28', '2015-07-29', '2015-07-30', '2015-07-31', '2015-08-03', '2015-08-04', '2015-08-05', '2015-08-06', '2015-08-07', '2015-08-10', '2015-08-11', '2015-08-12', '2015-08-13', '2015-08-14', '2015-08-17', '2015-08-18', '2015-08-19', '2015-08-20', '2015-08-21', '2015-08-24', '2015-08-25', '2015-08-26', '2015-08-27', '2015-08-28', '2015-08-31', '2015-09-01', '2015-09-02', '2015-09-03', '2015-09-04', '2015-09-07', '2015-09-08', '2015-09-09', '2015-09-10', '2015-09-11', '2015-09-14', '2015-09-15', '2015-09-16', '2015-09-17', '2015-09-18', '2015-09-21', '2015-09-22', '2015-09-23', '2015-09-24', '2015-09-25', '2015-09-28', '2015-09-29', '2015-09-30', '2015-10-01', '2015-10-02', '2015-10-05', '2015-10-06', '2015-10-07', '2015-10-08', '2015-10-09', '2015-10-12', '2015-10-13', '2015-10-14', '2015-10-15', '2015-10-16', '2015-10-19', '2015-10-20', '2015-10-21', '2015-10-22', '2015-10-23', '2015-10-26', '2015-10-27', '2015-10-28', '2015-10-29', '2015-10-30', '2015-11-02', '2015-11-03', '2015-11-05', '2015-11-06', '2015-11-09', '2015-11-10', '2015-11-11', '2015-11-12', '2015-11-13', '2015-11-16', '2015-11-17', '2015-11-18', '2015-11-19', '2015-11-20', '2015-11-23', '2015-11-24', '2015-11-25', '2015-11-26', '2015-11-27', '2015-11-30', '2015-12-01', '2015-12-02', '2015-12-03', '2015-12-04', '2015-12-07', '2015-12-08', '2015-12-09', '2015-12-10', '2015-12-11', '2015-12-14', '2015-12-15', '2015-12-16', '2015-12-17', '2015-12-18', '2015-12-21', '2015-12-22', '2015-12-23', '2015-12-24', '2015-12-25', '2015-12-28', '2015-12-29', '2015-12-30', '2016-01-04', '2016-01-05', '2016-01-06', '2016-01-11', '2016-01-12', '2016-01-13', '2016-01-14', '2016-01-15', '2016-01-18', '2016-01-19', '2016-01-20', '2016-01-21', '2016-01-22', '2016-01-25', '2016-01-26', '2016-01-27', '2016-01-28', '2016-01-29', '2016-02-01', '2016-02-02', '2016-02-03', '2016-02-04', '2016-02-05', '2016-02-08', '2016-02-09', '2016-02-10', '2016-02-11', '2016-02-12', '2016-02-15', '2016-02-16', '2016-02-17', '2016-02-18', '2016-02-19', '2016-02-20', '2016-02-22', '2016-02- ...

# %% [markdown]
# Разбиение дата фрейма 80/20

# %%
split_index = int(len(df_fut) * 0.8)  # Вычисляем индекс разбиения

df_80 = df_fut.iloc[:split_index]  # Первые 80%
df_20 = df_fut.iloc[split_index:]  # Последние 20%

# Получаем значение из 0-й строки df_20
first_trade_date = df_20.iloc[0]['TRADEDATE']

print(first_trade_date)
# Out:
# 2023-02-17

# %%
# === 4. СОЗДАНИЕ НЕЙРОСЕТИ (LSTM) ===
class CandleLSTM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim):
        super(CandleLSTM, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.lstm(x)
        x = self.fc(x[:, -1, :])  
        return self.sigmoid(x)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = CandleLSTM(
    vocab_size=len(unique_codes), embedding_dim=8, hidden_dim=32, output_dim=1
    ).to(device)

# Загружаем модель
model.load_state_dict(torch.load("best_model_02.pth"))
model.eval()

# Разделяем 80/20 и получаем first_trade_date
split_index = int(len(df_fut) * 0.8)
df_20 = df_fut.iloc[split_index:]
first_trade_date = df_20.iloc[0]['TRADEDATE']

# Определяем начальный индекс так, чтобы последнее значение первого окна было first_trade_date
start_index = df_fut[df_fut['TRADEDATE'] == first_trade_date].index[0] - 24  # 25 строк = 24 шага назад

# Если индекс ушел в минус, корректируем
start_index = max(0, start_index)

# Итерация по окнам в 25 строк
for i in range(start_index, len(df_fut) - 24):
    window = df_fut.iloc[i:i+25]  # Берем окно в 25 строк
    # print(f"Окно {i} - {i+24}, Последняя дата: {window.iloc[-1]['TRADEDATE']}")

    # Берем последние 20 свечей из df_fut
    last_sequence = torch.tensor(
        window['CANDLE_INT'].iloc[-20:].values, dtype=torch.long
        ).unsqueeze(0).to(device)

    # Предсказание
    with torch.no_grad():
        probability_up = model(last_sequence).item()  # Вероятность роста
        probability_down = 1 - probability_up  # Вероятность падения

        direction = "📈 UP" if probability_up >= 0.5 else "📉 DOWN"

        print(f"Prediction: {direction}")
        print(f"UP Probability: {probability_up:.2%}, DOWN Probability: {probability_down:.2%}")
        print()
# Out:
# Prediction: 📈 UP
# UP Probability: 95.67%, DOWN Probability: 4.33%
#
# Prediction: 📉 DOWN
# UP Probability: 1.00%, DOWN Probability: 99.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 25.27%, DOWN Probability: 74.73%
#
# Prediction: 📈 UP
# UP Probability: 99.97%, DOWN Probability: 0.03%
#
# Prediction: 📉 DOWN
# UP Probability: 35.54%, DOWN Probability: 64.46%
#
# Prediction: 📈 UP
# UP Probability: 96.25%, DOWN Probability: 3.75%
#
# Prediction: 📉 DOWN
# UP Probability: 1.71%, DOWN Probability: 98.29%
#
# Prediction: 📈 UP
# UP Probability: 99.54%, DOWN Probability: 0.46%
#
# Prediction: 📈 UP
# UP Probability: 89.56%, DOWN Probability: 10.44%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 54.88%, DOWN Probability: 45.12%
#
# Prediction: 📈 UP
# UP Probability: 83.86%, DOWN Probability: 16.14%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 99.89%, DOWN Probability: 0.11%
#
# Prediction: 📈 UP
# UP Probability: 99.98%, DOWN Probability: 0.02%
#
# Prediction: 📉 DOWN
# UP Probability: 6.71%, DOWN Probability: 93.29%
#
# Prediction: 📉 DOWN
# UP Probability: 1.45%, DOWN Probability: 98.55%
#
# Prediction: 📉 DOWN
# UP Probability: 3.53%, DOWN Probability: 96.47%
#
# Prediction: 📉 DOWN
# UP Probability: 45.60%, DOWN Probability: 54.40%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 88.38%, DOWN Probability: 11.62%
#
# Prediction: 📈 UP
# UP Probability: 99.87%, DOWN Probability: 0.13%
#
# Prediction: 📉 DOWN
# UP Probability: 19.87%, DOWN Probability: 80.13%
#
# Prediction: 📈 UP
# UP Probability: 72.33%, DOWN Probability: 27.67%
#
# Prediction: 📉 DOWN
# UP Probability: 0.28%, DOWN Probability: 99.72%
#
# Prediction: 📉 DOWN
# UP Probability: 0.15%, DOWN Probability: 99.85%
#
# Prediction: 📈 UP
# UP Probability: 72.54%, DOWN Probability: 27.46%
#
# Prediction: 📈 UP
# UP Probability: 99.61%, DOWN Probability: 0.39%
#
# Prediction: 📉 DOWN
# UP Probability: 0.02%, DOWN Probability: 99.98%
#
# Prediction: 📉 DOWN
# UP Probability: 0.01%, DOWN Probability: 99.99%
#
# Prediction: 📈 UP
# UP Probability: 92.47%, DOWN Probability: 7.53%
#
# Prediction: 📉 DOWN
# UP Probability: 22.24%, DOWN Probability: 77.76%
#
# Prediction: 📉 DOWN
# UP Probability: 2.23%, DOWN Probability: 97.77%
#
# Prediction: 📉 DOWN
# UP Probability: 0.07%, DOWN Probability: 99.93%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 97.61%, DOWN Probability: 2.39%
#
# Prediction: 📉 DOWN
# UP Probability: 0.01%, DOWN Probability: 99.99%
#
# Prediction: 📉 DOWN
# UP Probability: 16.59%, DOWN Probability: 83.41%
#
# Prediction: 📉 DOWN
# UP Probability: 21.20%, DOWN Probability: 78.80%
#
# Prediction: 📈 UP
# UP Probability: 99.94%, DOWN Probability: 0.06%
#
# Prediction: 📈 UP
# UP Probability: 99.90%, DOWN Probability: 0.10%
#
# Prediction: 📈 UP
# UP Probability: 99.98%, DOWN Probability: 0.02%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 99.52%, DOWN Probability: 0.48%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.01%, DOWN Probability: 99.99%
#
# Prediction: 📉 DOWN
# UP Probability: 46.98%, DOWN Probability: 53.02%
#
# Prediction: 📉 DOWN
# UP Probability: 0.73%, DOWN Probability: 99.27%
#
# Prediction: 📈 UP
# UP Probability: 72.33%, DOWN Probability: 27.67%
#
# Prediction: 📈 UP
# UP Probability: 98.15%, DOWN Probability: 1.85%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 99.47%, DOWN Probability: 0.53%
#
# Prediction: 📈 UP
# UP Probability: 99.81%, DOWN Probability: 0.19%
#
# Prediction: 📈 UP
# UP Probability: 61.02%, DOWN Probability: 38.98%
#
# Prediction: 📉 DOWN
# UP Probability: 2.41%, DOWN Probability: 97.59%
#
# Prediction: 📉 DOWN
# UP Probability: 0.04%, DOWN Probability: 99.96%
#
# Prediction: 📉 DOWN
# UP Probability: 6.84%, DOWN Probability: 93.16%
#
# Prediction: 📈 UP
# UP Probability: 97.13%, DOWN Probability: 2.87%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.25%, DOWN Probability: 99.75%
#
# Prediction: 📉 DOWN
# UP Probability: 0.18%, DOWN Probability: 99.82%
#
# Prediction: 📉 DOWN
# UP Probability: 1.81%, DOWN Probability: 98.19%
#
# Prediction: 📉 DOWN
# UP Probability: 0.04%, DOWN Probability: 99.96%
#
# Prediction: 📉 DOWN
# UP Probability: 5.41%, DOWN Probability: 94.59%
#
# Prediction: 📉 DOWN
# UP Probability: 38.71%, DOWN Probability: 61.29%
#
# Prediction: 📈 UP
# UP Probability: 99.81%, DOWN Probability: 0.19%
#
# Prediction: 📉 DOWN
# UP Probability: 0.75%, DOWN Probability: 99.25%
#
# Prediction: 📉 DOWN
# UP Probability: 0.01%, DOWN Probability: 99.99%
#
# Prediction: 📉 DOWN
# UP Probability: 0.01%, DOWN Probability: 99.99%
#
# Prediction: 📉 DOWN
# UP Probability: 0.01%, DOWN Probability: 99.99%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 40.96%, DOWN Probability: 59.04%
#
# Prediction: 📈 UP
# UP Probability: 92.96%, DOWN Probability: 7.04%
#
# Prediction: 📈 UP
# UP Probability: 97.14%, DOWN Probability: 2.86%
#
# Prediction: 📈 UP
# UP Probability: 99.99%, DOWN Probability: 0.01%
#
# Prediction: 📉 DOWN
# UP Probability: 19.27%, DOWN Probability: 80.73%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 1.81%, DOWN Probability: 98.19%
#
# Prediction: 📉 DOWN
# UP Probability: 0.62%, DOWN Probability: 99.38%
#
# Prediction: 📈 UP
# UP Probability: 70.79%, DOWN Probability: 29.21%
#
# Prediction: 📈 UP
# UP Probability: 98.94%, DOWN Probability: 1.06%
#
# Prediction: 📉 DOWN
# UP Probability: 5.10%, DOWN Probability: 94.90%
#
# Prediction: 📈 UP
# UP Probability: 98.23%, DOWN Probability: 1.77%
#
# Prediction: 📈 UP
# UP Probability: 99.96%, DOWN Probability: 0.04%
#
# Prediction: 📈 UP
# UP Probability: 99.25%, DOWN Probability: 0.75%
#
# Prediction: 📈 UP
# UP Probability: 96.61%, DOWN Probability: 3.39%
#
# Prediction: 📈 UP
# UP Probability: 95.06%, DOWN Probability: 4.94%
#
# Prediction: 📉 DOWN
# UP Probability: 1.83%, DOWN Probability: 98.17%
#
# Prediction: 📉 DOWN
# UP Probability: 45.61%, DOWN Probability: 54.39%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📈 UP
# UP Probability: 97.42%, DOWN Probability: 2.58%
#
# Prediction: 📈 UP
# UP Probability: 99.48%, DOWN Probability: 0.52%
#
# Prediction: 📈 UP
# UP Probability: 99.99%, DOWN Probability: 0.01%
#
# Prediction: 📈 UP
# UP Probability: 99.99%, DOWN Probability: 0.01%
#
# Prediction: 📈 UP
# UP Probability: 99.64%, DOWN Probability: 0.36%
#
# Prediction: 📈 UP
# UP Probability: 99.75%, DOWN Probability: 0.25%
#
# Prediction: 📈 UP
# UP Probability: 97.13%, DOWN Probability: 2.87%
#
# Prediction: 📈 UP
# UP Probability: 93.52%, DOWN Probability: 6.48%
#
# Prediction: 📉 DOWN
# UP Probability: 13.26%, DOWN Probability: 86.74%
#
# Prediction: 📉 DOWN
# UP Probability: 0.89%, DOWN Probability: 99.11%
#
# Prediction: 📉 DOWN
# UP Probability: 0.02%, DOWN Probability: 99.98%
#
# Prediction: 📉 DOWN
# UP Probability: 0.04%, DOWN Probability: 99.96%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📈 UP
# UP Probability: 94.41%, DOWN Probability: 5.59%
#
# Prediction: 📈 UP
# UP Probability: 81.85%, DOWN Probability: 18.15%
#
# Prediction: 📈 UP
# UP Probability: 71.51%, DOWN Probability: 28.49%
#
# Prediction: 📉 DOWN
# UP Probability: 3.16%, DOWN Probability: 96.84%
#
# Prediction: 📉 DOWN
# UP Probability: 0.17%, DOWN Probability: 99.83%
#
# Prediction: 📈 UP
# UP Probability: 80.05%, DOWN Probability: 19.95%
#
# Prediction: 📈 UP
# UP Probability: 99.51%, DOWN Probability: 0.49%
#
# Prediction: 📈 UP
# UP Probability: 92.17%, DOWN Probability: 7.83%
#
# Prediction: 📈 UP
# UP Probability: 51.43%, DOWN Probability: 48.57%
#
# Prediction: 📉 DOWN
# UP Probability: 4.77%, DOWN Probability: 95.23%
#
# Prediction: 📈 UP
# UP Probability: 99.48%, DOWN Probability: 0.52%
#
# Prediction: 📈 UP
# UP Probability: 97.47%, DOWN Probability: 2.53%
#
# Prediction: 📉 DOWN
# UP Probability: 0.14%, DOWN Probability: 99.86%
#
# Prediction: 📉 DOWN
# UP Probability: 25.08%, DOWN Probability: 74.92%
#
# Prediction: 📈 UP
# UP Probability: 86.62%, DOWN Probability: 13.38%
#
# Prediction: 📉 DOWN
# UP Probability: 0.02%, DOWN Probability: 99.98%
#
# Prediction: 📈 UP
# UP Probability: 87.70%, DOWN Probability: 12.30%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 99.95%, DOWN Probability: 0.05%
#
# Prediction: 📉 DOWN
# UP Probability: 0.29%, DOWN Probability: 99.71%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.01%, DOWN Probability: 99.99%
#
# Prediction: 📉 DOWN
# UP Probability: 11.82%, DOWN Probability: 88.18%
#
# Prediction: 📈 UP
# UP Probability: 59.29%, DOWN Probability: 40.71%
#
# Prediction: 📉 DOWN
# UP Probability: 0.39%, DOWN Probability: 99.61%
#
# Prediction: 📈 UP
# UP Probability: 86.06%, DOWN Probability: 13.94%
#
# Prediction: 📈 UP
# UP Probability: 99.83%, DOWN Probability: 0.17%
#
# Prediction: 📉 DOWN
# UP Probability: 0.77%, DOWN Probability: 99.23%
#
# Prediction: 📉 DOWN
# UP Probability: 35.23%, DOWN Probability: 64.77%
#
# Prediction: 📉 DOWN
# UP Probability: 45.14%, DOWN Probability: 54.86%
#
# Prediction: 📉 DOWN
# UP Probability: 0.03%, DOWN Probability: 99.97%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.31%, DOWN Probability: 99.69%
#
# Prediction: 📈 UP
# UP Probability: 99.83%, DOWN Probability: 0.17%
#
# Prediction: 📉 DOWN
# UP Probability: 0.68%, DOWN Probability: 99.32%
#
# Prediction: 📈 UP
# UP Probability: 83.26%, DOWN Probability: 16.74%
#
# Prediction: 📉 DOWN
# UP Probability: 5.02%, DOWN Probability: 94.98%
#
# Prediction: 📈 UP
# UP Probability: 79.20%, DOWN Probability: 20.80%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📈 UP
# UP Probability: 75.28%, DOWN Probability: 24.72%
#
# Prediction: 📈 UP
# UP Probability: 90.49%, DOWN Probability: 9.51%
#
# Prediction: 📈 UP
# UP Probability: 76.33%, DOWN Probability: 23.67%
#
# Prediction: 📉 DOWN
# UP Probability: 17.97%, DOWN Probability: 82.03%
#
# Prediction: 📈 UP
# UP Probability: 97.28%, DOWN Probability: 2.72%
#
# Prediction: 📉 DOWN
# UP Probability: 9.53%, DOWN Probability: 90.47%
#
# Prediction: 📉 DOWN
# UP Probability: 0.06%, DOWN Probability: 99.94%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.04%, DOWN Probability: 99.96%
#
# Prediction: 📈 UP
# UP Probability: 93.55%, DOWN Probability: 6.45%
#
# Prediction: 📈 UP
# UP Probability: 99.99%, DOWN Probability: 0.01%
#
# Prediction: 📈 UP
# UP Probability: 99.98%, DOWN Probability: 0.02%
#
# Prediction: 📈 UP
# UP Probability: 99.92%, DOWN Probability: 0.08%
#
# Prediction: 📈 UP
# UP Probability: 99.99%, DOWN Probability: 0.01%
#
# Prediction: 📉 DOWN
# UP Probability: 2.91%, DOWN Probability: 97.09%
#
# Prediction: 📈 UP
# UP Probability: 85.96%, DOWN Probability: 14.04%
#
# Prediction: 📈 UP
# UP Probability: 85.41%, DOWN Probability: 14.59%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 72.43%, DOWN Probability: 27.57%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.32%, DOWN Probability: 99.68%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 99.81%, DOWN Probability: 0.19%
#
# Prediction: 📈 UP
# UP Probability: 88.79%, DOWN Probability: 11.21%
#
# Prediction: 📉 DOWN
# UP Probability: 0.73%, DOWN Probability: 99.27%
#
# Prediction: 📉 DOWN
# UP Probability: 0.20%, DOWN Probability: 99.80%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 1.89%, DOWN Probability: 98.11%
#
# Prediction: 📈 UP
# UP Probability: 95.46%, DOWN Probability: 4.54%
#
# Prediction: 📉 DOWN
# UP Probability: 9.39%, DOWN Probability: 90.61%
#
# Prediction: 📉 DOWN
# UP Probability: 0.61%, DOWN Probability: 99.39%
#
# Prediction: 📉 DOWN
# UP Probability: 12.84%, DOWN Probability: 87.16%
#
# Prediction: 📉 DOWN
# UP Probability: 2.23%, DOWN Probability: 97.77%
#
# Prediction: 📉 DOWN
# UP Probability: 7.29%, DOWN Probability: 92.71%
#
# Prediction: 📈 UP
# UP Probability: 65.02%, DOWN Probability: 34.98%
#
# Prediction: 📈 UP
# UP Probability: 90.69%, DOWN Probability: 9.31%
#
# Prediction: 📈 UP
# UP Probability: 98.82%, DOWN Probability: 1.18%
#
# Prediction: 📉 DOWN
# UP Probability: 44.71%, DOWN Probability: 55.29%
#
# Prediction: 📈 UP
# UP Probability: 99.83%, DOWN Probability: 0.17%
#
# Prediction: 📈 UP
# UP Probability: 99.98%, DOWN Probability: 0.02%
#
# Prediction: 📉 DOWN
# UP Probability: 0.68%, DOWN Probability: 99.32%
#
# Prediction: 📉 DOWN
# UP Probability: 12.02%, DOWN Probability: 87.98%
#
# Prediction: 📈 UP
# UP Probability: 59.96%, DOWN Probability: 40.04%
#
# Prediction: 📈 UP
# UP Probability: 98.48%, DOWN Probability: 1.52%
#
# Prediction: 📉 DOWN
# UP Probability: 49.72%, DOWN Probability: 50.28%
#
# Prediction: 📈 UP
# UP Probability: 72.84%, DOWN Probability: 27.16%
#
# Prediction: 📈 UP
# UP Probability: 53.13%, DOWN Probability: 46.87%
#
# Prediction: 📈 UP
# UP Probability: 97.79%, DOWN Probability: 2.21%
#
# Prediction: 📈 UP
# UP Probability: 97.70%, DOWN Probability: 2.30%
#
# Prediction: 📈 UP
# UP Probability: 95.84%, DOWN Probability: 4.16%
#
# Prediction: 📈 UP
# UP Probability: 97.49%, DOWN Probability: 2.51%
#
# Prediction: 📈 UP
# UP Probability: 99.99%, DOWN Probability: 0.01%
#
# Prediction: 📉 DOWN
# UP Probability: 0.24%, DOWN Probability: 99.76%
#
# Prediction: 📉 DOWN
# UP Probability: 0.43%, DOWN Probability: 99.57%
#
# Prediction: 📉 DOWN
# UP Probability: 0.10%, DOWN Probability: 99.90%
#
# Prediction: 📉 DOWN
# UP Probability: 23.50%, DOWN Probability: 76.50%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 99.88%, DOWN Probability: 0.12%
#
# Prediction: 📈 UP
# UP Probability: 91.23%, DOWN Probability: 8.77%
#
# Prediction: 📈 UP
# UP Probability: 98.40%, DOWN Probability: 1.60%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 89.86%, DOWN Probability: 10.14%
#
# Prediction: 📈 UP
# UP Probability: 99.68%, DOWN Probability: 0.32%
#
# Prediction: 📈 UP
# UP Probability: 99.82%, DOWN Probability: 0.18%
#
# Prediction: 📈 UP
# UP Probability: 99.59%, DOWN Probability: 0.41%
#
# Prediction: 📉 DOWN
# UP Probability: 0.51%, DOWN Probability: 99.49%
#
# Prediction: 📉 DOWN
# UP Probability: 4.76%, DOWN Probability: 95.24%
#
# Prediction: 📉 DOWN
# UP Probability: 5.15%, DOWN Probability: 94.85%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.93%, DOWN Probability: 99.07%
#
# Prediction: 📈 UP
# UP Probability: 99.99%, DOWN Probability: 0.01%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 99.54%, DOWN Probability: 0.46%
#
# Prediction: 📈 UP
# UP Probability: 99.94%, DOWN Probability: 0.06%
#
# Prediction: 📈 UP
# UP Probability: 98.21%, DOWN Probability: 1.79%
#
# Prediction: 📉 DOWN
# UP Probability: 0.46%, DOWN Probability: 99.54%
#
# Prediction: 📉 DOWN
# UP Probability: 0.04%, DOWN Probability: 99.96%
#
# Prediction: 📈 UP
# UP Probability: 53.63%, DOWN Probability: 46.37%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 99.97%, DOWN Probability: 0.03%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 16.80%, DOWN Probability: 83.20%
#
# Prediction: 📈 UP
# UP Probability: 94.71%, DOWN Probability: 5.29%
#
# Prediction: 📈 UP
# UP Probability: 96.00%, DOWN Probability: 4.00%
#
# Prediction: 📉 DOWN
# UP Probability: 4.24%, DOWN Probability: 95.76%
#
# Prediction: 📉 DOWN
# UP Probability: 0.50%, DOWN Probability: 99.50%
#
# Prediction: 📉 DOWN
# UP Probability: 0.42%, DOWN Probability: 99.58%
#
# Prediction: 📉 DOWN
# UP Probability: 9.77%, DOWN Probability: 90.23%
#
# Prediction: 📉 DOWN
# UP Probability: 48.46%, DOWN Probability: 51.54%
#
# Prediction: 📈 UP
# UP Probability: 63.76%, DOWN Probability: 36.24%
#
# Prediction: 📉 DOWN
# UP Probability: 6.95%, DOWN Probability: 93.05%
#
# Prediction: 📈 UP
# UP Probability: 99.63%, DOWN Probability: 0.37%
#
# Prediction: 📈 UP
# UP Probability: 97.73%, DOWN Probability: 2.27%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📈 UP
# UP Probability: 98.37%, DOWN Probability: 1.63%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.48%, DOWN Probability: 99.52%
#
# Prediction: 📉 DOWN
# UP Probability: 0.09%, DOWN Probability: 99.91%
#
# Prediction: 📈 UP
# UP Probability: 56.59%, DOWN Probability: 43.41%
#
# Prediction: 📈 UP
# UP Probability: 90.34%, DOWN Probability: 9.66%
#
# Prediction: 📈 UP
# UP Probability: 99.97%, DOWN Probability: 0.03%
#
# Prediction: 📉 DOWN
# UP Probability: 17.99%, DOWN Probability: 82.01%
#
# Prediction: 📈 UP
# UP Probability: 98.12%, DOWN Probability: 1.88%
#
# Prediction: 📈 UP
# UP Probability: 76.43%, DOWN Probability: 23.57%
#
# Prediction: 📈 UP
# UP Probability: 97.26%, DOWN Probability: 2.74%
#
# Prediction: 📉 DOWN
# UP Probability: 0.12%, DOWN Probability: 99.88%
#
# Prediction: 📈 UP
# UP Probability: 98.21%, DOWN Probability: 1.79%
#
# Prediction: 📈 UP
# UP Probability: 99.94%, DOWN Probability: 0.06%
#
# Prediction: 📈 UP
# UP Probability: 99.80%, DOWN Probability: 0.20%
#
# Prediction: 📉 DOWN
# UP Probability: 1.39%, DOWN Probability: 98.61%
#
# Prediction: 📈 UP
# UP Probability: 99.98%, DOWN Probability: 0.02%
#
# Prediction: 📈 UP
# UP Probability: 98.61%, DOWN Probability: 1.39%
#
# Prediction: 📉 DOWN
# UP Probability: 0.37%, DOWN Probability: 99.63%
#
# Prediction: 📈 UP
# UP Probability: 53.37%, DOWN Probability: 46.63%
#
# Prediction: 📉 DOWN
# UP Probability: 28.38%, DOWN Probability: 71.62%
#
# Prediction: 📈 UP
# UP Probability: 58.06%, DOWN Probability: 41.94%
#
# Prediction: 📉 DOWN
# UP Probability: 36.04%, DOWN Probability: 63.96%
#
# Prediction: 📈 UP
# UP Probability: 99.42%, DOWN Probability: 0.58%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📉 DOWN
# UP Probability: 24.47%, DOWN Probability: 75.53%
#
# Prediction: 📉 DOWN
# UP Probability: 0.01%, DOWN Probability: 99.99%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.16%, DOWN Probability: 99.84%
#
# Prediction: 📈 UP
# UP Probability: 99.35%, DOWN Probability: 0.65%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.08%, DOWN Probability: 99.92%
#
# Prediction: 📉 DOWN
# UP Probability: 0.11%, DOWN Probability: 99.89%
#
# Prediction: 📉 DOWN
# UP Probability: 48.37%, DOWN Probability: 51.63%
#
# Prediction: 📈 UP
# UP Probability: 98.55%, DOWN Probability: 1.45%
#
# Prediction: 📈 UP
# UP Probability: 99.31%, DOWN Probability: 0.69%
#
# Prediction: 📈 UP
# UP Probability: 97.56%, DOWN Probability: 2.44%
#
# Prediction: 📈 UP
# UP Probability: 99.77%, DOWN Probability: 0.23%
#
# Prediction: 📈 UP
# UP Probability: 99.18%, DOWN Probability: 0.82%
#
# Prediction: 📉 DOWN
# UP Probability: 0.48%, DOWN Probability: 99.52%
#
# Prediction: 📈 UP
# UP Probability: 99.99%, DOWN Probability: 0.01%
#
# Prediction: 📈 UP
# UP Probability: 67.18%, DOWN Probability: 32.82%
#
# Prediction: 📈 UP
# UP Probability: 91.17%, DOWN Probability: 8.83%
#
# Prediction: 📉 DOWN
# UP Probability: 0.31%, DOWN Probability: 99.69%
#
# Prediction: 📉 DOWN
# UP Probability: 13.65%, DOWN Probability: 86.35%
#
# Prediction: 📈 UP
# UP Probability: 61.63%, DOWN Probability: 38.37%
#
# Prediction: 📈 UP
# UP Probability: 99.99%, DOWN Probability: 0.01%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 85.64%, DOWN Probability: 14.36%
#
# Prediction: 📈 UP
# UP Probability: 85.31%, DOWN Probability: 14.69%
#
# Prediction: 📈 UP
# UP Probability: 99.98%, DOWN Probability: 0.02%
#
# Prediction: 📈 UP
# UP Probability: 71.69%, DOWN Probability: 28.31%
#
# Prediction: 📈 UP
# UP Probability: 50.15%, DOWN Probability: 49.85%
#
# Prediction: 📉 DOWN
# UP Probability: 0.11%, DOWN Probability: 99.89%
#
# Prediction: 📉 DOWN
# UP Probability: 0.26%, DOWN Probability: 99.74%
#
# Prediction: 📉 DOWN
# UP Probability: 0.18%, DOWN Probability: 99.82%
#
# Prediction: 📉 DOWN
# UP Probability: 0.14%, DOWN Probability: 99.86%
#
# Prediction: 📉 DOWN
# UP Probability: 2.79%, DOWN Probability: 97.21%
#
# Prediction: 📉 DOWN
# UP Probability: 0.56%, DOWN Probability: 99.44%
#
# Prediction: 📉 DOWN
# UP Probability: 0.64%, DOWN Probability: 99.36%
#
# Prediction: 📈 UP
# UP Probability: 99.61%, DOWN Probability: 0.39%
#
# Prediction: 📈 UP
# UP Probability: 96.74%, DOWN Probability: 3.26%
#
# Prediction: 📈 UP
# UP Probability: 85.32%, DOWN Probability: 14.68%
#
# Prediction: 📈 UP
# UP Probability: 62.57%, DOWN Probability: 37.43%
#
# Prediction: 📈 UP
# UP Probability: 99.63%, DOWN Probability: 0.37%
#
# Prediction: 📈 UP
# UP Probability: 56.30%, DOWN Probability: 43.70%
#
# Prediction: 📈 UP
# UP Probability: 75.90%, DOWN Probability: 24.10%
#
# Prediction: 📈 UP
# UP Probability: 58.20%, DOWN Probability: 41.80%
#
# Prediction: 📈 UP
# UP Probability: 94.81%, DOWN Probability: 5.19%
#
# Prediction: 📈 UP
# UP Probability: 67.21%, DOWN Probability: 32.79%
#
# Prediction: 📈 UP
# UP Probability: 81.76%, DOWN Probability: 18.24%
#
# Prediction: 📈 UP
# UP Probability: 96.41%, DOWN Probability: 3.59%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 96.79%, DOWN Probability: 3.21%
#
# Prediction: 📉 DOWN
# UP Probability: 3.14%, DOWN Probability: 96.86%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 4.27%, DOWN Probability: 95.73%
#
# Prediction: 📈 UP
# UP Probability: 55.83%, DOWN Probability: 44.17%
#
# Prediction: 📉 DOWN
# UP Probability: 16.57%, DOWN Probability: 83.43%
#
# Prediction: 📉 DOWN
# UP Probability: 8.06%, DOWN Probability: 91.94%
#
# Prediction: 📈 UP
# UP Probability: 93.43%, DOWN Probability: 6.57%
#
# Prediction: 📈 UP
# UP Probability: 99.37%, DOWN Probability: 0.63%
#
# Prediction: 📉 DOWN
# UP Probability: 3.00%, DOWN Probability: 97.00%
#
# Prediction: 📈 UP
# UP Probability: 97.55%, DOWN Probability: 2.45%
#
# Prediction: 📈 UP
# UP Probability: 99.54%, DOWN Probability: 0.46%
#
# Prediction: 📈 UP
# UP Probability: 97.80%, DOWN Probability: 2.20%
#
# Prediction: 📉 DOWN
# UP Probability: 1.49%, DOWN Probability: 98.51%
#
# Prediction: 📈 UP
# UP Probability: 85.83%, DOWN Probability: 14.17%
#
# Prediction: 📉 DOWN
# UP Probability: 6.46%, DOWN Probability: 93.54%
#
# Prediction: 📉 DOWN
# UP Probability: 10.49%, DOWN Probability: 89.51%
#
# Prediction: 📉 DOWN
# UP Probability: 0.16%, DOWN Probability: 99.84%
#
# Prediction: 📉 DOWN
# UP Probability: 4.02%, DOWN Probability: 95.98%
#
# Prediction: 📈 UP
# UP Probability: 83.26%, DOWN Probability: 16.74%
#
# Prediction: 📈 UP
# UP Probability: 87.40%, DOWN Probability: 12.60%
#
# Prediction: 📉 DOWN
# UP Probability: 45.45%, DOWN Probability: 54.55%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📉 DOWN
# UP Probability: 5.53%, DOWN Probability: 94.47%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 99.97%, DOWN Probability: 0.03%
#
# Prediction: 📈 UP
# UP Probability: 87.45%, DOWN Probability: 12.55%
#
# Prediction: 📈 UP
# UP Probability: 98.72%, DOWN Probability: 1.28%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 4.74%, DOWN Probability: 95.26%
#
# Prediction: 📈 UP
# UP Probability: 75.92%, DOWN Probability: 24.08%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📈 UP
# UP Probability: 96.25%, DOWN Probability: 3.75%
#
# Prediction: 📈 UP
# UP Probability: 55.67%, DOWN Probability: 44.33%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 27.15%, DOWN Probability: 72.85%
#
# Prediction: 📈 UP
# UP Probability: 99.80%, DOWN Probability: 0.20%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 99.68%, DOWN Probability: 0.32%
#
# Prediction: 📉 DOWN
# UP Probability: 37.32%, DOWN Probability: 62.68%
#
# Prediction: 📉 DOWN
# UP Probability: 1.16%, DOWN Probability: 98.84%
#
# Prediction: 📉 DOWN
# UP Probability: 18.86%, DOWN Probability: 81.14%
#
# Prediction: 📉 DOWN
# UP Probability: 13.24%, DOWN Probability: 86.76%
#
# Prediction: 📈 UP
# UP Probability: 79.83%, DOWN Probability: 20.17%
#
# Prediction: 📈 UP
# UP Probability: 97.23%, DOWN Probability: 2.77%
#
# Prediction: 📉 DOWN
# UP Probability: 0.38%, DOWN Probability: 99.62%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 1.95%, DOWN Probability: 98.05%
#
# Prediction: 📉 DOWN
# UP Probability: 1.61%, DOWN Probability: 98.39%
#
# Prediction: 📈 UP
# UP Probability: 99.99%, DOWN Probability: 0.01%
#
# Prediction: 📉 DOWN
# UP Probability: 0.01%, DOWN Probability: 99.99%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📈 UP
# UP Probability: 99.65%, DOWN Probability: 0.35%
#
# Prediction: 📈 UP
# UP Probability: 99.99%, DOWN Probability: 0.01%
#
# Prediction: 📈 UP
# UP Probability: 98.91%, DOWN Probability: 1.09%
#
# Prediction: 📉 DOWN
# UP Probability: 0.19%, DOWN Probability: 99.81%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 2.38%, DOWN Probability: 97.62%
#
# Prediction: 📈 UP
# UP Probability: 89.08%, DOWN Probability: 10.92%
#
# Prediction: 📉 DOWN
# UP Probability: 6.95%, DOWN Probability: 93.05%
#
# Prediction: 📈 UP
# UP Probability: 98.62%, DOWN Probability: 1.38%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.24%, DOWN Probability: 99.76%
#
# Prediction: 📈 UP
# UP Probability: 97.89%, DOWN Probability: 2.11%
#
# Prediction: 📈 UP
# UP Probability: 99.99%, DOWN Probability: 0.01%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📉 DOWN
# UP Probability: 5.09%, DOWN Probability: 94.91%
#
# Prediction: 📈 UP
# UP Probability: 96.19%, DOWN Probability: 3.81%
#
# Prediction: 📉 DOWN
# UP Probability: 3.68%, DOWN Probability: 96.32%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.02%, DOWN Probability: 99.98%
#
# Prediction: 📈 UP
# UP Probability: 89.71%, DOWN Probability: 10.29%
#
# Prediction: 📉 DOWN
# UP Probability: 33.98%, DOWN Probability: 66.02%
#
# Prediction: 📈 UP
# UP Probability: 99.23%, DOWN Probability: 0.77%
#
# Prediction: 📈 UP
# UP Probability: 99.76%, DOWN Probability: 0.24%
#
# Prediction: 📉 DOWN
# UP Probability: 19.36%, DOWN Probability: 80.64%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.05%, DOWN Probability: 99.95%
#
# Prediction: 📉 DOWN
# UP Probability: 0.98%, DOWN Probability: 99.02%
#
# Prediction: 📈 UP
# UP Probability: 96.31%, DOWN Probability: 3.69%
#
# Prediction: 📈 UP
# UP Probability: 85.24%, DOWN Probability: 14.76%
#
# Prediction: 📈 UP
# UP Probability: 99.99%, DOWN Probability: 0.01%
#
# Prediction: 📈 UP
# UP Probability: 99.41%, DOWN Probability: 0.59%
#
# Prediction: 📉 DOWN
# UP Probability: 36.64%, DOWN Probability: 63.36%
#
# Prediction: 📈 UP
# UP Probability: 73.82%, DOWN Probability: 26.18%
#
# Prediction: 📉 DOWN
# UP Probability: 0.27%, DOWN Probability: 99.73%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.01%, DOWN Probability: 99.99%
#
# Prediction: 📈 UP
# UP Probability: 84.46%, DOWN Probability: 15.54%
#
# Prediction: 📉 DOWN
# UP Probability: 26.06%, DOWN Probability: 73.94%
#
# Prediction: 📈 UP
# UP Probability: 74.11%, DOWN Probability: 25.89%
#
# Prediction: 📉 DOWN
# UP Probability: 28.52%, DOWN Probability: 71.48%
#
# Prediction: 📉 DOWN
# UP Probability: 0.54%, DOWN Probability: 99.46%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📈 UP
# UP Probability: 99.57%, DOWN Probability: 0.43%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 11.60%, DOWN Probability: 88.40%
#
# Prediction: 📈 UP
# UP Probability: 64.25%, DOWN Probability: 35.75%
#
# Prediction: 📈 UP
# UP Probability: 99.99%, DOWN Probability: 0.01%
#
# Prediction: 📉 DOWN
# UP Probability: 2.89%, DOWN Probability: 97.11%
#
# Prediction: 📈 UP
# UP Probability: 55.96%, DOWN Probability: 44.04%
#
# Prediction: 📈 UP
# UP Probability: 56.79%, DOWN Probability: 43.21%
#
# Prediction: 📈 UP
# UP Probability: 98.07%, DOWN Probability: 1.93%
#
# Prediction: 📈 UP
# UP Probability: 98.36%, DOWN Probability: 1.64%
#
# Prediction: 📉 DOWN
# UP Probability: 41.12%, DOWN Probability: 58.88%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.02%, DOWN Probability: 99.98%
#
# Prediction: 📈 UP
# UP Probability: 99.98%, DOWN Probability: 0.02%
#
# Prediction: 📉 DOWN
# UP Probability: 25.04%, DOWN Probability: 74.96%
#
# Prediction: 📉 DOWN
# UP Probability: 0.08%, DOWN Probability: 99.92%
#
# Prediction: 📉 DOWN
# UP Probability: 0.01%, DOWN Probability: 99.99%
#
# Prediction: 📈 UP
# UP Probability: 97.99%, DOWN Probability: 2.01%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 26.96%, DOWN Probability: 73.04%
#
# Prediction: 📉 DOWN
# UP Probability: 5.76%, DOWN Probability: 94.24%
#
# Prediction: 📈 UP
# UP Probability: 98.85%, DOWN Probability: 1.15%
#
# Prediction: 📉 DOWN
# UP Probability: 2.21%, DOWN Probability: 97.79%
#
# Prediction: 📈 UP
# UP Probability: 93.64%, DOWN Probability: 6.36%
#
# Prediction: 📈 UP
# UP Probability: 99.81%, DOWN Probability: 0.19%
#
# Prediction: 📉 DOWN
# UP Probability: 3.41%, DOWN Probability: 96.59%
#
# Prediction: 📈 UP
# UP Probability: 70.41%, DOWN Probability: 29.59%
#
# Prediction: 📉 DOWN
# UP Probability: 0.79%, DOWN Probability: 99.21%
#
# Prediction: 📉 DOWN
# UP Probability: 0.01%, DOWN Probability: 99.99%
#
# Prediction: 📉 DOWN
# UP Probability: 0.35%, DOWN Probability: 99.65%
#
# Prediction: 📉 DOWN
# UP Probability: 1.09%, DOWN Probability: 98.91%
#
# Prediction: 📉 DOWN
# UP Probability: 13.96%, DOWN Probability: 86.04%
#
# Prediction: 📈 UP
# UP Probability: 96.27%, DOWN Probability: 3.73%
#
# Prediction: 📉 DOWN
# UP Probability: 0.02%, DOWN Probability: 99.98%
#
# Prediction: 📉 DOWN
# UP Probability: 0.01%, DOWN Probability: 99.99%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.01%, DOWN Probability: 99.99%
#
# Prediction: 📉 DOWN
# UP Probability: 14.28%, DOWN Probability: 85.72%
#
# Prediction: 📉 DOWN
# UP Probability: 35.76%, DOWN Probability: 64.24%
#
# Prediction: 📈 UP
# UP Probability: 97.55%, DOWN Probability: 2.45%
#
# Prediction: 📉 DOWN
# UP Probability: 2.36%, DOWN Probability: 97.64%
#
# Prediction: 📉 DOWN
# UP Probability: 0.02%, DOWN Probability: 99.98%
#
# Prediction: 📉 DOWN
# UP Probability: 0.12%, DOWN Probability: 99.88%
#
# Prediction: 📉 DOWN
# UP Probability: 6.80%, DOWN Probability: 93.20%
#
# Prediction: 📈 UP
# UP Probability: 50.60%, DOWN Probability: 49.40%
#
# Prediction: 📉 DOWN
# UP Probability: 31.53%, DOWN Probability: 68.47%
#
# Prediction: 📉 DOWN
# UP Probability: 3.12%, DOWN Probability: 96.88%
#
# Prediction: 📉 DOWN
# UP Probability: 0.53%, DOWN Probability: 99.47%
#
# Prediction: 📉 DOWN
# UP Probability: 0.39%, DOWN Probability: 99.61%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📈 UP
# UP Probability: 86.74%, DOWN Probability: 13.26%
#
# Prediction: 📈 UP
# UP Probability: 99.50%, DOWN Probability: 0.50%
#
# Prediction: 📈 UP
# UP Probability: 99.98%, DOWN Probability: 0.02%
#
# Prediction: 📈 UP
# UP Probability: 53.84%, DOWN Probability: 46.16%
#
# Prediction: 📈 UP
# UP Probability: 97.09%, DOWN Probability: 2.91%
#
# Prediction: 📉 DOWN
# UP Probability: 8.32%, DOWN Probability: 91.68%
#
# Prediction: 📈 UP
# UP Probability: 64.57%, DOWN Probability: 35.43%
#
# Prediction: 📉 DOWN
# UP Probability: 0.04%, DOWN Probability: 99.96%
#
# Prediction: 📈 UP
# UP Probability: 77.37%, DOWN Probability: 22.63%
#
# Prediction: 📈 UP
# UP Probability: 99.97%, DOWN Probability: 0.03%
#
# Prediction: 📈 UP
# UP Probability: 99.99%, DOWN Probability: 0.01%
#
# Prediction: 📈 UP
# UP Probability: 97.82%, DOWN Probability: 2.18%
#
# Prediction: 📉 DOWN
# UP Probability: 0.01%, DOWN Probability: 99.99%
#
# Prediction: 📈 UP
# UP Probability: 97.87%, DOWN Probability: 2.13%
#
# Prediction: 📈 UP
# UP Probability: 99.99%, DOWN Probability: 0.01%
#
# Prediction: 📉 DOWN
# UP Probability: 1.33%, DOWN Probability: 98.67%
#
# Prediction: 📉 DOWN
# UP Probability: 5.04%, DOWN Probability: 94.96%
#
# Prediction: 📈 UP
# UP Probability: 74.22%, DOWN Probability: 25.78%
#
# Prediction: 📈 UP
# UP Probability: 66.30%, DOWN Probability: 33.70%
#
# Prediction: 📈 UP
# UP Probability: 93.62%, DOWN Probability: 6.38%
#
# Prediction: 📉 DOWN
# UP Probability: 12.95%, DOWN Probability: 87.05%
#
# Prediction: 📈 UP
# UP Probability: 94.03%, DOWN Probability: 5.97%
#
# Prediction: 📈 UP
# UP Probability: 99.53%, DOWN Probability: 0.47%
#
# Prediction: 📈 UP
# UP Probability: 98.99%, DOWN Probability: 1.01%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 0.26%, DOWN Probability: 99.74%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📉 DOWN
# UP Probability: 41.98%, DOWN Probability: 58.02%
#
# Prediction: 📈 UP
# UP Probability: 99.58%, DOWN Probability: 0.42%
#
# Prediction: 📉 DOWN
# UP Probability: 4.72%, DOWN Probability: 95.28%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 77.58%, DOWN Probability: 22.42%
#
# Prediction: 📉 DOWN
# UP Probability: 0.00%, DOWN Probability: 100.00%
#
# Prediction: 📈 UP
# UP Probability: 99.72%, DOWN Probability: 0.28%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
#
# Prediction: 📈 UP
# UP Probability: 97.86%, DOWN Probability: 2.14%
#
# Prediction: 📈 UP
# UP Probability: 97.00%, DOWN Probability: 3.00%
#
# Prediction: 📈 UP
# UP Probability: 100.00%, DOWN Probability: 0.00%
