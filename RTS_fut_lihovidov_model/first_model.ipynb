# %% [markdown]
# # Кодировка свечей по методу Лиховидова, прогноз Up или Down.

# %% [markdown]
# Обучение модели на основе кода свечи Лиховидова.
# Бинарная классификация Up или Down.
# Основной гиперпараметр seed. Подбирается по графикам.

# %%
import sqlite3
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
import random
from pathlib import Path
from torch.utils.data import Dataset, DataLoader

# %%
# === 1. ФИКСАЦИЯ СЛУЧАЙНЫХ ЧИСЕЛ ДЛЯ ДЕТЕРМИНИРОВАННОСТИ ===
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# [53, 84], 1, 11, 15, 27, 32, 47, 53, 78, 82, 84, 91
set_seed(53)  # Устанавливаем одинаковый seed

# === 2. ЗАГРУЗКА ДАННЫХ ===
# db_path = Path(r'C:\Users\Alkor\gd\data_quote_db\RTS_futures_options_day.db')

# with sqlite3.connect(db_path) as conn:
#     df_fut = pd.read_sql_query(
#         "SELECT TRADEDATE, OPEN, LOW, HIGH, CLOSE, VOLUME FROM Futures",
#         conn
#     )

db_path = Path(r'C:\Users\Alkor\gd\data_quote_db\RTS_futures_day.db')

with sqlite3.connect(db_path) as conn:
    df_fut = pd.read_sql_query(
        "SELECT TRADEDATE, OPEN, LOW, HIGH, CLOSE, VOLUME FROM Day",
        conn
    )

"""
Строка ниже.
Фиксация порядка данных (если используем перемешивание). В данном случае не используется т.к. 
для создания фичей используются данные предыдущих свечей.
"""
# df_fut = df_fut.sample(frac=1, random_state=42).reset_index(drop=True)

# === 3. ФУНКЦИЯ КОДИРОВАНИЯ СВЕЧЕЙ (ЛИХОВИДОВ) ===
def encode_candle(row):
    open_, low, high, close = row['OPEN'], row['LOW'], row['HIGH'], row['CLOSE']

    direction = 1 if close > open_ else (0 if close < open_ else 2)
    upper_shadow = high - max(open_, close)
    lower_shadow = min(open_, close) - low
    body = abs(close - open_)

    def classify_shadow(shadow, body):
        return 0 if shadow < 0.1 * body else (1 if shadow < 0.5 * body else 2)

    return f"{direction}{classify_shadow(upper_shadow, body)}{classify_shadow(lower_shadow, body)}"

df_fut['CANDLE_CODE'] = df_fut.apply(encode_candle, axis=1)

# === 4. ПОДГОТОВКА ДАННЫХ ===
unique_codes = sorted(df_fut['CANDLE_CODE'].unique())
code_to_int = {code: i for i, code in enumerate(unique_codes)}
df_fut['CANDLE_INT'] = df_fut['CANDLE_CODE'].map(code_to_int)

window_size = 20  
predict_offset = 1  

X, y = [], []
for i in range(len(df_fut) - window_size - predict_offset):
    X.append(df_fut['CANDLE_INT'].iloc[i:i+window_size].values)
    y.append(
        1 if df_fut['CLOSE'].iloc[i+window_size+predict_offset] > 
        df_fut['CLOSE'].iloc[i+window_size] else 0
    )

X, y = np.array(X), np.array(y)

split = int(0.8 * len(X))
X_train, y_train = X[:split], y[:split]
X_test, y_test = X[split:], y[split:]

class CandlestickDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.long)
        self.y = torch.tensor(y, dtype=torch.float32)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

def seed_worker(worker_id):
    np.random.seed(42 + worker_id)
    random.seed(42 + worker_id)

train_dataset = CandlestickDataset(X_train, y_train)
test_dataset = CandlestickDataset(X_test, y_test)
# print(X_train)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, worker_init_fn=seed_worker)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, worker_init_fn=seed_worker)

# === 5. СОЗДАНИЕ НЕЙРОСЕТИ (LSTM) ===
class CandleLSTM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim):
        super(CandleLSTM, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.lstm(x)
        x = self.fc(x[:, -1, :])  
        return self.sigmoid(x)

# === 6. ОБУЧЕНИЕ МОДЕЛИ С СОХРАНЕНИЕМ ЛУЧШЕЙ ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = CandleLSTM(
    vocab_size=len(unique_codes), embedding_dim=8, hidden_dim=32, output_dim=1
).to(device)
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

best_accuracy = 0  
epoch_best_accuracy = 0
model_path = "best_model_first.pth"
early_stop_epochs = 200  # Для ранней остановки
epochs_no_improve = 0

epochs = 2000
for epoch in range(epochs):
    model.train()
    total_loss = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()
        y_pred = model(X_batch).squeeze()
        loss = criterion(y_pred, y_batch)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    # === Проверка на тесте после каждой эпохи ===
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_pred = model(X_batch).squeeze().round()
            correct += (y_pred == y_batch).sum().item()
            total += y_batch.size(0)

    accuracy = correct / total
    print(
        f"Epoch {epoch+1}/{epochs}, "
        f"Loss: {total_loss/len(train_loader):.4f}, "
        f"Test Accuracy: {accuracy:.2%}, "
        f"Best accuracy: {best_accuracy:.2%}, "
        f"Epoch best accuracy: {epoch_best_accuracy}, "
        f"seed: 53"
    )

    # === Сохранение лучшей модели ===
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        epochs_no_improve = 0
        epoch_best_accuracy = epoch + 1
        torch.save(model.state_dict(), model_path)
        print(f"✅ Model saved with accuracy: {best_accuracy:.2%}")
    else:
        epochs_no_improve += 1

    # === Ранняя остановка ===
    if epochs_no_improve >= early_stop_epochs:
        print(f"🛑 Early stopping at epoch {epoch + 1}")
        break

# === 7. ЗАГРУЗКА ЛУЧШЕЙ МОДЕЛИ И ТЕСТ ===
print("\n🔹 Loading best model for final evaluation...")
model.load_state_dict(torch.load(model_path))
model.eval()

correct = 0
total = 0
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        y_pred = model(X_batch).squeeze().round()
        correct += (y_pred == y_batch).sum().item()
        total += y_batch.size(0)

final_accuracy = correct / total
print(f"🏆 Final Test Accuracy: {final_accuracy:.2%}")

# # === 8. СОХРАНЕНИЕ ВЕРСИЙ БИБЛИОТЕК ===
# print("\n🔹 Library versions:")
# print(f"PyTorch: {torch.__version__}")
# print(f"NumPy: {np.__version__}")
# print(f"Pandas: {pd.__version__}")
# Out:
# Epoch 1/2000, Loss: 0.6940, Test Accuracy: 50.49%, Best accuracy: 0.00%, Epoch best accuracy: 0, seed: 53
# ✅ Model saved with accuracy: 50.49%
# Epoch 2/2000, Loss: 0.6920, Test Accuracy: 50.49%, Best accuracy: 50.49%, Epoch best accuracy: 1, seed: 53
# Epoch 3/2000, Loss: 0.6911, Test Accuracy: 50.49%, Best accuracy: 50.49%, Epoch best accuracy: 1, seed: 53
# Epoch 4/2000, Loss: 0.6908, Test Accuracy: 49.90%, Best accuracy: 50.49%, Epoch best accuracy: 1, seed: 53
# Epoch 5/2000, Loss: 0.6900, Test Accuracy: 50.10%, Best accuracy: 50.49%, Epoch best accuracy: 1, seed: 53
# Epoch 6/2000, Loss: 0.6900, Test Accuracy: 51.08%, Best accuracy: 50.49%, Epoch best accuracy: 1, seed: 53
# ✅ Model saved with accuracy: 51.08%
# Epoch 7/2000, Loss: 0.6890, Test Accuracy: 51.08%, Best accuracy: 51.08%, Epoch best accuracy: 6, seed: 53
# Epoch 8/2000, Loss: 0.6881, Test Accuracy: 50.89%, Best accuracy: 51.08%, Epoch best accuracy: 6, seed: 53
# Epoch 9/2000, Loss: 0.6878, Test Accuracy: 49.11%, Best accuracy: 51.08%, Epoch best accuracy: 6, seed: 53
# Epoch 10/2000, Loss: 0.6867, Test Accuracy: 51.48%, Best accuracy: 51.08%, Epoch best accuracy: 6, seed: 53
# ✅ Model saved with accuracy: 51.48%
# Epoch 11/2000, Loss: 0.6862, Test Accuracy: 53.65%, Best accuracy: 51.48%, Epoch best accuracy: 10, seed: 53
# ✅ Model saved with accuracy: 53.65%
# Epoch 12/2000, Loss: 0.6860, Test Accuracy: 53.45%, Best accuracy: 53.65%, Epoch best accuracy: 11, seed: 53
# Epoch 13/2000, Loss: 0.6848, Test Accuracy: 54.24%, Best accuracy: 53.65%, Epoch best accuracy: 11, seed: 53
# ✅ Model saved with accuracy: 54.24%
# Epoch 14/2000, Loss: 0.6824, Test Accuracy: 51.68%, Best accuracy: 54.24%, Epoch best accuracy: 13, seed: 53
# Epoch 15/2000, Loss: 0.6833, Test Accuracy: 52.27%, Best accuracy: 54.24%, Epoch best accuracy: 13, seed: 53
# Epoch 16/2000, Loss: 0.6819, Test Accuracy: 54.64%, Best accuracy: 54.24%, Epoch best accuracy: 13, seed: 53
# ✅ Model saved with accuracy: 54.64%
# Epoch 17/2000, Loss: 0.6799, Test Accuracy: 51.68%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 18/2000, Loss: 0.6783, Test Accuracy: 52.07%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 19/2000, Loss: 0.6771, Test Accuracy: 51.48%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 20/2000, Loss: 0.6742, Test Accuracy: 53.06%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 21/2000, Loss: 0.6728, Test Accuracy: 53.06%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 22/2000, Loss: 0.6714, Test Accuracy: 52.66%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 23/2000, Loss: 0.6674, Test Accuracy: 53.45%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 24/2000, Loss: 0.6624, Test Accuracy: 52.86%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 25/2000, Loss: 0.6594, Test Accuracy: 52.66%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 26/2000, Loss: 0.6568, Test Accuracy: 53.65%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 27/2000, Loss: 0.6554, Test Accuracy: 52.86%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 28/2000, Loss: 0.6525, Test Accuracy: 53.06%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 29/2000, Loss: 0.6459, Test Accuracy: 52.66%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 30/2000, Loss: 0.6390, Test Accuracy: 53.85%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 31/2000, Loss: 0.6331, Test Accuracy: 49.90%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 32/2000, Loss: 0.6306, Test Accuracy: 52.47%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 33/2000, Loss: 0.6252, Test Accuracy: 51.28%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 34/2000, Loss: 0.6206, Test Accuracy: 48.72%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 35/2000, Loss: 0.6196, Test Accuracy: 50.89%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 36/2000, Loss: 0.6121, Test Accuracy: 47.93%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 37/2000, Loss: 0.6042, Test Accuracy: 49.51%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 38/2000, Loss: 0.6027, Test Accuracy: 52.07%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 39/2000, Loss: 0.5958, Test Accuracy: 48.72%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 40/2000, Loss: 0.5898, Test Accuracy: 51.87%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 41/2000, Loss: 0.5853, Test Accuracy: 50.69%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 42/2000, Loss: 0.5844, Test Accuracy: 53.25%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 43/2000, Loss: 0.5814, Test Accuracy: 50.49%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 44/2000, Loss: 0.5699, Test Accuracy: 50.49%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 45/2000, Loss: 0.5634, Test Accuracy: 52.07%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 46/2000, Loss: 0.5630, Test Accuracy: 51.08%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 47/2000, Loss: 0.5531, Test Accuracy: 51.68%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 48/2000, Loss: 0.5534, Test Accuracy: 51.48%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 49/2000, Loss: 0.5421, Test Accuracy: 53.25%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 50/2000, Loss: 0.5395, Test Accuracy: 50.89%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 51/2000, Loss: 0.5430, Test Accuracy: 51.48%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 52/2000, Loss: 0.5352, Test Accuracy: 51.08%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 53/2000, Loss: 0.5173, Test Accuracy: 51.08%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 54/2000, Loss: 0.5172, Test Accuracy: 50.69%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 55/2000, Loss: 0.5139, Test Accuracy: 51.48%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 56/2000, Loss: 0.5021, Test Accuracy: 49.70%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 57/2000, Loss: 0.5016, Test Accuracy: 49.70%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 58/2000, Loss: 0.4876, Test Accuracy: 50.30%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 59/2000, Loss: 0.4880, Test Accuracy: 49.90%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 60/2000, Loss: 0.4897, Test Accuracy: 50.49%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 61/2000, Loss: 0.4702, Test Accuracy: 50.49%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 62/2000, Loss: 0.4614, Test Accuracy: 49.90%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 63/2000, Loss: 0.4675, Test Accuracy: 49.31%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 64/2000, Loss: 0.4570, Test Accuracy: 51.08%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 65/2000, Loss: 0.4385, Test Accuracy: 50.30%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 66/2000, Loss: 0.4399, Test Accuracy: 51.68%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 67/2000, Loss: 0.4261, Test Accuracy: 48.92%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 68/2000, Loss: 0.4373, Test Accuracy: 51.68%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 69/2000, Loss: 0.4150, Test Accuracy: 51.28%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 70/2000, Loss: 0.4245, Test Accuracy: 50.69%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 71/2000, Loss: 0.4251, Test Accuracy: 49.90%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 72/2000, Loss: 0.4109, Test Accuracy: 52.07%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 73/2000, Loss: 0.4017, Test Accuracy: 49.31%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 74/2000, Loss: 0.3968, Test Accuracy: 51.08%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 75/2000, Loss: 0.3808, Test Accuracy: 48.32%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 76/2000, Loss: 0.3724, Test Accuracy: 49.51%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 77/2000, Loss: 0.3701, Test Accuracy: 48.52%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 78/2000, Loss: 0.3612, Test Accuracy: 50.69%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 79/2000, Loss: 0.3565, Test Accuracy: 50.49%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 80/2000, Loss: 0.3446, Test Accuracy: 50.69%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 81/2000, Loss: 0.3452, Test Accuracy: 49.90%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 82/2000, Loss: 0.3408, Test Accuracy: 49.51%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 83/2000, Loss: 0.3509, Test Accuracy: 49.70%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 84/2000, Loss: 0.3566, Test Accuracy: 50.89%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 85/2000, Loss: 0.3243, Test Accuracy: 51.08%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 86/2000, Loss: 0.3299, Test Accuracy: 50.49%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 87/2000, Loss: 0.3465, Test Accuracy: 50.10%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 88/2000, Loss: 0.3288, Test Accuracy: 51.48%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 89/2000, Loss: 0.3092, Test Accuracy: 51.28%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 90/2000, Loss: 0.3051, Test Accuracy: 51.87%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 91/2000, Loss: 0.2903, Test Accuracy: 51.87%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 92/2000, Loss: 0.2786, Test Accuracy: 51.48%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 93/2000, Loss: 0.2943, Test Accuracy: 51.28%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 94/2000, Loss: 0.2864, Test Accuracy: 51.28%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 95/2000, Loss: 0.2771, Test Accuracy: 49.51%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 96/2000, Loss: 0.2695, Test Accuracy: 52.86%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 97/2000, Loss: 0.2546, Test Accuracy: 51.87%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 98/2000, Loss: 0.2466, Test Accuracy: 51.08%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 99/2000, Loss: 0.2468, Test Accuracy: 52.27%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 100/2000, Loss: 0.2560, Test Accuracy: 51.68%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 101/2000, Loss: 0.2596, Test Accuracy: 52.07%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 102/2000, Loss: 0.2387, Test Accuracy: 50.10%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 103/2000, Loss: 0.2310, Test Accuracy: 51.48%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 104/2000, Loss: 0.2322, Test Accuracy: 50.49%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 105/2000, Loss: 0.2401, Test Accuracy: 51.48%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 106/2000, Loss: 0.2613, Test Accuracy: 52.27%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 107/2000, Loss: 0.2274, Test Accuracy: 50.89%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 108/2000, Loss: 0.2105, Test Accuracy: 50.49%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 109/2000, Loss: 0.2086, Test Accuracy: 52.27%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 110/2000, Loss: 0.2042, Test Accuracy: 50.89%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 111/2000, Loss: 0.1934, Test Accuracy: 50.30%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 112/2000, Loss: 0.1886, Test Accuracy: 50.89%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 113/2000, Loss: 0.1825, Test Accuracy: 50.69%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 114/2000, Loss: 0.1777, Test Accuracy: 51.48%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 115/2000, Loss: 0.1756, Test Accuracy: 52.86%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 116/2000, Loss: 0.1750, Test Accuracy: 49.70%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 117/2000, Loss: 0.1889, Test Accuracy: 51.68%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 118/2000, Loss: 0.1729, Test Accuracy: 52.27%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 119/2000, Loss: 0.1746, Test Accuracy: 51.08%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 120/2000, Loss: 0.2100, Test Accuracy: 51.68%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 121/2000, Loss: 0.1717, Test Accuracy: 53.85%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 122/2000, Loss: 0.1691, Test Accuracy: 52.47%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 123/2000, Loss: 0.1510, Test Accuracy: 51.87%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 124/2000, Loss: 0.1547, Test Accuracy: 52.47%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 125/2000, Loss: 0.1622, Test Accuracy: 53.25%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 126/2000, Loss: 0.1659, Test Accuracy: 51.68%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 127/2000, Loss: 0.2206, Test Accuracy: 53.45%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 128/2000, Loss: 0.1522, Test Accuracy: 54.04%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 129/2000, Loss: 0.1971, Test Accuracy: 53.25%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 130/2000, Loss: 0.1920, Test Accuracy: 54.04%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 131/2000, Loss: 0.1575, Test Accuracy: 50.89%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 132/2000, Loss: 0.2009, Test Accuracy: 52.47%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 133/2000, Loss: 0.1658, Test Accuracy: 52.47%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 134/2000, Loss: 0.1545, Test Accuracy: 50.89%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 135/2000, Loss: 0.2094, Test Accuracy: 54.44%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 136/2000, Loss: 0.1359, Test Accuracy: 51.28%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 137/2000, Loss: 0.1164, Test Accuracy: 53.25%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 138/2000, Loss: 0.1092, Test Accuracy: 53.65%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 139/2000, Loss: 0.1149, Test Accuracy: 52.86%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 140/2000, Loss: 0.1033, Test Accuracy: 53.45%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 141/2000, Loss: 0.0995, Test Accuracy: 53.06%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 142/2000, Loss: 0.0969, Test Accuracy: 53.45%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 143/2000, Loss: 0.0935, Test Accuracy: 53.85%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 144/2000, Loss: 0.0917, Test Accuracy: 53.85%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 145/2000, Loss: 0.0888, Test Accuracy: 53.45%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 146/2000, Loss: 0.0846, Test Accuracy: 53.06%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 147/2000, Loss: 0.0826, Test Accuracy: 53.25%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 148/2000, Loss: 0.0807, Test Accuracy: 53.06%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 149/2000, Loss: 0.0813, Test Accuracy: 53.45%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 150/2000, Loss: 0.0909, Test Accuracy: 52.86%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 151/2000, Loss: 0.1088, Test Accuracy: 52.47%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 152/2000, Loss: 0.1265, Test Accuracy: 53.85%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 153/2000, Loss: 0.2823, Test Accuracy: 51.08%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 154/2000, Loss: 0.1806, Test Accuracy: 53.45%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 155/2000, Loss: 0.1214, Test Accuracy: 53.85%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 156/2000, Loss: 0.1006, Test Accuracy: 53.06%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 157/2000, Loss: 0.1016, Test Accuracy: 53.25%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 158/2000, Loss: 0.1010, Test Accuracy: 53.45%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 159/2000, Loss: 0.0895, Test Accuracy: 54.44%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 160/2000, Loss: 0.0761, Test Accuracy: 54.04%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 161/2000, Loss: 0.0680, Test Accuracy: 53.85%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 162/2000, Loss: 0.0644, Test Accuracy: 52.66%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 163/2000, Loss: 0.0647, Test Accuracy: 53.85%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 164/2000, Loss: 0.0600, Test Accuracy: 53.85%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 165/2000, Loss: 0.0578, Test Accuracy: 54.04%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 166/2000, Loss: 0.0568, Test Accuracy: 53.06%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 167/2000, Loss: 0.0544, Test Accuracy: 53.45%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 168/2000, Loss: 0.0532, Test Accuracy: 53.06%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 169/2000, Loss: 0.0513, Test Accuracy: 53.25%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 170/2000, Loss: 0.0500, Test Accuracy: 54.44%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 171/2000, Loss: 0.0594, Test Accuracy: 54.24%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 172/2000, Loss: 0.1338, Test Accuracy: 54.44%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 173/2000, Loss: 0.4062, Test Accuracy: 54.24%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 174/2000, Loss: 0.2299, Test Accuracy: 51.28%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 175/2000, Loss: 0.1118, Test Accuracy: 54.64%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# Epoch 176/2000, Loss: 0.1124, Test Accuracy: 55.23%, Best accuracy: 54.64%, Epoch best accuracy: 16, seed: 53
# ✅ Model saved with accuracy: 55.23%
# Epoch 177/2000, Loss: 0.1529, Test Accuracy: 53.45%, Best accuracy: 55.23%, Epoch best accuracy: 176, seed: 53
# Epoch 178/2000, Loss: 0.1105, Test Accuracy: 54.44%, Best accuracy: 55.23%, Epoch best accuracy: 176, seed: 53
# Epoch 179/2000, Loss: 0.0717, Test Accuracy: 54.04%, Best accuracy: 55.23%, Epoch best accuracy: 176, seed: 53
# Epoch 180/2000, Loss: 0.0687, Test Accuracy: 55.03%, Best accuracy: 55.23%, Epoch best accuracy: 176, seed: 53
# Epoch 181/2000, Loss: 0.0678, Test Accuracy: 55.82%, Best accuracy: 55.23%, Epoch best accuracy: 176, seed: 53
# ✅ Model saved with accuracy: 55.82%
# Epoch 182/2000, Loss: 0.0521, Test Accuracy: 55.82%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 183/2000, Loss: 0.0487, Test Accuracy: 55.23%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 184/2000, Loss: 0.0460, Test Accuracy: 54.64%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 185/2000, Loss: 0.0443, Test Accuracy: 54.64%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 186/2000, Loss: 0.0439, Test Accuracy: 55.42%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 187/2000, Loss: 0.0411, Test Accuracy: 54.83%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 188/2000, Loss: 0.0399, Test Accuracy: 54.44%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 189/2000, Loss: 0.0381, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 190/2000, Loss: 0.0371, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 191/2000, Loss: 0.0357, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 192/2000, Loss: 0.0348, Test Accuracy: 53.85%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 193/2000, Loss: 0.0338, Test Accuracy: 54.24%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 194/2000, Loss: 0.0329, Test Accuracy: 53.85%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 195/2000, Loss: 0.0315, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 196/2000, Loss: 0.0302, Test Accuracy: 54.44%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 197/2000, Loss: 0.0295, Test Accuracy: 53.85%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 198/2000, Loss: 0.0295, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 199/2000, Loss: 0.0295, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 200/2000, Loss: 0.0278, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 201/2000, Loss: 0.0267, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 202/2000, Loss: 0.1450, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 203/2000, Loss: 0.2927, Test Accuracy: 51.48%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 204/2000, Loss: 0.2057, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 205/2000, Loss: 0.1806, Test Accuracy: 52.86%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 206/2000, Loss: 0.1379, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 207/2000, Loss: 0.1005, Test Accuracy: 54.64%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 208/2000, Loss: 0.1015, Test Accuracy: 52.47%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 209/2000, Loss: 0.0535, Test Accuracy: 52.86%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 210/2000, Loss: 0.0420, Test Accuracy: 52.66%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 211/2000, Loss: 0.0367, Test Accuracy: 51.68%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 212/2000, Loss: 0.0331, Test Accuracy: 52.86%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 213/2000, Loss: 0.0312, Test Accuracy: 52.47%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 214/2000, Loss: 0.0292, Test Accuracy: 52.66%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 215/2000, Loss: 0.0278, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 216/2000, Loss: 0.0275, Test Accuracy: 52.66%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 217/2000, Loss: 0.0255, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 218/2000, Loss: 0.0247, Test Accuracy: 51.87%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 219/2000, Loss: 0.0236, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 220/2000, Loss: 0.0223, Test Accuracy: 52.86%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 221/2000, Loss: 0.0216, Test Accuracy: 52.86%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 222/2000, Loss: 0.0210, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 223/2000, Loss: 0.0209, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 224/2000, Loss: 0.0199, Test Accuracy: 52.86%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 225/2000, Loss: 0.0191, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 226/2000, Loss: 0.0188, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 227/2000, Loss: 0.0176, Test Accuracy: 52.47%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 228/2000, Loss: 0.0170, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 229/2000, Loss: 0.0165, Test Accuracy: 52.86%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 230/2000, Loss: 0.0159, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 231/2000, Loss: 0.0152, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 232/2000, Loss: 0.0151, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 233/2000, Loss: 0.0146, Test Accuracy: 52.86%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 234/2000, Loss: 0.0138, Test Accuracy: 52.66%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 235/2000, Loss: 0.0134, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 236/2000, Loss: 0.0134, Test Accuracy: 52.86%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 237/2000, Loss: 0.0157, Test Accuracy: 52.66%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 238/2000, Loss: 0.0940, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 239/2000, Loss: 0.4421, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 240/2000, Loss: 0.3174, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 241/2000, Loss: 0.2027, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 242/2000, Loss: 0.1226, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 243/2000, Loss: 0.0893, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 244/2000, Loss: 0.0657, Test Accuracy: 54.04%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 245/2000, Loss: 0.0435, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 246/2000, Loss: 0.0476, Test Accuracy: 52.66%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 247/2000, Loss: 0.0747, Test Accuracy: 54.64%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 248/2000, Loss: 0.0470, Test Accuracy: 54.44%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 249/2000, Loss: 0.0322, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 250/2000, Loss: 0.0240, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 251/2000, Loss: 0.0207, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 252/2000, Loss: 0.0192, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 253/2000, Loss: 0.0181, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 254/2000, Loss: 0.0170, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 255/2000, Loss: 0.0162, Test Accuracy: 52.66%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 256/2000, Loss: 0.0158, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 257/2000, Loss: 0.0152, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 258/2000, Loss: 0.0143, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 259/2000, Loss: 0.0139, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 260/2000, Loss: 0.0131, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 261/2000, Loss: 0.0128, Test Accuracy: 52.86%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 262/2000, Loss: 0.0123, Test Accuracy: 52.27%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 263/2000, Loss: 0.0121, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 264/2000, Loss: 0.0117, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 265/2000, Loss: 0.0112, Test Accuracy: 52.27%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 266/2000, Loss: 0.0107, Test Accuracy: 52.86%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 267/2000, Loss: 0.0104, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 268/2000, Loss: 0.0102, Test Accuracy: 52.66%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 269/2000, Loss: 0.0098, Test Accuracy: 52.66%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 270/2000, Loss: 0.0095, Test Accuracy: 52.86%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 271/2000, Loss: 0.0092, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 272/2000, Loss: 0.0090, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 273/2000, Loss: 0.0085, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 274/2000, Loss: 0.0084, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 275/2000, Loss: 0.0081, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 276/2000, Loss: 0.0078, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 277/2000, Loss: 0.0076, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 278/2000, Loss: 0.0073, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 279/2000, Loss: 0.0071, Test Accuracy: 52.66%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 280/2000, Loss: 0.0069, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 281/2000, Loss: 0.0067, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 282/2000, Loss: 0.0064, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 283/2000, Loss: 0.0063, Test Accuracy: 52.86%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 284/2000, Loss: 0.0061, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 285/2000, Loss: 0.0058, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 286/2000, Loss: 0.0057, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 287/2000, Loss: 0.0055, Test Accuracy: 52.86%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 288/2000, Loss: 0.0053, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 289/2000, Loss: 0.0051, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 290/2000, Loss: 0.0050, Test Accuracy: 53.85%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 291/2000, Loss: 0.0072, Test Accuracy: 54.83%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 292/2000, Loss: 0.7080, Test Accuracy: 54.64%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 293/2000, Loss: 0.5276, Test Accuracy: 54.64%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 294/2000, Loss: 0.2208, Test Accuracy: 54.83%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 295/2000, Loss: 0.1973, Test Accuracy: 54.64%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 296/2000, Loss: 0.1437, Test Accuracy: 52.27%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 297/2000, Loss: 0.1542, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 298/2000, Loss: 0.0789, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 299/2000, Loss: 0.0781, Test Accuracy: 52.86%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 300/2000, Loss: 0.0608, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 301/2000, Loss: 0.0424, Test Accuracy: 52.66%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 302/2000, Loss: 0.0290, Test Accuracy: 54.04%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 303/2000, Loss: 0.0231, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 304/2000, Loss: 0.0200, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 305/2000, Loss: 0.0181, Test Accuracy: 53.85%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 306/2000, Loss: 0.0166, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 307/2000, Loss: 0.0154, Test Accuracy: 54.24%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 308/2000, Loss: 0.0144, Test Accuracy: 53.85%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 309/2000, Loss: 0.0140, Test Accuracy: 53.85%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 310/2000, Loss: 0.0129, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 311/2000, Loss: 0.0125, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 312/2000, Loss: 0.0116, Test Accuracy: 53.85%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 313/2000, Loss: 0.0111, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 314/2000, Loss: 0.0105, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 315/2000, Loss: 0.0101, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 316/2000, Loss: 0.0099, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 317/2000, Loss: 0.0092, Test Accuracy: 53.85%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 318/2000, Loss: 0.0090, Test Accuracy: 53.85%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 319/2000, Loss: 0.0086, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 320/2000, Loss: 0.0084, Test Accuracy: 53.85%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 321/2000, Loss: 0.0080, Test Accuracy: 54.04%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 322/2000, Loss: 0.0077, Test Accuracy: 54.04%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 323/2000, Loss: 0.0075, Test Accuracy: 54.24%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 324/2000, Loss: 0.0072, Test Accuracy: 53.85%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 325/2000, Loss: 0.0070, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 326/2000, Loss: 0.0067, Test Accuracy: 54.24%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 327/2000, Loss: 0.0066, Test Accuracy: 53.85%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 328/2000, Loss: 0.0064, Test Accuracy: 53.85%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 329/2000, Loss: 0.0061, Test Accuracy: 53.85%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 330/2000, Loss: 0.0059, Test Accuracy: 54.24%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 331/2000, Loss: 0.0057, Test Accuracy: 54.24%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 332/2000, Loss: 0.0056, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 333/2000, Loss: 0.0055, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 334/2000, Loss: 0.0053, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 335/2000, Loss: 0.0051, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 336/2000, Loss: 0.0049, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 337/2000, Loss: 0.0048, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 338/2000, Loss: 0.0047, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 339/2000, Loss: 0.0045, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 340/2000, Loss: 0.0044, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 341/2000, Loss: 0.0042, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 342/2000, Loss: 0.0041, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 343/2000, Loss: 0.0040, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 344/2000, Loss: 0.0039, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 345/2000, Loss: 0.0038, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 346/2000, Loss: 0.0036, Test Accuracy: 54.04%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 347/2000, Loss: 0.0035, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 348/2000, Loss: 0.0035, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 349/2000, Loss: 0.0033, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 350/2000, Loss: 0.0032, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 351/2000, Loss: 0.0031, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 352/2000, Loss: 0.0030, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 353/2000, Loss: 0.0029, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 354/2000, Loss: 0.0029, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 355/2000, Loss: 0.0028, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 356/2000, Loss: 0.0027, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 357/2000, Loss: 0.0026, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 358/2000, Loss: 0.0025, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 359/2000, Loss: 0.0024, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 360/2000, Loss: 0.0024, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 361/2000, Loss: 0.0023, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 362/2000, Loss: 0.0022, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 363/2000, Loss: 0.0022, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 364/2000, Loss: 0.0021, Test Accuracy: 53.06%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 365/2000, Loss: 0.0020, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 366/2000, Loss: 0.0020, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 367/2000, Loss: 0.0019, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 368/2000, Loss: 0.0018, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 369/2000, Loss: 0.0018, Test Accuracy: 53.25%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 370/2000, Loss: 0.0018, Test Accuracy: 53.85%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 371/2000, Loss: 0.0017, Test Accuracy: 53.85%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 372/2000, Loss: 0.0017, Test Accuracy: 53.65%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 373/2000, Loss: 0.9061, Test Accuracy: 53.45%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 374/2000, Loss: 0.7987, Test Accuracy: 54.04%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 375/2000, Loss: 0.4980, Test Accuracy: 54.64%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 376/2000, Loss: 0.2686, Test Accuracy: 54.64%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 377/2000, Loss: 0.1941, Test Accuracy: 52.66%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 378/2000, Loss: 0.1208, Test Accuracy: 52.07%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 379/2000, Loss: 0.2265, Test Accuracy: 51.48%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 380/2000, Loss: 0.0941, Test Accuracy: 51.48%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# Epoch 381/2000, Loss: 0.0764, Test Accuracy: 52.86%, Best accuracy: 55.82%, Epoch best accuracy: 181, seed: 53
# 🛑 Early stopping at epoch 381
#
# 🔹 Loading best model for final evaluation...
# 🏆 Final Test Accuracy: 55.82%

# %% [markdown]
# 🔹 Как использовать модель для предсказания?
# После загрузки модели можно предсказать направление следующей свечи:

# %%
# Загружаем модель
model.load_state_dict(torch.load("best_model_first.pth"))
model.eval()

# Берем последние 20 свечей из df_fut
last_sequence = torch.tensor(
    df_fut['CANDLE_INT'].iloc[-20:].values, dtype=torch.long
    ).unsqueeze(0).to(device)

# Предсказание
with torch.no_grad():
    probability_up = model(last_sequence).item()  # Вероятность роста
    probability_down = 1 - probability_up  # Вероятность падения

    direction = "📈 UP" if probability_up >= 0.5 else "📉 DOWN"

    print(f"Prediction: {direction}")
    print(
        f"UP Probability: {probability_up:.2%}, \n"
        f"DOWN Probability: {probability_down:.2%}"
        )
# Out:
# Prediction: 📈 UP
# UP Probability: 100.00%,
# DOWN Probability: 0.00%
