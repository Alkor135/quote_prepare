# %% [markdown]
# # Кодировка свечей по методу Лиховидова, прогноз Up или Down.

# %% [markdown]
# Обучение модели на основе кода свечи Лиховидова.
# Бинарная классификация Up или Down.
# Основной гиперпараметр seed. Подбирается по графикам.
# Вот обновленный код с использованием взвешивания классов в функции потерь (BCEWithLogitsLoss с pos_weight). Я добавил вычисление pos_weight на основе количества классов и передал его в функцию потерь.

# %%
import sqlite3
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
import random
from pathlib import Path
from torch.utils.data import Dataset, DataLoader

# === Функция для фиксации случайных чисел ===
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_var = 79
set_seed(seed_var)

# === Загрузка данных ===
db_path = Path(r'C:\Users\Alkor\gd\data_quote_db\MIX_futures_day.db')
with sqlite3.connect(db_path) as conn:
    df_fut = pd.read_sql_query(
        """
        SELECT TRADEDATE, OPEN, LOW, HIGH, CLOSE, VOLUME 
        FROM Day 
        ORDER BY TRADEDATE
        """,
        conn
    )

# === Функция кодирования свечей ===
def encode_candle(row):
    open_, low, high, close = row['OPEN'], row['LOW'], row['HIGH'], row['CLOSE']
    direction = 1 if close > open_ else (0 if close < open_ else 2)
    upper_shadow = high - max(open_, close)
    lower_shadow = min(open_, close) - low
    body = abs(close - open_)
    
    def classify_shadow(shadow, body):
        return 0 if shadow < 0.1 * body else (1 if shadow < 0.5 * body else 2)

    return f"{direction}{classify_shadow(upper_shadow, body)}{classify_shadow(lower_shadow, body)}"

df_fut['CANDLE_CODE'] = df_fut.apply(encode_candle, axis=1)

# === Преобразование кодов в числа ===
unique_codes = sorted(df_fut['CANDLE_CODE'].unique())
code_to_int = {code: i for i, code in enumerate(unique_codes)}
df_fut['CANDLE_INT'] = df_fut['CANDLE_CODE'].map(code_to_int)

window_size = 20  
predict_offset = 1  

# === Подготовка данных. Создание последовательностей (датасетов). ===
X, y = [], []
for i in range(len(df_fut) - window_size - predict_offset):
    X.append(df_fut['CANDLE_INT'].iloc[i:i+window_size].values)
    y.append(
        1 if df_fut['CLOSE'].iloc[i+window_size+predict_offset] > 
        df_fut['CLOSE'].iloc[i+window_size] else 0
    )

X, y = np.array(X), np.array(y)

# === Разделение на обучающую и тестовую выборки ===
split = int(0.8 * len(X))
X_train, y_train = X[:split], y[:split]
X_test, y_test = X[split:], y[split:]

# === Взвешивание классов ===
class_counts = np.bincount(y_train)
# pos_weight = torch.tensor([class_counts[0] / class_counts[1]], dtype=torch.float32)
pos_weight = torch.tensor([class_counts[0] / class_counts[1]]) if class_counts[1] > 0 else torch.tensor([1.0])

# === Создание DataLoader ===
class CandlestickDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.long)
        self.y = torch.tensor(y, dtype=torch.float32)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# === Инициализация генератора случайных чисел для каждого воркера ===
def seed_worker(worker_id):
    np.random.seed(42 + worker_id)
    random.seed(42 + worker_id)

train_dataset = CandlestickDataset(X_train, y_train)
test_dataset = CandlestickDataset(X_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, worker_init_fn=seed_worker)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, worker_init_fn=seed_worker)

# === Определение модели ===
class CandleLSTM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim):
        super(CandleLSTM, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.lstm(x)
        x = self.fc(x[:, -1, :])  
        return x  # Без sigmoid, так как используем BCEWithLogitsLoss

# === Выбор устройства ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# === Инициализация модели ===
model = CandleLSTM(
    vocab_size=len(unique_codes), embedding_dim=8, hidden_dim=32, output_dim=1
).to(device)

# === Использование взвешивания классов ===
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight.to(device))
optimizer = optim.Adam(model.parameters(), lr=0.001)

best_accuracy = 0  
epoch_best_accuracy = 0
model_path = "best_model_first_MIX_01.pth"
early_stop_epochs = 200
epochs_no_improve = 0

epochs = 2000
for epoch in range(epochs):
    model.train()
    total_loss = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()
        y_pred = model(X_batch).squeeze()
        loss = criterion(y_pred, y_batch)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_pred = torch.sigmoid(model(X_batch).squeeze()).round()
            correct += (y_pred == y_batch).sum().item()
            total += y_batch.size(0)

    accuracy = correct / total
    print(
        f"Epoch {epoch+1}/{epochs}, "
        f"Loss: {total_loss/len(train_loader):.4f}, "
        f"Test Accuracy: {accuracy:.2%}, "
        f"Best accuracy: {best_accuracy:.2%}, "
        f"Epoch best accuracy: {epoch_best_accuracy}, "
        f"seed: {seed_var}"
    )

    if accuracy > best_accuracy:
        best_accuracy = accuracy
        epochs_no_improve = 0
        epoch_best_accuracy = epoch + 1
        torch.save(model.state_dict(), model_path)
        print(f"✅ Model saved with accuracy: {best_accuracy:.2%}")
    else:
        epochs_no_improve += 1

    if epochs_no_improve >= early_stop_epochs:
        print(f"🛑 Early stopping at epoch {epoch + 1}")
        break

print("\n🔹 Loading best model for final evaluation...")
model.load_state_dict(torch.load(model_path))
model.eval()

correct = 0
total = 0
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        y_pred = torch.sigmoid(model(X_batch).squeeze()).round()
        correct += (y_pred == y_batch).sum().item()
        total += y_batch.size(0)

final_accuracy = correct / total
print(f"🏆 Final Test Accuracy: {final_accuracy:.2%}")
# Out:
# Epoch 1/2000, Loss: 0.6734, Test Accuracy: 44.58%, Best accuracy: 0.00%, Epoch best accuracy: 0, seed: 79
# ✅ Model saved with accuracy: 44.58%
# Epoch 2/2000, Loss: 0.6732, Test Accuracy: 46.15%, Best accuracy: 44.58%, Epoch best accuracy: 1, seed: 79
# ✅ Model saved with accuracy: 46.15%
# Epoch 3/2000, Loss: 0.6722, Test Accuracy: 47.34%, Best accuracy: 46.15%, Epoch best accuracy: 2, seed: 79
# ✅ Model saved with accuracy: 47.34%
# Epoch 4/2000, Loss: 0.6719, Test Accuracy: 47.73%, Best accuracy: 47.34%, Epoch best accuracy: 3, seed: 79
# ✅ Model saved with accuracy: 47.73%
# Epoch 5/2000, Loss: 0.6715, Test Accuracy: 48.92%, Best accuracy: 47.73%, Epoch best accuracy: 4, seed: 79
# ✅ Model saved with accuracy: 48.92%
# Epoch 6/2000, Loss: 0.6706, Test Accuracy: 47.34%, Best accuracy: 48.92%, Epoch best accuracy: 5, seed: 79
# Epoch 7/2000, Loss: 0.6702, Test Accuracy: 48.92%, Best accuracy: 48.92%, Epoch best accuracy: 5, seed: 79
# Epoch 8/2000, Loss: 0.6696, Test Accuracy: 48.13%, Best accuracy: 48.92%, Epoch best accuracy: 5, seed: 79
# Epoch 9/2000, Loss: 0.6680, Test Accuracy: 48.32%, Best accuracy: 48.92%, Epoch best accuracy: 5, seed: 79
# Epoch 10/2000, Loss: 0.6666, Test Accuracy: 48.72%, Best accuracy: 48.92%, Epoch best accuracy: 5, seed: 79
# Epoch 11/2000, Loss: 0.6662, Test Accuracy: 48.52%, Best accuracy: 48.92%, Epoch best accuracy: 5, seed: 79
# Epoch 12/2000, Loss: 0.6650, Test Accuracy: 50.10%, Best accuracy: 48.92%, Epoch best accuracy: 5, seed: 79
# ✅ Model saved with accuracy: 50.10%
# Epoch 13/2000, Loss: 0.6638, Test Accuracy: 49.51%, Best accuracy: 50.10%, Epoch best accuracy: 12, seed: 79
# Epoch 14/2000, Loss: 0.6626, Test Accuracy: 50.49%, Best accuracy: 50.10%, Epoch best accuracy: 12, seed: 79
# ✅ Model saved with accuracy: 50.49%
# Epoch 15/2000, Loss: 0.6596, Test Accuracy: 49.70%, Best accuracy: 50.49%, Epoch best accuracy: 14, seed: 79
# Epoch 16/2000, Loss: 0.6575, Test Accuracy: 51.08%, Best accuracy: 50.49%, Epoch best accuracy: 14, seed: 79
# ✅ Model saved with accuracy: 51.08%
# Epoch 17/2000, Loss: 0.6546, Test Accuracy: 51.87%, Best accuracy: 51.08%, Epoch best accuracy: 16, seed: 79
# ✅ Model saved with accuracy: 51.87%
# Epoch 18/2000, Loss: 0.6524, Test Accuracy: 51.48%, Best accuracy: 51.87%, Epoch best accuracy: 17, seed: 79
# Epoch 19/2000, Loss: 0.6506, Test Accuracy: 50.69%, Best accuracy: 51.87%, Epoch best accuracy: 17, seed: 79
# Epoch 20/2000, Loss: 0.6465, Test Accuracy: 50.10%, Best accuracy: 51.87%, Epoch best accuracy: 17, seed: 79
# Epoch 21/2000, Loss: 0.6416, Test Accuracy: 51.28%, Best accuracy: 51.87%, Epoch best accuracy: 17, seed: 79
# Epoch 22/2000, Loss: 0.6377, Test Accuracy: 48.52%, Best accuracy: 51.87%, Epoch best accuracy: 17, seed: 79
# Epoch 23/2000, Loss: 0.6339, Test Accuracy: 50.69%, Best accuracy: 51.87%, Epoch best accuracy: 17, seed: 79
# Epoch 24/2000, Loss: 0.6275, Test Accuracy: 49.90%, Best accuracy: 51.87%, Epoch best accuracy: 17, seed: 79
# Epoch 25/2000, Loss: 0.6242, Test Accuracy: 51.08%, Best accuracy: 51.87%, Epoch best accuracy: 17, seed: 79
# Epoch 26/2000, Loss: 0.6195, Test Accuracy: 49.11%, Best accuracy: 51.87%, Epoch best accuracy: 17, seed: 79
# Epoch 27/2000, Loss: 0.6130, Test Accuracy: 49.90%, Best accuracy: 51.87%, Epoch best accuracy: 17, seed: 79
# Epoch 28/2000, Loss: 0.6096, Test Accuracy: 50.10%, Best accuracy: 51.87%, Epoch best accuracy: 17, seed: 79
# Epoch 29/2000, Loss: 0.6045, Test Accuracy: 50.10%, Best accuracy: 51.87%, Epoch best accuracy: 17, seed: 79
# Epoch 30/2000, Loss: 0.5987, Test Accuracy: 49.31%, Best accuracy: 51.87%, Epoch best accuracy: 17, seed: 79
# Epoch 31/2000, Loss: 0.5938, Test Accuracy: 49.90%, Best accuracy: 51.87%, Epoch best accuracy: 17, seed: 79
# Epoch 32/2000, Loss: 0.5894, Test Accuracy: 49.51%, Best accuracy: 51.87%, Epoch best accuracy: 17, seed: 79
# Epoch 33/2000, Loss: 0.5808, Test Accuracy: 50.30%, Best accuracy: 51.87%, Epoch best accuracy: 17, seed: 79
# Epoch 34/2000, Loss: 0.5784, Test Accuracy: 50.89%, Best accuracy: 51.87%, Epoch best accuracy: 17, seed: 79
# Epoch 35/2000, Loss: 0.5709, Test Accuracy: 52.66%, Best accuracy: 51.87%, Epoch best accuracy: 17, seed: 79
# ✅ Model saved with accuracy: 52.66%
# Epoch 36/2000, Loss: 0.5663, Test Accuracy: 50.10%, Best accuracy: 52.66%, Epoch best accuracy: 35, seed: 79
# Epoch 37/2000, Loss: 0.5592, Test Accuracy: 50.10%, Best accuracy: 52.66%, Epoch best accuracy: 35, seed: 79
# Epoch 38/2000, Loss: 0.5531, Test Accuracy: 50.30%, Best accuracy: 52.66%, Epoch best accuracy: 35, seed: 79
# Epoch 39/2000, Loss: 0.5407, Test Accuracy: 51.28%, Best accuracy: 52.66%, Epoch best accuracy: 35, seed: 79
# Epoch 40/2000, Loss: 0.5427, Test Accuracy: 53.65%, Best accuracy: 52.66%, Epoch best accuracy: 35, seed: 79
# ✅ Model saved with accuracy: 53.65%
# Epoch 41/2000, Loss: 0.5296, Test Accuracy: 52.07%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 42/2000, Loss: 0.5280, Test Accuracy: 51.48%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 43/2000, Loss: 0.5208, Test Accuracy: 53.45%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 44/2000, Loss: 0.5105, Test Accuracy: 53.25%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 45/2000, Loss: 0.5048, Test Accuracy: 52.27%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 46/2000, Loss: 0.4998, Test Accuracy: 51.28%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 47/2000, Loss: 0.4864, Test Accuracy: 50.89%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 48/2000, Loss: 0.4786, Test Accuracy: 51.68%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 49/2000, Loss: 0.4706, Test Accuracy: 52.47%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 50/2000, Loss: 0.4634, Test Accuracy: 52.47%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 51/2000, Loss: 0.4541, Test Accuracy: 50.49%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 52/2000, Loss: 0.4597, Test Accuracy: 50.10%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 53/2000, Loss: 0.4457, Test Accuracy: 51.28%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 54/2000, Loss: 0.4376, Test Accuracy: 51.68%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 55/2000, Loss: 0.4278, Test Accuracy: 51.68%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 56/2000, Loss: 0.4216, Test Accuracy: 51.08%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 57/2000, Loss: 0.4129, Test Accuracy: 50.30%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 58/2000, Loss: 0.4058, Test Accuracy: 51.28%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 59/2000, Loss: 0.4035, Test Accuracy: 51.28%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 60/2000, Loss: 0.3905, Test Accuracy: 52.07%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 61/2000, Loss: 0.3842, Test Accuracy: 50.30%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 62/2000, Loss: 0.3742, Test Accuracy: 52.47%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 63/2000, Loss: 0.3733, Test Accuracy: 50.30%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 64/2000, Loss: 0.3616, Test Accuracy: 51.87%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 65/2000, Loss: 0.3598, Test Accuracy: 51.28%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 66/2000, Loss: 0.3429, Test Accuracy: 51.28%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 67/2000, Loss: 0.3522, Test Accuracy: 52.27%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 68/2000, Loss: 0.3399, Test Accuracy: 53.25%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 69/2000, Loss: 0.3320, Test Accuracy: 52.66%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 70/2000, Loss: 0.3168, Test Accuracy: 51.68%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 71/2000, Loss: 0.3115, Test Accuracy: 52.07%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 72/2000, Loss: 0.3132, Test Accuracy: 52.27%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 73/2000, Loss: 0.3237, Test Accuracy: 52.07%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 74/2000, Loss: 0.3006, Test Accuracy: 51.48%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 75/2000, Loss: 0.3022, Test Accuracy: 51.28%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 76/2000, Loss: 0.2871, Test Accuracy: 52.47%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 77/2000, Loss: 0.2778, Test Accuracy: 51.28%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 78/2000, Loss: 0.2681, Test Accuracy: 51.48%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 79/2000, Loss: 0.2600, Test Accuracy: 50.30%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 80/2000, Loss: 0.2592, Test Accuracy: 52.66%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 81/2000, Loss: 0.2644, Test Accuracy: 52.07%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 82/2000, Loss: 0.2565, Test Accuracy: 50.10%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 83/2000, Loss: 0.2425, Test Accuracy: 50.89%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 84/2000, Loss: 0.2341, Test Accuracy: 51.48%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 85/2000, Loss: 0.2233, Test Accuracy: 51.48%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 86/2000, Loss: 0.2341, Test Accuracy: 49.90%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 87/2000, Loss: 0.2363, Test Accuracy: 49.70%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 88/2000, Loss: 0.2177, Test Accuracy: 51.48%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 89/2000, Loss: 0.2014, Test Accuracy: 51.08%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 90/2000, Loss: 0.1980, Test Accuracy: 50.30%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 91/2000, Loss: 0.2314, Test Accuracy: 50.30%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 92/2000, Loss: 0.2241, Test Accuracy: 50.49%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 93/2000, Loss: 0.2209, Test Accuracy: 50.30%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 94/2000, Loss: 0.1995, Test Accuracy: 50.69%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 95/2000, Loss: 0.2125, Test Accuracy: 52.66%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 96/2000, Loss: 0.2190, Test Accuracy: 50.49%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 97/2000, Loss: 0.1915, Test Accuracy: 50.89%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 98/2000, Loss: 0.1836, Test Accuracy: 50.89%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 99/2000, Loss: 0.1710, Test Accuracy: 51.87%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 100/2000, Loss: 0.1650, Test Accuracy: 52.47%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 101/2000, Loss: 0.1593, Test Accuracy: 51.48%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 102/2000, Loss: 0.1569, Test Accuracy: 51.08%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 103/2000, Loss: 0.1522, Test Accuracy: 50.89%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 104/2000, Loss: 0.1484, Test Accuracy: 50.89%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 105/2000, Loss: 0.1459, Test Accuracy: 50.89%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 106/2000, Loss: 0.1507, Test Accuracy: 51.48%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 107/2000, Loss: 0.1444, Test Accuracy: 51.87%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 108/2000, Loss: 0.1390, Test Accuracy: 52.27%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 109/2000, Loss: 0.1354, Test Accuracy: 51.48%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 110/2000, Loss: 0.1426, Test Accuracy: 52.27%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 111/2000, Loss: 0.1653, Test Accuracy: 51.48%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 112/2000, Loss: 0.1567, Test Accuracy: 52.27%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 113/2000, Loss: 0.1508, Test Accuracy: 52.07%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 114/2000, Loss: 0.1333, Test Accuracy: 51.87%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 115/2000, Loss: 0.1302, Test Accuracy: 50.69%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 116/2000, Loss: 0.1250, Test Accuracy: 52.07%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 117/2000, Loss: 0.1369, Test Accuracy: 51.28%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 118/2000, Loss: 0.1274, Test Accuracy: 51.87%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 119/2000, Loss: 0.1110, Test Accuracy: 51.48%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 120/2000, Loss: 0.1101, Test Accuracy: 52.07%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 121/2000, Loss: 0.1130, Test Accuracy: 52.07%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 122/2000, Loss: 0.1219, Test Accuracy: 49.51%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 123/2000, Loss: 0.1432, Test Accuracy: 49.70%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 124/2000, Loss: 0.1609, Test Accuracy: 51.68%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 125/2000, Loss: 0.1348, Test Accuracy: 49.70%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 126/2000, Loss: 0.1291, Test Accuracy: 51.08%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 127/2000, Loss: 0.1448, Test Accuracy: 50.69%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 128/2000, Loss: 0.1185, Test Accuracy: 49.90%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 129/2000, Loss: 0.1003, Test Accuracy: 49.70%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 130/2000, Loss: 0.0924, Test Accuracy: 50.30%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 131/2000, Loss: 0.0837, Test Accuracy: 50.10%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 132/2000, Loss: 0.0803, Test Accuracy: 51.87%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 133/2000, Loss: 0.0807, Test Accuracy: 51.08%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 134/2000, Loss: 0.0766, Test Accuracy: 51.28%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 135/2000, Loss: 0.0744, Test Accuracy: 50.10%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 136/2000, Loss: 0.0739, Test Accuracy: 51.48%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 137/2000, Loss: 0.0724, Test Accuracy: 51.87%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 138/2000, Loss: 0.0696, Test Accuracy: 52.47%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 139/2000, Loss: 0.0708, Test Accuracy: 51.48%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 140/2000, Loss: 0.0705, Test Accuracy: 52.07%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 141/2000, Loss: 0.0639, Test Accuracy: 51.48%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 142/2000, Loss: 0.0629, Test Accuracy: 52.47%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 143/2000, Loss: 0.0614, Test Accuracy: 51.87%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 144/2000, Loss: 0.0615, Test Accuracy: 51.68%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 145/2000, Loss: 0.1332, Test Accuracy: 52.07%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 146/2000, Loss: 0.1803, Test Accuracy: 49.51%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 147/2000, Loss: 0.2814, Test Accuracy: 48.32%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 148/2000, Loss: 0.2708, Test Accuracy: 50.69%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 149/2000, Loss: 0.1398, Test Accuracy: 50.30%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 150/2000, Loss: 0.0975, Test Accuracy: 49.51%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 151/2000, Loss: 0.0950, Test Accuracy: 51.08%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 152/2000, Loss: 0.1377, Test Accuracy: 51.48%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 153/2000, Loss: 0.0862, Test Accuracy: 51.68%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 154/2000, Loss: 0.1003, Test Accuracy: 51.28%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 155/2000, Loss: 0.0777, Test Accuracy: 50.49%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 156/2000, Loss: 0.0638, Test Accuracy: 50.89%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 157/2000, Loss: 0.0588, Test Accuracy: 50.49%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 158/2000, Loss: 0.0558, Test Accuracy: 50.69%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 159/2000, Loss: 0.0536, Test Accuracy: 49.90%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 160/2000, Loss: 0.0510, Test Accuracy: 51.68%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 161/2000, Loss: 0.0489, Test Accuracy: 51.08%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 162/2000, Loss: 0.0476, Test Accuracy: 50.69%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 163/2000, Loss: 0.0451, Test Accuracy: 51.28%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 164/2000, Loss: 0.0445, Test Accuracy: 51.28%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 165/2000, Loss: 0.0418, Test Accuracy: 51.28%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 166/2000, Loss: 0.0403, Test Accuracy: 51.48%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 167/2000, Loss: 0.0389, Test Accuracy: 51.28%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 168/2000, Loss: 0.0375, Test Accuracy: 51.48%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 169/2000, Loss: 0.0373, Test Accuracy: 51.08%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 170/2000, Loss: 0.0359, Test Accuracy: 51.87%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 171/2000, Loss: 0.0342, Test Accuracy: 51.68%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 172/2000, Loss: 0.0375, Test Accuracy: 51.68%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 173/2000, Loss: 0.1612, Test Accuracy: 51.08%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 174/2000, Loss: 0.1805, Test Accuracy: 51.28%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 175/2000, Loss: 0.2273, Test Accuracy: 49.51%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 176/2000, Loss: 0.1315, Test Accuracy: 50.49%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 177/2000, Loss: 0.1061, Test Accuracy: 49.90%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 178/2000, Loss: 0.0726, Test Accuracy: 49.31%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 179/2000, Loss: 0.0573, Test Accuracy: 50.10%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 180/2000, Loss: 0.0557, Test Accuracy: 50.10%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 181/2000, Loss: 0.0511, Test Accuracy: 49.51%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 182/2000, Loss: 0.0416, Test Accuracy: 50.49%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 183/2000, Loss: 0.0374, Test Accuracy: 50.89%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 184/2000, Loss: 0.0343, Test Accuracy: 50.49%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 185/2000, Loss: 0.0325, Test Accuracy: 50.69%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 186/2000, Loss: 0.0312, Test Accuracy: 50.30%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 187/2000, Loss: 0.0300, Test Accuracy: 50.49%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 188/2000, Loss: 0.0284, Test Accuracy: 50.69%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 189/2000, Loss: 0.0276, Test Accuracy: 50.49%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 190/2000, Loss: 0.0269, Test Accuracy: 50.89%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 191/2000, Loss: 0.0258, Test Accuracy: 49.90%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 192/2000, Loss: 0.0254, Test Accuracy: 50.89%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 193/2000, Loss: 0.0248, Test Accuracy: 51.08%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 194/2000, Loss: 0.0909, Test Accuracy: 48.72%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 195/2000, Loss: 0.2432, Test Accuracy: 48.72%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 196/2000, Loss: 0.2013, Test Accuracy: 51.28%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 197/2000, Loss: 0.0796, Test Accuracy: 51.48%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 198/2000, Loss: 0.0514, Test Accuracy: 51.28%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 199/2000, Loss: 0.0352, Test Accuracy: 49.90%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 200/2000, Loss: 0.0304, Test Accuracy: 50.10%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 201/2000, Loss: 0.0283, Test Accuracy: 49.51%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 202/2000, Loss: 0.0267, Test Accuracy: 50.10%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 203/2000, Loss: 0.0247, Test Accuracy: 49.31%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 204/2000, Loss: 0.0238, Test Accuracy: 50.10%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 205/2000, Loss: 0.0226, Test Accuracy: 49.90%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 206/2000, Loss: 0.0217, Test Accuracy: 49.90%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 207/2000, Loss: 0.0208, Test Accuracy: 50.10%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 208/2000, Loss: 0.0204, Test Accuracy: 49.90%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 209/2000, Loss: 0.0197, Test Accuracy: 50.30%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 210/2000, Loss: 0.0191, Test Accuracy: 50.89%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 211/2000, Loss: 0.0185, Test Accuracy: 50.89%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 212/2000, Loss: 0.0180, Test Accuracy: 50.30%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 213/2000, Loss: 0.0177, Test Accuracy: 50.49%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 214/2000, Loss: 0.0167, Test Accuracy: 50.69%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 215/2000, Loss: 0.0165, Test Accuracy: 50.10%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 216/2000, Loss: 0.0159, Test Accuracy: 50.30%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 217/2000, Loss: 0.0152, Test Accuracy: 49.90%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 218/2000, Loss: 0.0148, Test Accuracy: 49.90%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 219/2000, Loss: 0.0143, Test Accuracy: 49.31%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 220/2000, Loss: 0.0139, Test Accuracy: 49.31%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 221/2000, Loss: 0.0134, Test Accuracy: 49.70%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 222/2000, Loss: 0.2252, Test Accuracy: 51.28%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 223/2000, Loss: 0.3907, Test Accuracy: 48.92%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 224/2000, Loss: 0.1830, Test Accuracy: 49.31%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 225/2000, Loss: 0.1222, Test Accuracy: 49.70%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 226/2000, Loss: 0.0653, Test Accuracy: 51.28%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 227/2000, Loss: 0.0478, Test Accuracy: 50.10%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 228/2000, Loss: 0.1200, Test Accuracy: 48.92%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 229/2000, Loss: 0.0497, Test Accuracy: 48.32%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 230/2000, Loss: 0.0329, Test Accuracy: 49.31%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 231/2000, Loss: 0.0254, Test Accuracy: 48.72%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 232/2000, Loss: 0.0230, Test Accuracy: 49.11%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 233/2000, Loss: 0.0216, Test Accuracy: 49.31%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 234/2000, Loss: 0.0195, Test Accuracy: 49.11%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 235/2000, Loss: 0.0186, Test Accuracy: 48.92%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 236/2000, Loss: 0.0179, Test Accuracy: 48.92%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 237/2000, Loss: 0.0173, Test Accuracy: 49.31%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 238/2000, Loss: 0.0164, Test Accuracy: 49.90%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 239/2000, Loss: 0.0157, Test Accuracy: 49.51%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# Epoch 240/2000, Loss: 0.0152, Test Accuracy: 49.51%, Best accuracy: 53.65%, Epoch best accuracy: 40, seed: 79
# 🛑 Early stopping at epoch 240
#
# 🔹 Loading best model for final evaluation...
# 🏆 Final Test Accuracy: 53.65%

# %% [markdown]
# 🔹 Как использовать модель для предсказания?
# После загрузки модели можно предсказать направление следующей свечи:

# %%
# === Предсказание следующей свечи ===
# Загружаем модель
model.load_state_dict(torch.load("best_model_first_MIX_01.pth"))
model.eval()

# Берем последние 20 свечей из df_fut
last_sequence = torch.tensor(
    df_fut['CANDLE_INT'].iloc[-20:].values, dtype=torch.long
).unsqueeze(0).to(device)

print(last_sequence)

# Предсказание
with torch.no_grad():
    logit = model(last_sequence).item()  # Логит
    probability_up = torch.sigmoid(torch.tensor(logit)).item()  # Применяем сигмоиду
    probability_down = 1 - probability_up  # Вероятность падения

    direction = "📈 UP" if probability_up >= 0.5 else "📉 DOWN"

    print(f"Prediction: {direction}")
    print(
        f"UP Probability: {probability_up:.2%}, \n"
        f"DOWN Probability: {probability_down:.2%}"
    )
# Out:
# tensor([[12,  8, 12,  8, 17, 13,  8,  9,  6, 17, 17,  8, 10, 17,  8,  2,  5,  7,
#          10, 17]])
# Prediction: 📈 UP
# UP Probability: 56.57%,
# DOWN Probability: 43.43%

# %%
df_fut
# Out:
#        TRADEDATE      OPEN       LOW      HIGH     CLOSE  VOLUME CANDLE_CODE  \
# 0     2015-01-05  142000.0  138525.0  145950.0  145150.0    2587         112
# 1     2015-01-06  144750.0  144350.0  149900.0  149900.0    2953         100
# 2     2015-01-08  149500.0  148200.0  158200.0  156025.0    5567         111
# 3     2015-01-09  155575.0  150450.0  158100.0  154975.0    6100         022
# 4     2015-01-12  154750.0  151975.0  155500.0  152850.0    4574         011
# ...          ...       ...       ...       ...       ...     ...         ...
# 2548  2025-02-27  332100.0  324325.0  332100.0  328325.0  271316         002
# 2549  2025-02-28  328000.0  319875.0  328825.0  324900.0  243498         012
# 2550  2025-03-03  324775.0  316550.0  330300.0  319050.0  334920         021
# 2551  2025-03-04  318850.0  316700.0  331400.0  331050.0  246511         101
# 2552  2025-03-05  331000.0  328200.0  335200.0  331650.0  223266         122
#
#       CANDLE_INT
# 0             14
# 1              9
# 2             13
# 3              8
# 4              4
# ...          ...
# 2548           2
# 2549           5
# 2550           7
# 2551          10
# 2552          17
#
# [2553 rows x 8 columns]

# %%
# === ЗАГРУЗКА ОБУЧЕННОЙ МОДЕЛИ ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model_path = "best_model_first_MIX_01.pth"
model = CandleLSTM(
    vocab_size=len(unique_codes), embedding_dim=8, hidden_dim=32, output_dim=1
    ).to(device)
model.load_state_dict(torch.load(model_path, map_location=device))
model.eval()

# === ПРОГНОЗИРОВАНИЕ ===
predictions = []
with torch.no_grad():
    for i in range(len(df_fut) - window_size):
        sequence = torch.tensor(
            df_fut['CANDLE_INT'].iloc[i:i+window_size].values, dtype=torch.long
            ).unsqueeze(0).to(device)
        pred = model(sequence).item()
        predictions.append(1 if pred > 0.5 else 0)

# Заполняем колонку PREDICTION (первые window_size значений - NaN)
df_fut['PREDICTION'] = [None] * window_size + predictions

# === СОХРАНЕНИЕ РЕЗУЛЬТАТОВ ===
predictions_file = r"predictions_first_model_01.csv"
df_fut.to_csv(predictions_file, index=False)
print(f"✅ Прогнозы сохранены в '{predictions_file}'")

df_fut
# Out:
# ✅ Прогнозы сохранены в 'predictions_first_model_01.csv'
#        TRADEDATE      OPEN       LOW      HIGH     CLOSE  VOLUME CANDLE_CODE  \
# 0     2015-01-05  142000.0  138525.0  145950.0  145150.0    2587         112
# 1     2015-01-06  144750.0  144350.0  149900.0  149900.0    2953         100
# 2     2015-01-08  149500.0  148200.0  158200.0  156025.0    5567         111
# 3     2015-01-09  155575.0  150450.0  158100.0  154975.0    6100         022
# 4     2015-01-12  154750.0  151975.0  155500.0  152850.0    4574         011
# ...          ...       ...       ...       ...       ...     ...         ...
# 2548  2025-02-27  332100.0  324325.0  332100.0  328325.0  271316         002
# 2549  2025-02-28  328000.0  319875.0  328825.0  324900.0  243498         012
# 2550  2025-03-03  324775.0  316550.0  330300.0  319050.0  334920         021
# 2551  2025-03-04  318850.0  316700.0  331400.0  331050.0  246511         101
# 2552  2025-03-05  331000.0  328200.0  335200.0  331650.0  223266         122
#
#       CANDLE_INT  PREDICTION
# 0             14         NaN
# 1              9         NaN
# 2             13         NaN
# 3              8         NaN
# 4              4         NaN
# ...          ...         ...
# 2548           2         0.0
# 2549           5         1.0
# 2550           7         1.0
# 2551          10         1.0
# 2552          17         1.0
#
# [2553 rows x 9 columns]

# %% [markdown]
# # Глобальная проверка.
# 2025-02-18,338500.0,331675.0,342525.0,332250.0,386951,020,6,0.0
# 2025-02-19,332225.0,327850.0,335650.0,334500.0,216330,122,17,1.0
# 2025-02-20,334750.0,333625.0,339600.0,335375.0,179755,122,17,1.0
# 2025-02-21,335675.0,331325.0,337600.0,334225.0,164931,022,8,0.0

# %% [markdown]
# Есть код:
# ```Python
# db_path = Path(r'C:\Users\Alkor\gd\data_quote_db\MIX_futures_day.db')
#
# with sqlite3.connect(db_path) as conn:
#     df_fut = pd.read_sql_query(
#         "SELECT TRADEDATE, OPEN, LOW, HIGH, CLOSE, VOLUME FROM Day",
#         conn
#     )
# ```
# Как в дата фрейм выбрать все строки до даты 2025-02-18 в колонке TRADEDATE

# %%
# === Делаем предсказание на 2025-02-18 ===
# === Загрузка данных до 2025-02-18 ===
with sqlite3.connect(db_path) as conn:
    df_fut = pd.read_sql_query(
        """
        SELECT TRADEDATE, OPEN, LOW, HIGH, CLOSE, VOLUME 
        FROM Day 
        WHERE TRADEDATE < '2025-02-18'
        ORDER BY TRADEDATE
        """,
        conn
    )

# === Функция кодирования свечей ===
def encode_candle(row):
    open_, low, high, close = row['OPEN'], row['LOW'], row['HIGH'], row['CLOSE']
    direction = 1 if close > open_ else (0 if close < open_ else 2)
    upper_shadow = high - max(open_, close)
    lower_shadow = min(open_, close) - low
    body = abs(close - open_)
    
    def classify_shadow(shadow, body):
        return 0 if shadow < 0.1 * body else (1 if shadow < 0.5 * body else 2)

    return f"{direction}{classify_shadow(upper_shadow, body)}{classify_shadow(lower_shadow, body)}"

df_fut['CANDLE_CODE'] = df_fut.apply(encode_candle, axis=1)

# === Преобразование кодов в числа ===
unique_codes = sorted(df_fut['CANDLE_CODE'].unique())
code_to_int = {code: i for i, code in enumerate(unique_codes)}
df_fut['CANDLE_INT'] = df_fut['CANDLE_CODE'].map(code_to_int)

# === Предсказание следующей свечи ===
# Загружаем модель
model.load_state_dict(torch.load("best_model_first_MIX_01.pth"))
model.eval()

# Берем последние 20 свечей из df_fut
last_sequence = torch.tensor(
    df_fut['CANDLE_INT'].iloc[-20:].values, dtype=torch.long
).unsqueeze(0).to(device)

# Предсказание
with torch.no_grad():
    logit = model(last_sequence).item()  # Логит
    print(logit)
    probability_up = torch.sigmoid(torch.tensor(logit)).item()  # Применяем сигмоиду
    probability_down = 1 - probability_up  # Вероятность падения

    direction = "📈 UP" if probability_up >= 0.5 else "📉 DOWN"

    print(f"Prediction: {direction}")
    print(
        f"UP Probability: {probability_up:.2%}, \n"
        f"DOWN Probability: {probability_down:.2%}"
    )
# Out:
# -0.9402869939804077
# Prediction: 📉 DOWN
# UP Probability: 28.08%,
# DOWN Probability: 71.92%

# %% [markdown]
# Предсказание на 2025-02-18 на понижение, что `соответствует` и колонке предсказаний в csv файле в строке на 2025-02-18.

# %%
# === Делаем предсказание на 2025-02-19 ===
# === Загрузка данных до 2025-02-19 ===
with sqlite3.connect(db_path) as conn:
    df_fut = pd.read_sql_query(
        """
        SELECT TRADEDATE, OPEN, LOW, HIGH, CLOSE, VOLUME 
        FROM Day 
        WHERE TRADEDATE < '2025-02-19'
        ORDER BY TRADEDATE
        """,
        conn
    )

# === Функция кодирования свечей ===
def encode_candle(row):
    open_, low, high, close = row['OPEN'], row['LOW'], row['HIGH'], row['CLOSE']
    direction = 1 if close > open_ else (0 if close < open_ else 2)
    upper_shadow = high - max(open_, close)
    lower_shadow = min(open_, close) - low
    body = abs(close - open_)
    
    def classify_shadow(shadow, body):
        return 0 if shadow < 0.1 * body else (1 if shadow < 0.5 * body else 2)

    return f"{direction}{classify_shadow(upper_shadow, body)}{classify_shadow(lower_shadow, body)}"

df_fut['CANDLE_CODE'] = df_fut.apply(encode_candle, axis=1)

# === Преобразование кодов в числа ===
unique_codes = sorted(df_fut['CANDLE_CODE'].unique())
code_to_int = {code: i for i, code in enumerate(unique_codes)}
df_fut['CANDLE_INT'] = df_fut['CANDLE_CODE'].map(code_to_int)

# === Предсказание следующей свечи ===
# Загружаем модель
model.load_state_dict(torch.load("best_model_first_MIX_01.pth"))
model.eval()

# Берем последние 20 свечей из df_fut
last_sequence = torch.tensor(
    df_fut['CANDLE_INT'].iloc[-20:].values, dtype=torch.long
).unsqueeze(0).to(device)

# Предсказание
with torch.no_grad():
    logit = model(last_sequence).item()  # Логит
    print(logit)
    probability_up = torch.sigmoid(torch.tensor(logit)).item()  # Применяем сигмоиду
    probability_down = 1 - probability_up  # Вероятность падения

    direction = "📈 UP" if probability_up >= 0.5 else "📉 DOWN"

    print(f"Prediction: {direction}")
    print(
        f"UP Probability: {probability_up:.2%}, \n"
        f"DOWN Probability: {probability_down:.2%}"
    )
# Out:
# 0.691784143447876
# Prediction: 📈 UP
# UP Probability: 66.64%,
# DOWN Probability: 33.36%

# %% [markdown]
# Предсказание на 2025-02-19 на повышение, что `соответствует` и колонке предсказаний в csv файле в строке на 2025-02-19.

# %%
# === Делаем предсказание на 2025-02-20 ===
# === Загрузка данных до 2025-02-20 ===
with sqlite3.connect(db_path) as conn:
    df_fut = pd.read_sql_query(
        """
        SELECT TRADEDATE, OPEN, LOW, HIGH, CLOSE, VOLUME 
        FROM Day 
        WHERE TRADEDATE < '2025-02-20'
        ORDER BY TRADEDATE
        """,
        conn
    )

# === Функция кодирования свечей ===
def encode_candle(row):
    open_, low, high, close = row['OPEN'], row['LOW'], row['HIGH'], row['CLOSE']
    direction = 1 if close > open_ else (0 if close < open_ else 2)
    upper_shadow = high - max(open_, close)
    lower_shadow = min(open_, close) - low
    body = abs(close - open_)
    
    def classify_shadow(shadow, body):
        return 0 if shadow < 0.1 * body else (1 if shadow < 0.5 * body else 2)

    return f"{direction}{classify_shadow(upper_shadow, body)}{classify_shadow(lower_shadow, body)}"

df_fut['CANDLE_CODE'] = df_fut.apply(encode_candle, axis=1)

# === Преобразование кодов в числа ===
unique_codes = sorted(df_fut['CANDLE_CODE'].unique())
code_to_int = {code: i for i, code in enumerate(unique_codes)}
df_fut['CANDLE_INT'] = df_fut['CANDLE_CODE'].map(code_to_int)

# === Предсказание следующей свечи ===
# Загружаем модель
model.load_state_dict(torch.load("best_model_first_MIX_01.pth"))
model.eval()

# Берем последние 20 свечей из df_fut
last_sequence = torch.tensor(
    df_fut['CANDLE_INT'].iloc[-20:].values, dtype=torch.long
).unsqueeze(0).to(device)

# Предсказание
with torch.no_grad():
    logit = model(last_sequence).item()  # Логит
    print(logit)
    probability_up = torch.sigmoid(torch.tensor(logit)).item()  # Применяем сигмоиду
    probability_down = 1 - probability_up  # Вероятность падения

    direction = "📈 UP" if probability_up >= 0.5 else "📉 DOWN"

    print(f"Prediction: {direction}")
    print(
        f"UP Probability: {probability_up:.2%}, \n"
        f"DOWN Probability: {probability_down:.2%}"
    )
# Out:
# 1.18339204788208
# Prediction: 📈 UP
# UP Probability: 76.56%,
# DOWN Probability: 23.44%

# %% [markdown]
# Предсказание на 2025-02-20 на повышение, что `соответствует` и колонке предсказаний в csv файле в строке на 2025-02-20.

# %%
# === Делаем предсказание на 2025-02-21 ===
# === Загрузка данных до 2025-02-21 ===
with sqlite3.connect(db_path) as conn:
    df_fut = pd.read_sql_query(
        """
        SELECT TRADEDATE, OPEN, LOW, HIGH, CLOSE, VOLUME 
        FROM Day 
        WHERE TRADEDATE < '2025-02-21'
        ORDER BY TRADEDATE
        """,
        conn
    )

# === Функция кодирования свечей ===
def encode_candle(row):
    open_, low, high, close = row['OPEN'], row['LOW'], row['HIGH'], row['CLOSE']
    direction = 1 if close > open_ else (0 if close < open_ else 2)
    upper_shadow = high - max(open_, close)
    lower_shadow = min(open_, close) - low
    body = abs(close - open_)
    
    def classify_shadow(shadow, body):
        return 0 if shadow < 0.1 * body else (1 if shadow < 0.5 * body else 2)

    return f"{direction}{classify_shadow(upper_shadow, body)}{classify_shadow(lower_shadow, body)}"

df_fut['CANDLE_CODE'] = df_fut.apply(encode_candle, axis=1)

# === Преобразование кодов в числа ===
unique_codes = sorted(df_fut['CANDLE_CODE'].unique())
code_to_int = {code: i for i, code in enumerate(unique_codes)}
df_fut['CANDLE_INT'] = df_fut['CANDLE_CODE'].map(code_to_int)

# === Предсказание следующей свечи ===
# Загружаем модель
model.load_state_dict(torch.load("best_model_first_MIX_01.pth"))
model.eval()

# Берем последние 20 свечей из df_fut
last_sequence = torch.tensor(
    df_fut['CANDLE_INT'].iloc[-20:].values, dtype=torch.long
).unsqueeze(0).to(device)

# Предсказание
with torch.no_grad():
    logit = model(last_sequence).item()  # Логит
    print(logit)
    probability_up = torch.sigmoid(torch.tensor(logit)).item()  # Применяем сигмоиду
    probability_down = 1 - probability_up  # Вероятность падения

    direction = "📈 UP" if probability_up >= 0.5 else "📉 DOWN"

    print(f"Prediction: {direction}")
    print(
        f"UP Probability: {probability_up:.2%}, \n"
        f"DOWN Probability: {probability_down:.2%}"
    )
# Out:
# 0.4870644509792328
# Prediction: 📈 UP
# UP Probability: 61.94%,
# DOWN Probability: 38.06%

# %% [markdown]
# Предсказание на 2025-02-21 на повышение, что `не соответствует` колонке предсказаний в csv файле в строке на 2025-02-21. Там значение 0.0.

# %%
# === Делаем предсказание на 2025-02-22(24) ===
# === Загрузка данных до 2025-02-22 ===
with sqlite3.connect(db_path) as conn:
    df_fut = pd.read_sql_query(
        """
        SELECT TRADEDATE, OPEN, LOW, HIGH, CLOSE, VOLUME 
        FROM Day 
        WHERE TRADEDATE < '2025-02-22'
        ORDER BY TRADEDATE
        """,
        conn
    )

# === Функция кодирования свечей ===
def encode_candle(row):
    open_, low, high, close = row['OPEN'], row['LOW'], row['HIGH'], row['CLOSE']
    direction = 1 if close > open_ else (0 if close < open_ else 2)
    upper_shadow = high - max(open_, close)
    lower_shadow = min(open_, close) - low
    body = abs(close - open_)
    
    def classify_shadow(shadow, body):
        return 0 if shadow < 0.1 * body else (1 if shadow < 0.5 * body else 2)

    return f"{direction}{classify_shadow(upper_shadow, body)}{classify_shadow(lower_shadow, body)}"

df_fut['CANDLE_CODE'] = df_fut.apply(encode_candle, axis=1)

# === Преобразование кодов в числа ===
unique_codes = sorted(df_fut['CANDLE_CODE'].unique())
code_to_int = {code: i for i, code in enumerate(unique_codes)}
df_fut['CANDLE_INT'] = df_fut['CANDLE_CODE'].map(code_to_int)

# === Предсказание следующей свечи ===
# Загружаем модель
model.load_state_dict(torch.load("best_model_first_MIX_01.pth"))
model.eval()

# Берем последние 20 свечей из df_fut
last_sequence = torch.tensor(
    df_fut['CANDLE_INT'].iloc[-20:].values, dtype=torch.long
).unsqueeze(0).to(device)

# Предсказание
with torch.no_grad():
    logit = model(last_sequence).item()  # Логит
    print(logit)
    probability_up = torch.sigmoid(torch.tensor(logit)).item()  # Применяем сигмоиду
    probability_down = 1 - probability_up  # Вероятность падения

    direction = "📈 UP" if probability_up >= 0.5 else "📉 DOWN"

    print(f"Prediction: {direction}")
    print(
        f"UP Probability: {probability_up:.2%}, \n"
        f"DOWN Probability: {probability_down:.2%}"
    )
# Out:
# 0.305134654045105
# Prediction: 📈 UP
# UP Probability: 57.57%,
# DOWN Probability: 42.43%
