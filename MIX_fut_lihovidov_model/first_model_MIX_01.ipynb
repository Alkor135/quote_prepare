# %% [markdown]
# # Кодировка свечей по методу Лиховидова, прогноз Up или Down.

# %% [markdown]
# Обучение модели на основе кода свечи Лиховидова.
# Бинарная классификация Up или Down.
# Основной гиперпараметр seed. Подбирается по графикам.
# Вот обновленный код с использованием взвешивания классов в функции потерь (BCEWithLogitsLoss с pos_weight). Я добавил вычисление pos_weight на основе количества классов и передал его в функцию потерь.

# %%
import sqlite3
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
import random
from pathlib import Path
from torch.utils.data import Dataset, DataLoader

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_var = 79
set_seed(seed_var)

db_path = Path(r'C:\Users\Alkor\gd\data_quote_db\MIX_futures_day.db')

with sqlite3.connect(db_path) as conn:
    df_fut = pd.read_sql_query(
        "SELECT TRADEDATE, OPEN, LOW, HIGH, CLOSE, VOLUME FROM Day",
        conn
    )

def encode_candle(row):
    open_, low, high, close = row['OPEN'], row['LOW'], row['HIGH'], row['CLOSE']
    direction = 1 if close > open_ else (0 if close < open_ else 2)
    upper_shadow = high - max(open_, close)
    lower_shadow = min(open_, close) - low
    body = abs(close - open_)
    
    def classify_shadow(shadow, body):
        return 0 if shadow < 0.1 * body else (1 if shadow < 0.5 * body else 2)

    return f"{direction}{classify_shadow(upper_shadow, body)}{classify_shadow(lower_shadow, body)}"

df_fut['CANDLE_CODE'] = df_fut.apply(encode_candle, axis=1)

unique_codes = sorted(df_fut['CANDLE_CODE'].unique())
code_to_int = {code: i for i, code in enumerate(unique_codes)}
df_fut['CANDLE_INT'] = df_fut['CANDLE_CODE'].map(code_to_int)

window_size = 20  
predict_offset = 1  

X, y = [], []
for i in range(len(df_fut) - window_size - predict_offset):
    X.append(df_fut['CANDLE_INT'].iloc[i:i+window_size].values)
    y.append(
        1 if df_fut['CLOSE'].iloc[i+window_size+predict_offset] > 
        df_fut['CLOSE'].iloc[i+window_size] else 0
    )

X, y = np.array(X), np.array(y)

split = int(0.8 * len(X))
X_train, y_train = X[:split], y[:split]
X_test, y_test = X[split:], y[split:]

class_counts = np.bincount(y_train)
pos_weight = torch.tensor([class_counts[0] / class_counts[1]], dtype=torch.float32)

class CandlestickDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.long)
        self.y = torch.tensor(y, dtype=torch.float32)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

def seed_worker(worker_id):
    np.random.seed(42 + worker_id)
    random.seed(42 + worker_id)

train_dataset = CandlestickDataset(X_train, y_train)
test_dataset = CandlestickDataset(X_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, worker_init_fn=seed_worker)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, worker_init_fn=seed_worker)

class CandleLSTM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim):
        super(CandleLSTM, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.lstm(x)
        x = self.fc(x[:, -1, :])  
        return x  # Без sigmoid, так как используем BCEWithLogitsLoss

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = CandleLSTM(
    vocab_size=len(unique_codes), embedding_dim=8, hidden_dim=32, output_dim=1
).to(device)

criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight.to(device))
optimizer = optim.Adam(model.parameters(), lr=0.001)

best_accuracy = 0  
epoch_best_accuracy = 0
model_path = "best_model_first_MIX.pth"
early_stop_epochs = 200
epochs_no_improve = 0

epochs = 2000
for epoch in range(epochs):
    model.train()
    total_loss = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()
        y_pred = model(X_batch).squeeze()
        loss = criterion(y_pred, y_batch)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_pred = torch.sigmoid(model(X_batch).squeeze()).round()
            correct += (y_pred == y_batch).sum().item()
            total += y_batch.size(0)

    accuracy = correct / total
    print(
        f"Epoch {epoch+1}/{epochs}, "
        f"Loss: {total_loss/len(train_loader):.4f}, "
        f"Test Accuracy: {accuracy:.2%}, "
        f"Best accuracy: {best_accuracy:.2%}, "
        f"Epoch best accuracy: {epoch_best_accuracy}, "
        f"seed: {seed_var}"
    )

    if accuracy > best_accuracy:
        best_accuracy = accuracy
        epochs_no_improve = 0
        epoch_best_accuracy = epoch + 1
        torch.save(model.state_dict(), model_path)
        print(f"✅ Model saved with accuracy: {best_accuracy:.2%}")
    else:
        epochs_no_improve += 1

    if epochs_no_improve >= early_stop_epochs:
        print(f"🛑 Early stopping at epoch {epoch + 1}")
        break

print("\n🔹 Loading best model for final evaluation...")
model.load_state_dict(torch.load(model_path))
model.eval()

correct = 0
total = 0
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        y_pred = torch.sigmoid(model(X_batch).squeeze()).round()
        correct += (y_pred == y_batch).sum().item()
        total += y_batch.size(0)

final_accuracy = correct / total
print(f"🏆 Final Test Accuracy: {final_accuracy:.2%}")
# Out:
# Epoch 1/2000, Loss: 0.6734, Test Accuracy: 44.58%, Best accuracy: 0.00%, Epoch best accuracy: 0, seed: 79
# ✅ Model saved with accuracy: 44.58%
# Epoch 2/2000, Loss: 0.6732, Test Accuracy: 46.15%, Best accuracy: 44.58%, Epoch best accuracy: 1, seed: 79
# ✅ Model saved with accuracy: 46.15%
# Epoch 3/2000, Loss: 0.6722, Test Accuracy: 47.34%, Best accuracy: 46.15%, Epoch best accuracy: 2, seed: 79
# ✅ Model saved with accuracy: 47.34%
# Epoch 4/2000, Loss: 0.6719, Test Accuracy: 47.73%, Best accuracy: 47.34%, Epoch best accuracy: 3, seed: 79
# ✅ Model saved with accuracy: 47.73%
# Epoch 5/2000, Loss: 0.6715, Test Accuracy: 48.92%, Best accuracy: 47.73%, Epoch best accuracy: 4, seed: 79
# ✅ Model saved with accuracy: 48.92%
# Epoch 6/2000, Loss: 0.6706, Test Accuracy: 47.34%, Best accuracy: 48.92%, Epoch best accuracy: 5, seed: 79
# Epoch 7/2000, Loss: 0.6702, Test Accuracy: 48.92%, Best accuracy: 48.92%, Epoch best accuracy: 5, seed: 79
# Epoch 8/2000, Loss: 0.6696, Test Accuracy: 48.13%, Best accuracy: 48.92%, Epoch best accuracy: 5, seed: 79
# Epoch 9/2000, Loss: 0.6680, Test Accuracy: 48.32%, Best accuracy: 48.92%, Epoch best accuracy: 5, seed: 79
# Epoch 10/2000, Loss: 0.6666, Test Accuracy: 48.72%, Best accuracy: 48.92%, Epoch best accuracy: 5, seed: 79
# Epoch 11/2000, Loss: 0.6662, Test Accuracy: 48.52%, Best accuracy: 48.92%, Epoch best accuracy: 5, seed: 79
# Epoch 12/2000, Loss: 0.6650, Test Accuracy: 50.10%, Best accuracy: 48.92%, Epoch best accuracy: 5, seed: 79
# ✅ Model saved with accuracy: 50.10%
# Epoch 13/2000, Loss: 0.6638, Test Accuracy: 49.51%, Best accuracy: 50.10%, Epoch best accuracy: 12, seed: 79
# Epoch 14/2000, Loss: 0.6626, Test Accuracy: 50.49%, Best accuracy: 50.10%, Epoch best accuracy: 12, seed: 79
# ✅ Model saved with accuracy: 50.49%
# Epoch 15/2000, Loss: 0.6596, Test Accuracy: 49.70%, Best accuracy: 50.49%, Epoch best accuracy: 14, seed: 79
# Epoch 16/2000, Loss: 0.6575, Test Accuracy: 51.08%, Best accuracy: 50.49%, Epoch best accuracy: 14, seed: 79
# ✅ Model saved with accuracy: 51.08%
# Epoch 17/2000, Loss: 0.6546, Test Accuracy: 51.87%, Best accuracy: 51.08%, Epoch best accuracy: 16, seed: 79
# ✅ Model saved with accuracy: 51.87%
# Epoch 18/2000, Loss: 0.6524, Test Accuracy: 51.48%, Best accuracy: 51.87%, Epoch best accuracy: 17, seed: 79
# Epoch
Test Accuracy: 48.72%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 272/2000, Loss: 0.0088, Test Accuracy: 47.73%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 273/2000, Loss: 0.0087, Test Accuracy: 48.32%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 274/2000, Loss: 0.0082, Test Accuracy: 47.93%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 275/2000, Loss: 0.0080, Test Accuracy: 48.92%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 276/2000, Loss: 0.0077, Test Accuracy: 49.11%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 277/2000, Loss: 0.0074, Test Accuracy: 48.72%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 278/2000, Loss: 0.0071, Test Accuracy: 49.11%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 279/2000, Loss: 0.0070, Test Accuracy: 48.92%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 280/2000, Loss: 0.0067, Test Accuracy: 48.52%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 281/2000, Loss: 0.0065, Test Accuracy: 48.52%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 282/2000, Loss: 0.0063, Test Accuracy: 48.92%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 283/2000, Loss: 0.0061, Test Accuracy: 48.32%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 284/2000, Loss: 0.0059, Test Accuracy: 48.72%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 285/2000, Loss: 0.0058, Test Accuracy: 47.93%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 286/2000, Loss: 0.0056, Test Accuracy: 48.92%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 287/2000, Loss: 0.0055, Test Accuracy: 48.52%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 288/2000, Loss: 0.0052, Test Accuracy: 48.52%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 289/2000, Loss: 0.0051, Test Accuracy: 48.92%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 290/2000, Loss: 0.0049, Test Accuracy: 48.72%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 291/2000, Loss: 0.0048, Test Accuracy: 48.72%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 292/2000, Loss: 0.0047, Test Accuracy: 48.92%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 293/2000, Loss: 0.0045, Test Accuracy: 48.92%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 294/2000, Loss: 0.0044, Test Accuracy: 49.11%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 295/2000, Loss: 0.0043, Test Accuracy: 48.92%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 296/2000, Loss: 0.0042, Test Accuracy: 49.11%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 297/2000, Loss: 0.0041, Test Accuracy: 49.31%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 298/2000, Loss: 0.0039, Test Accuracy: 49.31%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 299/2000, Loss: 0.0038, Test Accuracy: 48.72%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 300/2000, Loss: 0.0036, Test Accuracy: 48.72%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 301/2000, Loss: 0.0036, Test Accuracy: 48.52%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 302/2000, Loss: 0.3625, Test Accuracy: 48.92%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 303/2000, Loss: 0.7539, Test Accuracy: 49.70%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 304/2000, Loss: 0.3195, Test Accuracy: 49.90%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 305/2000, Loss: 0.2047, Test Accuracy: 47.53%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 306/2000, Loss: 0.1041, Test Accuracy: 48.52%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 307/2000, Loss: 0.0567, Test Accuracy: 50.10%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 308/2000, Loss: 0.0512, Test Accuracy: 49.90%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 309/2000, Loss: 0.0345, Test Accuracy: 49.70%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 310/2000, Loss: 0.0259, Test Accuracy: 50.89%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 311/2000, Loss: 0.0207, Test Accuracy: 50.89%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 312/2000, Loss: 0.0183, Test Accuracy: 50.49%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 313/2000, Loss: 0.0165, Test Accuracy: 50.49%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 314/2000, Loss: 0.0148, Test Accuracy: 51.08%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 315/2000, Loss: 0.0138, Test Accuracy: 51.28%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# Epoch 316/2000, Loss: 0.0126, Test Accuracy: 50.89%, Best accuracy: 53.85%, Epoch best accuracy: 116, seed: 79
# 🛑 Early stopping at epoch 316
#
# 🔹 Loading best model for final evaluation...
# 🏆 Final Test Accuracy: 53.85%

# %% [markdown]
# 🔹 Как использовать модель для предсказания?
# После загрузки модели можно предсказать направление следующей свечи:

# %%
# Загружаем модель
model.load_state_dict(torch.load("best_model_first_MIX.pth"))
model.eval()

# Берем последние 20 свечей из df_fut
last_sequence = torch.tensor(
    df_fut['CANDLE_INT'].iloc[-20:].values, dtype=torch.long
).unsqueeze(0).to(device)

# Предсказание
with torch.no_grad():
    logit = model(last_sequence).item()  # Логит
    probability_up = torch.sigmoid(torch.tensor(logit)).item()  # Применяем сигмоиду
    probability_down = 1 - probability_up  # Вероятность падения

    direction = "📈 UP" if probability_up >= 0.5 else "📉 DOWN"

    print(f"Prediction: {direction}")
    print(
        f"UP Probability: {probability_up:.2%}, \n"
        f"DOWN Probability: {probability_down:.2%}"
    )
# Out:
# Prediction: 📈 UP
# UP Probability: 93.88%,
# DOWN Probability: 6.12%
