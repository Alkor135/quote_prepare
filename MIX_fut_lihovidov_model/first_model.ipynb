# %% [markdown]
# # Кодировка свечей по методу Лиховидова, прогноз Up или Down.

# %% [markdown]
# Обучение модели на основе кода свечи Лиховидова.
# Бинарная классификация Up или Down.
# Основной гиперпараметр seed. Подбирается по графикам.

# %%
import sqlite3
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
import random
from pathlib import Path
from torch.utils.data import Dataset, DataLoader

# %%
# === 1. ФИКСАЦИЯ СЛУЧАЙНЫХ ЧИСЕЛ ДЛЯ ДЕТЕРМИНИРОВАННОСТИ ===
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# [64, 97], 2, 5, 16, 22, 32, 34, 51, 64, 75, 89, 97
seed_var = 64
set_seed(seed_var)  # Устанавливаем одинаковый seed

# === 2. ЗАГРУЗКА ДАННЫХ ===
# db_path = Path(r'C:\Users\Alkor\gd\data_quote_db\RTS_futures_options_day.db')

# with sqlite3.connect(db_path) as conn:
#     df_fut = pd.read_sql_query(
#         "SELECT TRADEDATE, OPEN, LOW, HIGH, CLOSE, VOLUME FROM Futures",
#         conn
#     )

db_path = Path(r'C:\Users\Alkor\gd\data_quote_db\MIX_futures_day.db')

with sqlite3.connect(db_path) as conn:
    df_fut = pd.read_sql_query(
        "SELECT TRADEDATE, OPEN, LOW, HIGH, CLOSE, VOLUME FROM Day",
        conn
    )

"""
Строка ниже.
Фиксация порядка данных (если используем перемешивание). В данном случае не используется т.к. 
для создания фичей используются данные предыдущих свечей.
"""
# df_fut = df_fut.sample(frac=1, random_state=42).reset_index(drop=True)

# === 3. ФУНКЦИЯ КОДИРОВАНИЯ СВЕЧЕЙ (ЛИХОВИДОВ) ===
def encode_candle(row):
    open_, low, high, close = row['OPEN'], row['LOW'], row['HIGH'], row['CLOSE']

    direction = 1 if close > open_ else (0 if close < open_ else 2)
    upper_shadow = high - max(open_, close)
    lower_shadow = min(open_, close) - low
    body = abs(close - open_)

    def classify_shadow(shadow, body):
        return 0 if shadow < 0.1 * body else (1 if shadow < 0.5 * body else 2)

    return f"{direction}{classify_shadow(upper_shadow, body)}{classify_shadow(lower_shadow, body)}"

df_fut['CANDLE_CODE'] = df_fut.apply(encode_candle, axis=1)

# === 4. ПОДГОТОВКА ДАННЫХ ===
unique_codes = sorted(df_fut['CANDLE_CODE'].unique())
code_to_int = {code: i for i, code in enumerate(unique_codes)}
df_fut['CANDLE_INT'] = df_fut['CANDLE_CODE'].map(code_to_int)

window_size = 20  
predict_offset = 1  

X, y = [], []
for i in range(len(df_fut) - window_size - predict_offset):
    X.append(df_fut['CANDLE_INT'].iloc[i:i+window_size].values)
    y.append(
        1 if df_fut['CLOSE'].iloc[i+window_size+predict_offset] > 
        df_fut['CLOSE'].iloc[i+window_size] else 0
    )

X, y = np.array(X), np.array(y)

split = int(0.8 * len(X))
X_train, y_train = X[:split], y[:split]
X_test, y_test = X[split:], y[split:]

class CandlestickDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.long)
        self.y = torch.tensor(y, dtype=torch.float32)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

def seed_worker(worker_id):
    np.random.seed(42 + worker_id)
    random.seed(42 + worker_id)

train_dataset = CandlestickDataset(X_train, y_train)
test_dataset = CandlestickDataset(X_test, y_test)
# print(X_train)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, worker_init_fn=seed_worker)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, worker_init_fn=seed_worker)

# === 5. СОЗДАНИЕ НЕЙРОСЕТИ (LSTM) ===
class CandleLSTM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim):
        super(CandleLSTM, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.lstm(x)
        x = self.fc(x[:, -1, :])  
        return self.sigmoid(x)

# === 6. ОБУЧЕНИЕ МОДЕЛИ С СОХРАНЕНИЕМ ЛУЧШЕЙ ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = CandleLSTM(
    vocab_size=len(unique_codes), embedding_dim=8, hidden_dim=32, output_dim=1
).to(device)
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

best_accuracy = 0  
epoch_best_accuracy = 0
model_path = "best_model_first.pth"
early_stop_epochs = 200  # Для ранней остановки
epochs_no_improve = 0

epochs = 2000
for epoch in range(epochs):
    model.train()
    total_loss = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()
        y_pred = model(X_batch).squeeze()
        loss = criterion(y_pred, y_batch)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    # === Проверка на тесте после каждой эпохи ===
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_pred = model(X_batch).squeeze().round()
            correct += (y_pred == y_batch).sum().item()
            total += y_batch.size(0)

    accuracy = correct / total
    print(
        f"Epoch {epoch+1}/{epochs}, "
        f"Loss: {total_loss/len(train_loader):.4f}, "
        f"Test Accuracy: {accuracy:.2%}, "
        f"Best accuracy: {best_accuracy:.2%}, "
        f"Epoch best accuracy: {epoch_best_accuracy}, "
        f"seed: {seed_var}"
    )

    # === Сохранение лучшей модели ===
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        epochs_no_improve = 0
        epoch_best_accuracy = epoch + 1
        torch.save(model.state_dict(), model_path)
        print(f"✅ Model saved with accuracy: {best_accuracy:.2%}")
    else:
        epochs_no_improve += 1

    # === Ранняя остановка ===
    if epochs_no_improve >= early_stop_epochs:
        print(f"🛑 Early stopping at epoch {epoch + 1}")
        break

# === 7. ЗАГРУЗКА ЛУЧШЕЙ МОДЕЛИ И ТЕСТ ===
print("\n🔹 Loading best model for final evaluation...")
model.load_state_dict(torch.load(model_path))
model.eval()

correct = 0
total = 0
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        y_pred = model(X_batch).squeeze().round()
        correct += (y_pred == y_batch).sum().item()
        total += y_batch.size(0)

final_accuracy = correct / total
print(f"🏆 Final Test Accuracy: {final_accuracy:.2%}")

# # === 8. СОХРАНЕНИЕ ВЕРСИЙ БИБЛИОТЕК ===
# print("\n🔹 Library versions:")
# print(f"PyTorch: {torch.__version__}")
# print(f"NumPy: {np.__version__}")
# print(f"Pandas: {pd.__version__}")
# Out:
# Epoch 1/2000, Loss: 0.6929, Test Accuracy: 50.49%, Best accuracy: 0.00%, Epoch best accuracy: 0, seed: 64
# ✅ Model saved with accuracy: 50.49%
# Epoch 2/2000, Loss: 0.6923, Test Accuracy: 50.49%, Best accuracy: 50.49%, Epoch best accuracy: 1, seed: 64
# Epoch 3/2000, Loss: 0.6912, Test Accuracy: 50.49%, Best accuracy: 50.49%, Epoch best accuracy: 1, seed: 64
# Epoch 4/2000, Loss: 0.6908, Test Accuracy: 50.10%, Best accuracy: 50.49%, Epoch best accuracy: 1, seed: 64
# Epoch 5/2000, Loss: 0.6905, Test Accuracy: 50.69%, Best accuracy: 50.49%, Epoch best accuracy: 1, seed: 64
# ✅ Model saved with accuracy: 50.69%
# Epoch 6/2000, Loss: 0.6896, Test Accuracy: 50.69%, Best accuracy: 50.69%, Epoch best accuracy: 5, seed: 64
# Epoch 7/2000, Loss: 0.6897, Test Accuracy: 50.69%, Best accuracy: 50.69%, Epoch best accuracy: 5, seed: 64
# Epoch 8/2000, Loss: 0.6883, Test Accuracy: 51.87%, Best accuracy: 50.69%, Epoch best accuracy: 5, seed: 64
# ✅ Model saved with accuracy: 51.87%
# Epoch 9/2000, Loss: 0.6865, Test Accuracy: 52.07%, Best accuracy: 51.87%, Epoch best accuracy: 8, seed: 64
# ✅ Model saved with accuracy: 52.07%
# Epoch 10/2000, Loss: 0.6862, Test Accuracy: 50.49%, Best accuracy: 52.07%, Epoch best accuracy: 9, seed: 64
# Epoch 11/2000, Loss: 0.6835, Test Accuracy: 51.48%, Best accuracy: 52.07%, Epoch best accuracy: 9, seed: 64
# Epoch 12/2000, Loss: 0.6830, Test Accuracy: 52.66%, Best accuracy: 52.07%, Epoch best accuracy: 9, seed: 64
# ✅ Model saved with accuracy: 52.66%
# Epoch 13/2000, Loss: 0.6809, Test Accuracy: 51.68%, Best accuracy: 52.66%, Epoch best accuracy: 12, seed: 64
# Epoch 14/2000, Loss: 0.6775, Test Accuracy: 50.69%, Best accuracy: 52.66%, Epoch best accuracy: 12, seed: 64
# Epoch 15/2000, Loss: 0.6763, Test Accuracy: 50.69%, Best accuracy: 52.66%, Epoch best accuracy: 12, seed: 64
# Epoch 16/2000, Loss: 0.6719, Test Accuracy: 52.27%, Best accuracy: 52.66%, Epoch best accuracy: 12, seed: 64
# Epoch 17/2000, Loss: 0.6705, Test Accuracy: 51.08%, Best accuracy: 52.66%, Epoch best accuracy: 12, seed: 64
# Epoch 18/2000, Loss: 0.6646, Test Accuracy: 51.28%, Best accuracy: 52.66%, Epoch best accuracy: 12, seed: 64
# Epoch 19/2000, Loss: 0.6626, Test Accuracy: 51.68%, Best accuracy: 52.66%, Epoch best accuracy: 12, seed: 64
# Epoch 20/2000, Loss: 0.6582, Test Accuracy: 53.25%, Best accuracy: 52.66%, Epoch best accuracy: 12, seed: 64
# ✅ Model saved with accuracy: 53.25%
# Epoch 21/2000, Loss: 0.6533, Test Accuracy: 52.86%, Best accuracy: 53.25%, Epoch best accuracy: 20, seed: 64
# Epoch 22/2000, Loss: 0.6479, Test Accuracy: 52.86%, Best accuracy: 53.25%, Epoch best accuracy: 20, seed: 64
# Epoch 23/2000, Loss: 0.6446, Test Accuracy: 54.83%, Best accuracy: 53.25%, Epoch best accuracy: 20, seed: 64
# ✅ Model saved with accuracy: 54.83%
# Epoch 24/2000, Loss: 0.6413, Test Accuracy: 54.04%, Best accuracy: 54.83%, Epoch best accuracy: 23, seed: 64
# Epoch 25/2000, Loss: 0.6318, Test Accuracy: 54.83%, Best accuracy: 54.83%, Epoch best accuracy: 23, seed: 64
# Epoch 26/2000, Loss: 0.6330, Test Accuracy: 54.83%, Best accuracy: 54.83%, Epoch best accuracy: 23, seed: 64
# Epoch 27/2000, Loss: 0.6237, Test Accuracy: 53.45%, Best accuracy: 54.83%, Epoch best accuracy: 23, seed: 64
# Epoch 28/2000, Loss: 0.6196, Test Accuracy: 53.25%, Best accuracy: 54.83%, Epoch best accuracy: 23, seed: 64
# Epoch 29/2000, Loss: 0.6106, Test Accuracy: 53.65%, Best accuracy: 54.83%, Epoch best accuracy: 23, seed: 64
# Epoch 30/2000, Loss: 0.6064, Test Accuracy: 53.65%, Best accuracy: 54.83%, Epoch best accuracy: 23, seed: 64
# Epoch 31/2000, Loss: 0.6017, Test Accuracy: 52.47%, Best accuracy: 54.83%, Epoch best accuracy: 23, seed: 64
# Epoch 32/2000, Loss: 0.5976, Test Accuracy: 54.83%, Best accuracy: 54.83%, Epoch best accuracy: 23, seed: 64
# Epoch 33/2000, Loss: 0.5946, Test Accuracy: 54.24%, Best accuracy: 54.83%, Epoch best accuracy: 23, seed: 64
# Epoch 34/2000, Loss: 0.5854, Test Accuracy: 55.03%, Best accuracy: 54.83%, Epoch best accuracy: 23, seed: 64
# ✅ Model saved with accuracy: 55.03%
# Epoch 35/2000, Loss: 0.5808, Test Accuracy: 52.27%, Best accuracy: 55.03%, Epoch best accuracy: 34, seed: 64
# Epoch 36/2000, Loss: 0.5766, Test Accuracy: 54.24%, Best accuracy: 55.03%, Epoch best accuracy: 34, seed: 64
# Epoch 37/2000, Loss: 0.5677, Test Accuracy: 55.62%, Best accuracy: 55.03%, Epoch best accuracy: 34, seed: 64
# ✅ Model saved with accuracy: 55.62%
# Epoch 38/2000, Loss: 0.5622, Test Accuracy: 54.83%, Best accuracy: 55.62%, Epoch best accuracy: 37, seed: 64
# Epoch 39/2000, Loss: 0.5641, Test Accuracy: 53.65%, Best accuracy: 55.62%, Epoch best accuracy: 37, seed: 64
# Epoch 40/2000, Loss: 0.5541, Test Accuracy: 52.86%, Best accuracy: 55.62%, Epoch best accuracy: 37, seed: 64
# Epoch 41/2000, Loss: 0.5440, Test Accuracy: 54.04%, Best accuracy: 55.62%, Epoch best accuracy: 37, seed: 64
# Epoch 42/2000, Loss: 0.5432, Test Accuracy: 55.03%, Best accuracy: 55.62%, Epoch best accuracy: 37, seed: 64
# Epoch 43/2000, Loss: 0.5344, Test Accuracy: 56.02%, Best accuracy: 55.62%, Epoch best accuracy: 37, seed: 64
# ✅ Model saved with accuracy: 56.02%
# Epoch 44/2000, Loss: 0.5337, Test Accuracy: 53.45%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 45/2000, Loss: 0.5173, Test Accuracy: 54.64%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 46/2000, Loss: 0.5153, Test Accuracy: 53.45%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 47/2000, Loss: 0.5047, Test Accuracy: 53.45%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 48/2000, Loss: 0.5058, Test Accuracy: 54.64%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 49/2000, Loss: 0.5002, Test Accuracy: 53.85%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 50/2000, Loss: 0.4923, Test Accuracy: 55.03%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 51/2000, Loss: 0.4989, Test Accuracy: 54.04%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 52/2000, Loss: 0.4866, Test Accuracy: 55.62%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 53/2000, Loss: 0.4756, Test Accuracy: 55.82%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 54/2000, Loss: 0.4761, Test Accuracy: 55.42%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 55/2000, Loss: 0.4656, Test Accuracy: 53.45%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 56/2000, Loss: 0.4647, Test Accuracy: 55.82%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 57/2000, Loss: 0.4641, Test Accuracy: 55.62%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 58/2000, Loss: 0.4462, Test Accuracy: 53.85%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 59/2000, Loss: 0.4390, Test Accuracy: 54.64%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 60/2000, Loss: 0.4339, Test Accuracy: 55.82%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 61/2000, Loss: 0.4235, Test Accuracy: 55.42%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 62/2000, Loss: 0.4258, Test Accuracy: 54.04%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 63/2000, Loss: 0.4149, Test Accuracy: 54.24%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 64/2000, Loss: 0.4277, Test Accuracy: 53.45%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 65/2000, Loss: 0.4077, Test Accuracy: 54.24%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 66/2000, Loss: 0.3986, Test Accuracy: 54.44%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 67/2000, Loss: 0.3880, Test Accuracy: 54.44%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 68/2000, Loss: 0.3802, Test Accuracy: 53.06%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 69/2000, Loss: 0.3772, Test Accuracy: 55.03%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# Epoch 70/2000, Loss: 0.3733, Test Accuracy: 56.61%, Best accuracy: 56.02%, Epoch best accuracy: 43, seed: 64
# ✅ Model saved with accuracy: 56.61%
# Epoch 71/2000, Loss: 0.3613, Test Accuracy: 54.83%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 72/2000, Loss: 0.3671, Test Accuracy: 54.83%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 73/2000, Loss: 0.3630, Test Accuracy: 55.03%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 74/2000, Loss: 0.3632, Test Accuracy: 53.85%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 75/2000, Loss: 0.3409, Test Accuracy: 54.24%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 76/2000, Loss: 0.3397, Test Accuracy: 54.24%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 77/2000, Loss: 0.3246, Test Accuracy: 53.45%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 78/2000, Loss: 0.3180, Test Accuracy: 53.25%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 79/2000, Loss: 0.3220, Test Accuracy: 55.03%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 80/2000, Loss: 0.3093, Test Accuracy: 54.44%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 81/2000, Loss: 0.3040, Test Accuracy: 53.45%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 82/2000, Loss: 0.2955, Test Accuracy: 54.44%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 83/2000, Loss: 0.3073, Test Accuracy: 52.27%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 84/2000, Loss: 0.3042, Test Accuracy: 53.45%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 85/2000, Loss: 0.2865, Test Accuracy: 53.25%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 86/2000, Loss: 0.2757, Test Accuracy: 54.83%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 87/2000, Loss: 0.2710, Test Accuracy: 53.65%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 88/2000, Loss: 0.2776, Test Accuracy: 54.64%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 89/2000, Loss: 0.2727, Test Accuracy: 54.44%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 90/2000, Loss: 0.2529, Test Accuracy: 55.03%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 91/2000, Loss: 0.2629, Test Accuracy: 54.83%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 92/2000, Loss: 0.2508, Test Accuracy: 54.24%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 93/2000, Loss: 0.2434, Test Accuracy: 54.44%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 94/2000, Loss: 0.2314, Test Accuracy: 54.44%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 95/2000, Loss: 0.2348, Test Accuracy: 55.82%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 96/2000, Loss: 0.2290, Test Accuracy: 54.24%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 97/2000, Loss: 0.2378, Test Accuracy: 55.42%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 98/2000, Loss: 0.2330, Test Accuracy: 56.21%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 99/2000, Loss: 0.2145, Test Accuracy: 55.03%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 100/2000, Loss: 0.2035, Test Accuracy: 55.82%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 101/2000, Loss: 0.1999, Test Accuracy: 56.41%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 102/2000, Loss: 0.1967, Test Accuracy: 55.42%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 103/2000, Loss: 0.1941, Test Accuracy: 55.62%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 104/2000, Loss: 0.2053, Test Accuracy: 55.42%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# Epoch 105/2000, Loss: 0.2061, Test Accuracy: 57.00%, Best accuracy: 56.61%, Epoch best accuracy: 70, seed: 64
# ✅ Model saved with accuracy: 57.00%
# Epoch 106/2000, Loss: 0.1910, Test Accuracy: 55.42%, Best accuracy: 57.00%, Epoch best accuracy: 105, seed: 64
# Epoch 107/2000, Loss: 0.1767, Test Accuracy: 55.82%, Best accuracy: 57.00%, Epoch best accuracy: 105, seed: 64
# Epoch 108/2000, Loss: 0.1675, Test Accuracy: 57.20%, Best accuracy: 57.00%, Epoch best accuracy: 105, seed: 64
# ✅ Model saved with accuracy: 57.20%
# Epoch 109/2000, Loss: 0.1670, Test Accuracy: 55.62%, Best accuracy: 57.20%, Epoch best accuracy: 108, seed: 64
# Epoch 110/2000, Loss: 0.1592, Test Accuracy: 56.41%, Best accuracy: 57.20%, Epoch best accuracy: 108, seed: 64
# Epoch 111/2000, Loss: 0.1606, Test Accuracy: 56.41%, Best accuracy: 57.20%, Epoch best accuracy: 108, seed: 64
# Epoch 112/2000, Loss: 0.2410, Test Accuracy: 56.61%, Best accuracy: 57.20%, Epoch best accuracy: 108, seed: 64
# Epoch 113/2000, Loss: 0.2024, Test Accuracy: 56.41%, Best accuracy: 57.20%, Epoch best accuracy: 108, seed: 64
# Epoch 114/2000, Loss: 0.1981, Test Accuracy: 55.03%, Best accuracy: 57.20%, Epoch best accuracy: 108, seed: 64
# Epoch 115/2000, Loss: 0.1664, Test Accuracy: 56.02%, Best accuracy: 57.20%, Epoch best accuracy: 108, seed: 64
# Epoch 116/2000, Loss: 0.1682, Test Accuracy: 54.24%, Best accuracy: 57.20%, Epoch best accuracy: 108, seed: 64
# Epoch 117/2000, Loss: 0.1420, Test Accuracy: 55.62%, Best accuracy: 57.20%, Epoch best accuracy: 108, seed: 64
# Epoch 118/2000, Loss: 0.1361, Test Accuracy: 54.83%, Best accuracy: 57.20%, Epoch best accuracy: 108, seed: 64
# Epoch 119/2000, Loss: 0.1301, Test Accuracy: 55.62%, Best accuracy: 57.20%, Epoch best accuracy: 108, seed: 64
# Epoch 120/2000, Loss: 0.1456, Test Accuracy: 55.62%, Best accuracy: 57.20%, Epoch best accuracy: 108, seed: 64
# Epoch 121/2000, Loss: 0.1446, Test Accuracy: 54.64%, Best accuracy: 57.20%, Epoch best accuracy: 108, seed: 64
# Epoch 122/2000, Loss: 0.1556, Test Accuracy: 56.80%, Best accuracy: 57.20%, Epoch best accuracy: 108, seed: 64
# Epoch 123/2000, Loss: 0.1433, Test Accuracy: 55.42%, Best accuracy: 57.20%, Epoch best accuracy: 108, seed: 64
# Epoch 124/2000, Loss: 0.1374, Test Accuracy: 55.62%, Best accuracy: 57.20%, Epoch best accuracy: 108, seed: 64
# Epoch 125/2000, Loss: 0.1676, Test Accuracy: 56.21%, Best accuracy: 57.20%, Epoch best accuracy: 108, seed: 64
# Epoch 126/2000, Loss: 0.1226, Test Accuracy: 57.20%, Best accuracy: 57.20%, Epoch best accuracy: 108, seed: 64
# Epoch 127/2000, Loss: 0.1153, Test Accuracy: 57.99%, Best accuracy: 57.20%, Epoch best accuracy: 108, seed: 64
# ✅ Model saved with accuracy: 57.99%
# Epoch 128/2000, Loss: 0.1052, Test Accuracy: 57.59%, Best accuracy: 57.99%, Epoch best accuracy: 127, seed: 64
# Epoch 129/2000, Loss: 0.0983, Test Accuracy: 56.80%, Best accuracy: 57.99%, Epoch best accuracy: 127, seed: 64
# Epoch 130/2000, Loss: 0.0918, Test Accuracy: 57.79%, Best accuracy: 57.99%, Epoch best accuracy: 127, seed: 64
# Epoch 131/2000, Loss: 0.0921, Test Accuracy: 58.19%, Best accuracy: 57.99%, Epoch best accuracy: 127, seed: 64
# ✅ Model saved with accuracy: 58.19%
# Epoch 132/2000, Loss: 0.0961, Test Accuracy: 57.00%, Best accuracy: 58.19%, Epoch best accuracy: 131, seed: 64
# Epoch 133/2000, Loss: 0.1033, Test Accuracy: 57.59%, Best accuracy: 58.19%, Epoch best accuracy: 131, seed: 64
# Epoch 134/2000, Loss: 0.1150, Test Accuracy: 55.03%, Best accuracy: 58.19%, Epoch best accuracy: 131, seed: 64
# Epoch 135/2000, Loss: 0.1092, Test Accuracy: 55.82%, Best accuracy: 58.19%, Epoch best accuracy: 131, seed: 64
# Epoch 136/2000, Loss: 0.1769, Test Accuracy: 56.21%, Best accuracy: 58.19%, Epoch best accuracy: 131, seed: 64
# Epoch 137/2000, Loss: 0.1542, Test Accuracy: 56.61%, Best accuracy: 58.19%, Epoch best accuracy: 131, seed: 64
# Epoch 138/2000, Loss: 0.1371, Test Accuracy: 57.59%, Best accuracy: 58.19%, Epoch best accuracy: 131, seed: 64
# Epoch 139/2000, Loss: 0.0904, Test Accuracy: 57.59%, Best accuracy: 58.19%, Epoch best accuracy: 131, seed: 64
# Epoch 140/2000, Loss: 0.0771, Test Accuracy: 58.58%, Best accuracy: 58.19%, Epoch best accuracy: 131, seed: 64
# ✅ Model saved with accuracy: 58.58%
# Epoch 141/2000, Loss: 0.0720, Test Accuracy: 57.00%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 142/2000, Loss: 0.0750, Test Accuracy: 58.19%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 143/2000, Loss: 0.0692, Test Accuracy: 57.00%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 144/2000, Loss: 0.0695, Test Accuracy: 57.79%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 145/2000, Loss: 0.0660, Test Accuracy: 57.79%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 146/2000, Loss: 0.0669, Test Accuracy: 57.99%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 147/2000, Loss: 0.0847, Test Accuracy: 57.40%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 148/2000, Loss: 0.1089, Test Accuracy: 56.02%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 149/2000, Loss: 0.1633, Test Accuracy: 55.23%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 150/2000, Loss: 0.1646, Test Accuracy: 57.20%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 151/2000, Loss: 0.1710, Test Accuracy: 55.23%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 152/2000, Loss: 0.1259, Test Accuracy: 55.62%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 153/2000, Loss: 0.0923, Test Accuracy: 57.40%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 154/2000, Loss: 0.0643, Test Accuracy: 57.99%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 155/2000, Loss: 0.0571, Test Accuracy: 58.38%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 156/2000, Loss: 0.0554, Test Accuracy: 58.38%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 157/2000, Loss: 0.0508, Test Accuracy: 58.19%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 158/2000, Loss: 0.0483, Test Accuracy: 57.99%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 159/2000, Loss: 0.0451, Test Accuracy: 58.38%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 160/2000, Loss: 0.0434, Test Accuracy: 57.79%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 161/2000, Loss: 0.0420, Test Accuracy: 57.59%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 162/2000, Loss: 0.0403, Test Accuracy: 57.79%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 163/2000, Loss: 0.0382, Test Accuracy: 57.59%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 164/2000, Loss: 0.0377, Test Accuracy: 57.00%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 165/2000, Loss: 0.0365, Test Accuracy: 57.20%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 166/2000, Loss: 0.0486, Test Accuracy: 57.20%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 167/2000, Loss: 0.0866, Test Accuracy: 55.23%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 168/2000, Loss: 0.2125, Test Accuracy: 55.42%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 169/2000, Loss: 0.3307, Test Accuracy: 56.41%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 170/2000, Loss: 0.2554, Test Accuracy: 54.83%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 171/2000, Loss: 0.1478, Test Accuracy: 56.41%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 172/2000, Loss: 0.1146, Test Accuracy: 56.02%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 173/2000, Loss: 0.0913, Test Accuracy: 56.21%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 174/2000, Loss: 0.0692, Test Accuracy: 56.80%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 175/2000, Loss: 0.0515, Test Accuracy: 55.42%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 176/2000, Loss: 0.0465, Test Accuracy: 55.23%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 177/2000, Loss: 0.0401, Test Accuracy: 54.24%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 178/2000, Loss: 0.0364, Test Accuracy: 54.83%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 179/2000, Loss: 0.0345, Test Accuracy: 54.04%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 180/2000, Loss: 0.0330, Test Accuracy: 54.04%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 181/2000, Loss: 0.0320, Test Accuracy: 54.24%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 182/2000, Loss: 0.0302, Test Accuracy: 54.24%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 183/2000, Loss: 0.0293, Test Accuracy: 54.64%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 184/2000, Loss: 0.0281, Test Accuracy: 54.64%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 185/2000, Loss: 0.0266, Test Accuracy: 54.24%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 186/2000, Loss: 0.0258, Test Accuracy: 54.24%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 187/2000, Loss: 0.0253, Test Accuracy: 54.24%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 188/2000, Loss: 0.0243, Test Accuracy: 54.44%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 189/2000, Loss: 0.0235, Test Accuracy: 55.03%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 190/2000, Loss: 0.0224, Test Accuracy: 53.85%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 191/2000, Loss: 0.0218, Test Accuracy: 54.04%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 192/2000, Loss: 0.0207, Test Accuracy: 54.83%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 193/2000, Loss: 0.0198, Test Accuracy: 54.24%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 194/2000, Loss: 0.0193, Test Accuracy: 54.83%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 195/2000, Loss: 0.0187, Test Accuracy: 54.64%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 196/2000, Loss: 0.0181, Test Accuracy: 54.44%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 197/2000, Loss: 0.0174, Test Accuracy: 54.64%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 198/2000, Loss: 0.0168, Test Accuracy: 55.23%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 199/2000, Loss: 0.0161, Test Accuracy: 55.23%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 200/2000, Loss: 0.0157, Test Accuracy: 55.03%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 201/2000, Loss: 0.0152, Test Accuracy: 54.83%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 202/2000, Loss: 0.0147, Test Accuracy: 55.42%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 203/2000, Loss: 0.0142, Test Accuracy: 54.83%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 204/2000, Loss: 0.0134, Test Accuracy: 55.23%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 205/2000, Loss: 0.0131, Test Accuracy: 55.23%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 206/2000, Loss: 0.0130, Test Accuracy: 55.62%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 207/2000, Loss: 0.0125, Test Accuracy: 55.42%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 208/2000, Loss: 0.0131, Test Accuracy: 53.45%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 209/2000, Loss: 0.2547, Test Accuracy: 53.65%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 210/2000, Loss: 0.4766, Test Accuracy: 53.65%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 211/2000, Loss: 0.3096, Test Accuracy: 53.85%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 212/2000, Loss: 0.1584, Test Accuracy: 55.23%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 213/2000, Loss: 0.1148, Test Accuracy: 54.64%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 214/2000, Loss: 0.0643, Test Accuracy: 53.65%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 215/2000, Loss: 0.0439, Test Accuracy: 55.42%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 216/2000, Loss: 0.0345, Test Accuracy: 54.83%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 217/2000, Loss: 0.0323, Test Accuracy: 52.66%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 218/2000, Loss: 0.0466, Test Accuracy: 55.23%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 219/2000, Loss: 0.0385, Test Accuracy: 53.65%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 220/2000, Loss: 0.0556, Test Accuracy: 54.83%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 221/2000, Loss: 0.0358, Test Accuracy: 53.85%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 222/2000, Loss: 0.0259, Test Accuracy: 54.44%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 223/2000, Loss: 0.0207, Test Accuracy: 54.04%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 224/2000, Loss: 0.0188, Test Accuracy: 54.24%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 225/2000, Loss: 0.0176, Test Accuracy: 54.24%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 226/2000, Loss: 0.0165, Test Accuracy: 53.85%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 227/2000, Loss: 0.0158, Test Accuracy: 53.85%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 228/2000, Loss: 0.0152, Test Accuracy: 53.65%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 229/2000, Loss: 0.0142, Test Accuracy: 53.65%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 230/2000, Loss: 0.0136, Test Accuracy: 53.65%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 231/2000, Loss: 0.0132, Test Accuracy: 53.65%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 232/2000, Loss: 0.0126, Test Accuracy: 53.65%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 233/2000, Loss: 0.0122, Test Accuracy: 53.65%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 234/2000, Loss: 0.0120, Test Accuracy: 53.25%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 235/2000, Loss: 0.0113, Test Accuracy: 53.25%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 236/2000, Loss: 0.0110, Test Accuracy: 53.45%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 237/2000, Loss: 0.0105, Test Accuracy: 53.45%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 238/2000, Loss: 0.0102, Test Accuracy: 53.65%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 239/2000, Loss: 0.0098, Test Accuracy: 53.25%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 240/2000, Loss: 0.0095, Test Accuracy: 53.45%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 241/2000, Loss: 0.0093, Test Accuracy: 53.65%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 242/2000, Loss: 0.0089, Test Accuracy: 53.85%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 243/2000, Loss: 0.0086, Test Accuracy: 53.85%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 244/2000, Loss: 0.0083, Test Accuracy: 53.65%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 245/2000, Loss: 0.0081, Test Accuracy: 53.85%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 246/2000, Loss: 0.0077, Test Accuracy: 53.65%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 247/2000, Loss: 0.0075, Test Accuracy: 53.85%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 248/2000, Loss: 0.0072, Test Accuracy: 53.85%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 249/2000, Loss: 0.0071, Test Accuracy: 54.04%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 250/2000, Loss: 0.0069, Test Accuracy: 53.65%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 251/2000, Loss: 0.0067, Test Accuracy: 53.25%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 252/2000, Loss: 0.0065, Test Accuracy: 53.45%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 253/2000, Loss: 0.0063, Test Accuracy: 54.44%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 254/2000, Loss: 0.0062, Test Accuracy: 54.64%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 255/2000, Loss: 0.0063, Test Accuracy: 54.24%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 256/2000, Loss: 0.0057, Test Accuracy: 54.24%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 257/2000, Loss: 0.0054, Test Accuracy: 54.44%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 258/2000, Loss: 0.0053, Test Accuracy: 54.04%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 259/2000, Loss: 0.0052, Test Accuracy: 54.24%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 260/2000, Loss: 0.0049, Test Accuracy: 54.64%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 261/2000, Loss: 0.0047, Test Accuracy: 54.44%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 262/2000, Loss: 0.0047, Test Accuracy: 53.85%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 263/2000, Loss: 0.0045, Test Accuracy: 54.64%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 264/2000, Loss: 0.0043, Test Accuracy: 53.85%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 265/2000, Loss: 0.0042, Test Accuracy: 54.44%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 266/2000, Loss: 0.0041, Test Accuracy: 54.24%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 267/2000, Loss: 0.0040, Test Accuracy: 54.04%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 268/2000, Loss: 0.0038, Test Accuracy: 54.44%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 269/2000, Loss: 0.0037, Test Accuracy: 53.65%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 270/2000, Loss: 0.0036, Test Accuracy: 54.83%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 271/2000, Loss: 0.0035, Test Accuracy: 54.04%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 272/2000, Loss: 0.0033, Test Accuracy: 53.65%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 273/2000, Loss: 0.5803, Test Accuracy: 56.80%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 274/2000, Loss: 0.7238, Test Accuracy: 54.04%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 275/2000, Loss: 0.3436, Test Accuracy: 54.04%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 276/2000, Loss: 0.2107, Test Accuracy: 54.83%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 277/2000, Loss: 0.1257, Test Accuracy: 54.44%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 278/2000, Loss: 0.0842, Test Accuracy: 54.44%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 279/2000, Loss: 0.0568, Test Accuracy: 53.06%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 280/2000, Loss: 0.0559, Test Accuracy: 54.64%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 281/2000, Loss: 0.0547, Test Accuracy: 54.64%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 282/2000, Loss: 0.0373, Test Accuracy: 54.44%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 283/2000, Loss: 0.0361, Test Accuracy: 53.45%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 284/2000, Loss: 0.0244, Test Accuracy: 53.85%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 285/2000, Loss: 0.0181, Test Accuracy: 53.85%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 286/2000, Loss: 0.0157, Test Accuracy: 54.04%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 287/2000, Loss: 0.0144, Test Accuracy: 53.25%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 288/2000, Loss: 0.0133, Test Accuracy: 54.04%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 289/2000, Loss: 0.0126, Test Accuracy: 53.85%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 290/2000, Loss: 0.0120, Test Accuracy: 54.24%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 291/2000, Loss: 0.0112, Test Accuracy: 54.24%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 292/2000, Loss: 0.0106, Test Accuracy: 53.85%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 293/2000, Loss: 0.0102, Test Accuracy: 53.65%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 294/2000, Loss: 0.0097, Test Accuracy: 53.65%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 295/2000, Loss: 0.0094, Test Accuracy: 53.45%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 296/2000, Loss: 0.0090, Test Accuracy: 53.25%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 297/2000, Loss: 0.0086, Test Accuracy: 52.86%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 298/2000, Loss: 0.0082, Test Accuracy: 53.25%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 299/2000, Loss: 0.0078, Test Accuracy: 52.86%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 300/2000, Loss: 0.0075, Test Accuracy: 53.45%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 301/2000, Loss: 0.0074, Test Accuracy: 53.06%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 302/2000, Loss: 0.0605, Test Accuracy: 55.03%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 303/2000, Loss: 0.3823, Test Accuracy: 53.65%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 304/2000, Loss: 0.3442, Test Accuracy: 53.06%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 305/2000, Loss: 0.2718, Test Accuracy: 54.44%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 306/2000, Loss: 0.1597, Test Accuracy: 53.65%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 307/2000, Loss: 0.0905, Test Accuracy: 54.24%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 308/2000, Loss: 0.0469, Test Accuracy: 54.83%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 309/2000, Loss: 0.0728, Test Accuracy: 54.64%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 310/2000, Loss: 0.0534, Test Accuracy: 55.82%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 311/2000, Loss: 0.0388, Test Accuracy: 55.23%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 312/2000, Loss: 0.0281, Test Accuracy: 55.03%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 313/2000, Loss: 0.0512, Test Accuracy: 54.64%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 314/2000, Loss: 0.0399, Test Accuracy: 54.24%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 315/2000, Loss: 0.0212, Test Accuracy: 54.83%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 316/2000, Loss: 0.0160, Test Accuracy: 54.24%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 317/2000, Loss: 0.0137, Test Accuracy: 54.64%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 318/2000, Loss: 0.0127, Test Accuracy: 54.83%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 319/2000, Loss: 0.0118, Test Accuracy: 54.83%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 320/2000, Loss: 0.0113, Test Accuracy: 54.64%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 321/2000, Loss: 0.0107, Test Accuracy: 55.62%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 322/2000, Loss: 0.0101, Test Accuracy: 55.23%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 323/2000, Loss: 0.0097, Test Accuracy: 54.83%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 324/2000, Loss: 0.0093, Test Accuracy: 55.62%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 325/2000, Loss: 0.0088, Test Accuracy: 55.82%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 326/2000, Loss: 0.0085, Test Accuracy: 55.82%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 327/2000, Loss: 0.0081, Test Accuracy: 55.82%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 328/2000, Loss: 0.0079, Test Accuracy: 55.82%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 329/2000, Loss: 0.0075, Test Accuracy: 55.42%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 330/2000, Loss: 0.0073, Test Accuracy: 55.62%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 331/2000, Loss: 0.0070, Test Accuracy: 55.23%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 332/2000, Loss: 0.0068, Test Accuracy: 55.23%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 333/2000, Loss: 0.0065, Test Accuracy: 55.23%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 334/2000, Loss: 0.0063, Test Accuracy: 55.23%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 335/2000, Loss: 0.0060, Test Accuracy: 54.83%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 336/2000, Loss: 0.0059, Test Accuracy: 55.42%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 337/2000, Loss: 0.0057, Test Accuracy: 55.03%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 338/2000, Loss: 0.0055, Test Accuracy: 55.23%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 339/2000, Loss: 0.0054, Test Accuracy: 55.03%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# Epoch 340/2000, Loss: 0.0051, Test Accuracy: 54.83%, Best accuracy: 58.58%, Epoch best accuracy: 140, seed: 64
# 🛑 Early stopping at epoch 340
#
# 🔹 Loading best model for final evaluation...
# 🏆 Final Test Accuracy: 58.58%

# %% [markdown]
# 🔹 Как использовать модель для предсказания?
# После загрузки модели можно предсказать направление следующей свечи:

# %%
# Загружаем модель
model.load_state_dict(torch.load("best_model_first.pth"))
model.eval()

# Берем последние 20 свечей из df_fut
last_sequence = torch.tensor(
    df_fut['CANDLE_INT'].iloc[-20:].values, dtype=torch.long
    ).unsqueeze(0).to(device)

# Предсказание
with torch.no_grad():
    probability_up = model(last_sequence).item()  # Вероятность роста
    probability_down = 1 - probability_up  # Вероятность падения

    direction = "📈 UP" if probability_up >= 0.5 else "📉 DOWN"

    print(f"Prediction: {direction}")
    print(
        f"UP Probability: {probability_up:.2%}, \n"
        f"DOWN Probability: {probability_down:.2%}"
        )
# Out:
# Prediction: 📉 DOWN
# UP Probability: 9.31%,
# DOWN Probability: 90.69%
