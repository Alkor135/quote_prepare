# %% [markdown]
# # Кодировка свечей по методу Лиховидова, прогноз Up или Down.

# %% [markdown]
# Обучение модели на основе кода свечи Лиховидова.
# Бинарная классификация Up или Down.
# Основной гиперпараметр seed. Подбирается по графикам.

# %%
import sqlite3
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
import random
from pathlib import Path
from torch.utils.data import Dataset, DataLoader

# %%
# === 1. ФИКСАЦИЯ СЛУЧАЙНЫХ ЧИСЕЛ ДЛЯ ДЕТЕРМИНИРОВАННОСТИ ===
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# [64, 97], 2, 5, 16, 22, 32, 34, 51, 64, 75, 89, 97
seed_var = 64
set_seed(seed_var)  # Устанавливаем одинаковый seed

# === 2. ЗАГРУЗКА ДАННЫХ ===
# db_path = Path(r'C:\Users\Alkor\gd\data_quote_db\RTS_futures_options_day.db')

# with sqlite3.connect(db_path) as conn:
#     df_fut = pd.read_sql_query(
#         "SELECT TRADEDATE, OPEN, LOW, HIGH, CLOSE, VOLUME FROM Futures",
#         conn
#     )

db_path = Path(r'C:\Users\Alkor\gd\data_quote_db\MIX_futures_day.db')

with sqlite3.connect(db_path) as conn:
    df_fut = pd.read_sql_query(
        "SELECT TRADEDATE, OPEN, LOW, HIGH, CLOSE, VOLUME FROM Day",
        conn
    )

"""
Строка ниже.
Фиксация порядка данных (если используем перемешивание). В данном случае не используется т.к. 
для создания фичей используются данные предыдущих свечей.
"""
# df_fut = df_fut.sample(frac=1, random_state=42).reset_index(drop=True)

# === 3. ФУНКЦИЯ КОДИРОВАНИЯ СВЕЧЕЙ (ЛИХОВИДОВ) ===
def encode_candle(row):
    open_, low, high, close = row['OPEN'], row['LOW'], row['HIGH'], row['CLOSE']

    direction = 1 if close > open_ else (0 if close < open_ else 2)
    upper_shadow = high - max(open_, close)
    lower_shadow = min(open_, close) - low
    body = abs(close - open_)

    def classify_shadow(shadow, body):
        return 0 if shadow < 0.1 * body else (1 if shadow < 0.5 * body else 2)

    return f"{direction}{classify_shadow(upper_shadow, body)}{classify_shadow(lower_shadow, body)}"

df_fut['CANDLE_CODE'] = df_fut.apply(encode_candle, axis=1)

# === 4. ПОДГОТОВКА ДАННЫХ ===
unique_codes = sorted(df_fut['CANDLE_CODE'].unique())
code_to_int = {code: i for i, code in enumerate(unique_codes)}
df_fut['CANDLE_INT'] = df_fut['CANDLE_CODE'].map(code_to_int)

window_size = 20  
predict_offset = 1  

X, y = [], []
for i in range(len(df_fut) - window_size - predict_offset):
    X.append(df_fut['CANDLE_INT'].iloc[i:i+window_size].values)
    y.append(
        1 if df_fut['CLOSE'].iloc[i+window_size+predict_offset] > 
        df_fut['CLOSE'].iloc[i+window_size] else 0
    )

X, y = np.array(X), np.array(y)

split = int(0.8 * len(X))
X_train, y_train = X[:split], y[:split]
X_test, y_test = X[split:], y[split:]

class CandlestickDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.long)
        self.y = torch.tensor(y, dtype=torch.float32)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

def seed_worker(worker_id):
    np.random.seed(42 + worker_id)
    random.seed(42 + worker_id)

train_dataset = CandlestickDataset(X_train, y_train)
test_dataset = CandlestickDataset(X_test, y_test)
# print(X_train)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, worker_init_fn=seed_worker)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, worker_init_fn=seed_worker)

# === 5. СОЗДАНИЕ НЕЙРОСЕТИ (LSTM) ===
class CandleLSTM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim):
        super(CandleLSTM, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.lstm(x)
        x = self.fc(x[:, -1, :])  
        return self.sigmoid(x)

# === 6. ОБУЧЕНИЕ МОДЕЛИ С СОХРАНЕНИЕМ ЛУЧШЕЙ ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = CandleLSTM(
    vocab_size=len(unique_codes), embedding_dim=8, hidden_dim=32, output_dim=1
).to(device)
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

best_accuracy = 0  
epoch_best_accuracy = 0
model_path = "best_model_first.pth"
early_stop_epochs = 200  # Для ранней остановки
epochs_no_improve = 0

epochs = 2000
for epoch in range(epochs):
    model.train()
    total_loss = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()
        y_pred = model(X_batch).squeeze()
        loss = criterion(y_pred, y_batch)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    # === Проверка на тесте после каждой эпохи ===
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_pred = model(X_batch).squeeze().round()
            correct += (y_pred == y_batch).sum().item()
            total += y_batch.size(0)

    accuracy = correct / total
    print(
        f"Epoch {epoch+1}/{epochs}, "
        f"Loss: {total_loss/len(train_loader):.4f}, "
        f"Test Accuracy: {accuracy:.2%}, "
        f"Best accuracy: {best_accuracy:.2%}, "
        f"Epoch best accuracy: {epoch_best_accuracy}, "
        f"seed: {seed_var}"
    )

    # === Сохранение лучшей модели ===
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        epochs_no_improve = 0
        epoch_best_accuracy = epoch + 1
        torch.save(model.state_dict(), model_path)
        print(f"✅ Model saved with accuracy: {best_accuracy:.2%}")
    else:
        epochs_no_improve += 1

    # === Ранняя остановка ===
    if epochs_no_improve >= early_stop_epochs:
        print(f"🛑 Early stopping at epoch {epoch + 1}")
        break

# === 7. ЗАГРУЗКА ЛУЧШЕЙ МОДЕЛИ И ТЕСТ ===
print("\n🔹 Loading best model for final evaluation...")
model.load_state_dict(torch.load(model_path))
model.eval()

correct = 0
total = 0
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        y_pred = model(X_batch).squeeze().round()
        correct += (y_pred == y_batch).sum().item()
        total += y_batch.size(0)

final_accuracy = correct / total
print(f"🏆 Final Test Accuracy: {final_accuracy:.2%}")

# # === 8. СОХРАНЕНИЕ ВЕРСИЙ БИБЛИОТЕК ===
# print("\n🔹 Library versions:")
# print(f"PyTorch: {torch.__version__}")
# print(f"NumPy: {np.__version__}")
# print(f"Pandas: {pd.__version__}")
# Out:
# Epoch 1/2000, Loss: 0.6932, Test Accuracy: 51.48%, Best accuracy: 0.00%, Epoch best accuracy: 0, seed: 64
# ✅ Model saved with accuracy: 51.48%
# Epoch 2/2000, Loss: 0.6920, Test Accuracy: 52.07%, Best accuracy: 51.48%, Epoch best accuracy: 1, seed: 64
# ✅ Model saved with accuracy: 52.07%
# Epoch 3/2000, Loss: 0.6912, Test Accuracy: 52.86%, Best accuracy: 52.07%, Epoch best accuracy: 2, seed: 64
# ✅ Model saved with accuracy: 52.86%
# Epoch 4/2000, Loss: 0.6907, Test Accuracy: 52.27%, Best accuracy: 52.86%, Epoch best accuracy: 3, seed: 64
# Epoch 5/2000, Loss: 0.6895, Test Accuracy: 53.06%, Best accuracy: 52.86%, Epoch best accuracy: 3, seed: 64
# ✅ Model saved with accuracy: 53.06%
# Epoch 6/2000, Loss: 0.6891, Test Accuracy: 52.27%, Best accuracy: 53.06%, Epoch best accuracy: 5, seed: 64
# Epoch 7/2000, Loss: 0.6891, Test Accuracy: 53.85%, Best accuracy: 53.06%, Epoch best accuracy: 5, seed: 64
# ✅ Model saved with accuracy: 53.85%
# Epoch 8/2000, Loss: 0.6878, Test Accuracy: 53.25%, Best accuracy: 53.85%, Epoch best accuracy: 7, seed: 64
# Epoch 9/2000, Loss: 0.6867, Test Accuracy: 50.89%, Best accuracy: 53.85%, Epoch best accuracy: 7, seed: 64
# Epoch 10/2000, Loss: 0.6847, Test Accuracy: 52.07%, Best accuracy: 53.85%, Epoch best accuracy: 7, seed: 64
# Epoch 11/2000, Loss: 0.6857, Test Accuracy: 51.28%, Best accuracy: 53.85%, Epoch best accuracy: 7, seed: 64
# Epoch 12/2000, Loss: 0.6830, Test Accuracy: 51.48%, Best accuracy: 53.85%, Epoch best accuracy: 7, seed: 64
# Epoch 13/2000, Loss: 0.6801, Test Accuracy: 50.69%, Best accuracy: 53.85%, Epoch best accuracy: 7, seed: 64
# Epoch 14/2000, Loss: 0.6786, Test Accuracy: 52.27%, Best accuracy: 53.85%, Epoch best accuracy: 7, seed: 64
# Epoch 15/2000, Loss: 0.6735, Test Accuracy: 51.28%, Best accuracy: 53.85%, Epoch best accuracy: 7, seed: 64
# Epoch 16/2000, Loss: 0.6732, Test Accuracy: 50.49%, Best accuracy: 53.85%, Epoch best accuracy: 7, seed: 64
# Epoch 17/2000, Loss: 0.6674, Test Accuracy: 52.47%, Best accuracy: 53.85%, Epoch best accuracy: 7, seed: 64
# Epoch 18/2000, Loss: 0.6636, Test Accuracy: 52.66%, Best accuracy: 53.85%, Epoch best accuracy: 7, seed: 64
# Epoch 19/2000, Loss: 0.6596, Test Accuracy: 52.07%, Best accuracy: 53.85%, Epoch best accuracy: 7, seed: 64
# Epoch 20/2000, Loss: 0.6555, Test Accuracy: 51.28%, Best accuracy: 53.85%, Epoch best accuracy: 7, seed: 64
# Epoch 21/2000, Loss: 0.6474, Test Accuracy: 54.24%, Best accuracy: 53.85%, Epoch best accuracy: 7, seed: 64
# ✅ Model saved with accuracy: 54.24%
# Epoch 22/2000, Loss: 0.6446, Test Accuracy: 51.28%, Best accuracy: 54.24%, Epoch best accuracy: 21, seed: 64
# Epoch 23/2000, Loss: 0.6414, Test Accuracy: 50.69%, Best accuracy: 54.24%, Epoch best accuracy: 21, seed: 64
# Epoch 24/2000, Loss: 0.6329, Test Accuracy: 53.06%, Best accuracy: 54.24%, Epoch best accuracy: 21, seed: 64
# Epoch 25/2000, Loss: 0.6296, Test Accuracy: 52.47%, Best accuracy: 54.24%, Epoch best accuracy: 21, seed: 64
# Epoch 26/2000, Loss: 0.6190, Test Accuracy: 53.25%, Best accuracy: 54.24%, Epoch best accuracy: 21, seed: 64
# Epoch 27/2000, Loss: 0.6142, Test Accuracy: 49.70%, Best accuracy: 54.24%, Epoch best accuracy: 21, seed: 64
# Epoch 28/2000, Loss: 0.6093, Test Accuracy: 51.68%, Best accuracy: 54.24%, Epoch best accuracy: 21, seed: 64
# Epoch 29/2000, Loss: 0.6002, Test Accuracy: 53.06%, Best accuracy: 54.24%, Epoch best accuracy: 21, seed: 64
# Epoch 30/2000, Loss: 0.6024, Test Accuracy: 52.07%, Best accuracy: 54.24%, Epoch best accuracy: 21, seed: 64
# Epoch 31/2000, Loss: 0.5895, Test Accuracy: 50.89%, Best accuracy: 54.24%, Epoch best accuracy: 21, seed: 64
# Epoch 32/2000, Loss: 0.5818, Test Accuracy: 51.68%, Best accuracy: 54.24%, Epoch best accuracy: 21, seed: 64
# Epoch 33/2000, Loss: 0.5743, Test Accuracy: 53.65%, Best accuracy: 54.24%, Epoch best accuracy: 21, seed: 64
# Epoch 34/2000, Loss: 0.5707, Test Accuracy: 52.86%, Best accuracy: 54.24%, Epoch best accuracy: 21, seed: 64
# Epoch 35/2000, Loss: 0.5593, Test Accuracy: 52.86%, Best accuracy: 54.24%, Epoch best accuracy: 21, seed: 64
# Epoch 36/2000, Loss: 0.5535, Test Accuracy: 53.85%, Best accuracy: 54.24%, Epoch best accuracy: 21, seed: 64
# Epoch 37/2000, Loss: 0.5475, Test Accuracy: 50.69%, Best accuracy: 54.24%, Epoch best accuracy: 21, seed: 64
# Epoch 38/2000, Loss: 0.5354, Test Accuracy: 53.45%, Best accuracy: 54.24%, Epoch best accuracy: 21, seed: 64
# Epoch 39/2000, Loss: 0.5316, Test Accuracy: 53.25%, Best accuracy: 54.24%, Epoch best accuracy: 21, seed: 64
# Epoch 40/2000, Loss: 0.5283, Test Accuracy: 53.25%, Best accuracy: 54.24%, Epoch best accuracy: 21, seed: 64
# Epoch 41/2000, Loss: 0.5158, Test Accuracy: 55.23%, Best accuracy: 54.24%, Epoch best accuracy: 21, seed: 64
# ✅ Model saved with accuracy: 55.23%
# Epoch 42/2000, Loss: 0.5090, Test Accuracy: 51.28%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 43/2000, Loss: 0.4948, Test Accuracy: 51.28%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 44/2000, Loss: 0.4924, Test Accuracy: 52.47%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 45/2000, Loss: 0.4878, Test Accuracy: 51.87%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 46/2000, Loss: 0.4776, Test Accuracy: 53.25%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 47/2000, Loss: 0.4709, Test Accuracy: 52.66%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 48/2000, Loss: 0.4623, Test Accuracy: 53.65%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 49/2000, Loss: 0.4545, Test Accuracy: 50.89%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 50/2000, Loss: 0.4536, Test Accuracy: 52.47%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 51/2000, Loss: 0.4441, Test Accuracy: 52.07%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 52/2000, Loss: 0.4350, Test Accuracy: 52.27%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 53/2000, Loss: 0.4344, Test Accuracy: 52.47%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 54/2000, Loss: 0.4270, Test Accuracy: 53.06%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 55/2000, Loss: 0.4158, Test Accuracy: 52.47%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 56/2000, Loss: 0.4030, Test Accuracy: 52.86%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 57/2000, Loss: 0.4092, Test Accuracy: 51.87%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 58/2000, Loss: 0.4003, Test Accuracy: 54.24%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 59/2000, Loss: 0.3970, Test Accuracy: 50.89%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 60/2000, Loss: 0.3863, Test Accuracy: 52.66%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 61/2000, Loss: 0.3673, Test Accuracy: 52.27%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 62/2000, Loss: 0.3742, Test Accuracy: 51.87%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 63/2000, Loss: 0.3575, Test Accuracy: 51.48%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 64/2000, Loss: 0.3577, Test Accuracy: 51.68%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 65/2000, Loss: 0.3472, Test Accuracy: 51.28%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 66/2000, Loss: 0.3459, Test Accuracy: 52.27%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 67/2000, Loss: 0.3339, Test Accuracy: 52.86%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 68/2000, Loss: 0.3259, Test Accuracy: 52.66%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 69/2000, Loss: 0.3226, Test Accuracy: 52.66%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 70/2000, Loss: 0.3085, Test Accuracy: 51.68%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 71/2000, Loss: 0.3054, Test Accuracy: 50.69%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 72/2000, Loss: 0.2989, Test Accuracy: 51.68%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 73/2000, Loss: 0.2961, Test Accuracy: 50.69%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 74/2000, Loss: 0.2947, Test Accuracy: 51.48%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 75/2000, Loss: 0.3068, Test Accuracy: 51.87%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 76/2000, Loss: 0.2844, Test Accuracy: 51.48%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 77/2000, Loss: 0.2729, Test Accuracy: 51.28%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 78/2000, Loss: 0.2666, Test Accuracy: 50.10%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 79/2000, Loss: 0.2634, Test Accuracy: 51.48%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 80/2000, Loss: 0.2477, Test Accuracy: 50.49%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 81/2000, Loss: 0.2418, Test Accuracy: 49.70%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 82/2000, Loss: 0.2418, Test Accuracy: 50.49%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 83/2000, Loss: 0.2575, Test Accuracy: 51.87%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 84/2000, Loss: 0.2459, Test Accuracy: 51.28%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 85/2000, Loss: 0.2342, Test Accuracy: 50.30%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 86/2000, Loss: 0.2367, Test Accuracy: 49.51%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 87/2000, Loss: 0.2200, Test Accuracy: 49.51%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 88/2000, Loss: 0.2532, Test Accuracy: 50.30%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 89/2000, Loss: 0.2181, Test Accuracy: 50.69%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 90/2000, Loss: 0.2073, Test Accuracy: 49.70%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 91/2000, Loss: 0.1980, Test Accuracy: 51.28%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 92/2000, Loss: 0.2074, Test Accuracy: 51.08%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 93/2000, Loss: 0.1924, Test Accuracy: 50.49%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 94/2000, Loss: 0.1871, Test Accuracy: 51.28%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 95/2000, Loss: 0.2020, Test Accuracy: 51.08%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 96/2000, Loss: 0.1925, Test Accuracy: 53.06%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 97/2000, Loss: 0.1745, Test Accuracy: 50.89%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 98/2000, Loss: 0.1655, Test Accuracy: 51.87%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 99/2000, Loss: 0.1610, Test Accuracy: 51.48%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 100/2000, Loss: 0.1576, Test Accuracy: 51.68%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 101/2000, Loss: 0.1491, Test Accuracy: 52.07%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 102/2000, Loss: 0.1460, Test Accuracy: 52.07%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 103/2000, Loss: 0.1431, Test Accuracy: 52.47%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 104/2000, Loss: 0.1376, Test Accuracy: 52.47%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 105/2000, Loss: 0.1372, Test Accuracy: 52.07%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 106/2000, Loss: 0.1307, Test Accuracy: 51.28%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 107/2000, Loss: 0.1976, Test Accuracy: 53.65%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 108/2000, Loss: 0.2338, Test Accuracy: 51.68%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 109/2000, Loss: 0.1584, Test Accuracy: 51.08%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 110/2000, Loss: 0.1555, Test Accuracy: 51.08%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 111/2000, Loss: 0.1288, Test Accuracy: 50.69%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 112/2000, Loss: 0.1323, Test Accuracy: 50.89%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 113/2000, Loss: 0.1227, Test Accuracy: 50.10%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 114/2000, Loss: 0.1160, Test Accuracy: 51.68%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 115/2000, Loss: 0.1081, Test Accuracy: 51.08%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 116/2000, Loss: 0.1034, Test Accuracy: 50.10%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 117/2000, Loss: 0.0965, Test Accuracy: 50.89%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 118/2000, Loss: 0.0973, Test Accuracy: 49.90%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 119/2000, Loss: 0.0953, Test Accuracy: 50.30%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 120/2000, Loss: 0.0902, Test Accuracy: 49.90%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 121/2000, Loss: 0.0884, Test Accuracy: 51.68%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 122/2000, Loss: 0.0875, Test Accuracy: 50.10%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 123/2000, Loss: 0.0843, Test Accuracy: 51.28%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 124/2000, Loss: 0.0820, Test Accuracy: 50.30%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 125/2000, Loss: 0.0811, Test Accuracy: 50.49%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 126/2000, Loss: 0.1612, Test Accuracy: 51.48%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 127/2000, Loss: 0.3211, Test Accuracy: 50.30%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 128/2000, Loss: 0.1721, Test Accuracy: 51.68%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 129/2000, Loss: 0.1338, Test Accuracy: 50.10%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 130/2000, Loss: 0.0924, Test Accuracy: 50.10%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 131/2000, Loss: 0.0803, Test Accuracy: 50.69%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 132/2000, Loss: 0.0721, Test Accuracy: 50.69%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 133/2000, Loss: 0.0678, Test Accuracy: 50.10%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 134/2000, Loss: 0.0646, Test Accuracy: 50.49%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 135/2000, Loss: 0.0621, Test Accuracy: 50.30%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 136/2000, Loss: 0.0586, Test Accuracy: 50.49%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 137/2000, Loss: 0.0606, Test Accuracy: 50.69%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 138/2000, Loss: 0.0561, Test Accuracy: 49.90%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 139/2000, Loss: 0.0584, Test Accuracy: 50.10%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 140/2000, Loss: 0.0555, Test Accuracy: 49.70%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 141/2000, Loss: 0.0514, Test Accuracy: 49.70%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 142/2000, Loss: 0.1057, Test Accuracy: 49.11%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 143/2000, Loss: 0.3039, Test Accuracy: 52.66%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 144/2000, Loss: 0.2214, Test Accuracy: 49.51%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 145/2000, Loss: 0.1314, Test Accuracy: 48.13%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 146/2000, Loss: 0.0997, Test Accuracy: 49.31%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 147/2000, Loss: 0.0720, Test Accuracy: 47.93%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 148/2000, Loss: 0.0603, Test Accuracy: 47.93%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 149/2000, Loss: 0.0527, Test Accuracy: 48.52%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 150/2000, Loss: 0.0495, Test Accuracy: 48.32%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 151/2000, Loss: 0.0467, Test Accuracy: 47.93%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 152/2000, Loss: 0.0444, Test Accuracy: 48.13%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 153/2000, Loss: 0.0424, Test Accuracy: 47.93%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 154/2000, Loss: 0.0421, Test Accuracy: 48.32%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 155/2000, Loss: 0.0397, Test Accuracy: 48.32%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 156/2000, Loss: 0.0373, Test Accuracy: 47.93%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 157/2000, Loss: 0.0365, Test Accuracy: 48.72%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 158/2000, Loss: 0.0348, Test Accuracy: 49.11%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 159/2000, Loss: 0.0336, Test Accuracy: 48.13%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 160/2000, Loss: 0.0328, Test Accuracy: 49.11%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 161/2000, Loss: 0.0318, Test Accuracy: 48.92%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 162/2000, Loss: 0.0307, Test Accuracy: 48.32%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 163/2000, Loss: 0.0299, Test Accuracy: 48.72%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 164/2000, Loss: 0.0288, Test Accuracy: 49.51%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 165/2000, Loss: 0.0275, Test Accuracy: 49.11%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 166/2000, Loss: 0.0270, Test Accuracy: 49.11%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 167/2000, Loss: 0.0457, Test Accuracy: 50.49%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 168/2000, Loss: 0.2170, Test Accuracy: 51.08%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 169/2000, Loss: 0.3383, Test Accuracy: 51.48%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 170/2000, Loss: 0.2325, Test Accuracy: 48.92%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 171/2000, Loss: 0.1165, Test Accuracy: 48.13%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 172/2000, Loss: 0.0641, Test Accuracy: 47.53%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 173/2000, Loss: 0.0439, Test Accuracy: 48.92%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 174/2000, Loss: 0.0370, Test Accuracy: 49.11%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 175/2000, Loss: 0.0337, Test Accuracy: 48.72%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 176/2000, Loss: 0.0315, Test Accuracy: 49.11%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 177/2000, Loss: 0.0298, Test Accuracy: 48.52%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 178/2000, Loss: 0.0286, Test Accuracy: 48.92%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 179/2000, Loss: 0.0274, Test Accuracy: 48.72%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 180/2000, Loss: 0.0302, Test Accuracy: 49.51%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 181/2000, Loss: 0.0264, Test Accuracy: 49.11%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 182/2000, Loss: 0.0247, Test Accuracy: 49.51%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 183/2000, Loss: 0.0234, Test Accuracy: 49.70%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 184/2000, Loss: 0.0227, Test Accuracy: 50.10%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 185/2000, Loss: 0.0217, Test Accuracy: 49.90%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 186/2000, Loss: 0.0206, Test Accuracy: 50.10%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 187/2000, Loss: 0.0201, Test Accuracy: 50.30%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 188/2000, Loss: 0.0198, Test Accuracy: 50.10%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 189/2000, Loss: 0.0192, Test Accuracy: 49.90%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 190/2000, Loss: 0.0183, Test Accuracy: 50.10%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 191/2000, Loss: 0.0177, Test Accuracy: 49.90%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 192/2000, Loss: 0.0172, Test Accuracy: 50.49%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 193/2000, Loss: 0.0166, Test Accuracy: 49.90%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 194/2000, Loss: 0.0160, Test Accuracy: 50.30%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 195/2000, Loss: 0.0156, Test Accuracy: 49.90%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 196/2000, Loss: 0.0152, Test Accuracy: 49.51%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 197/2000, Loss: 0.0146, Test Accuracy: 50.10%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 198/2000, Loss: 0.0142, Test Accuracy: 49.90%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 199/2000, Loss: 0.0138, Test Accuracy: 49.90%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 200/2000, Loss: 0.0134, Test Accuracy: 49.70%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 201/2000, Loss: 0.0128, Test Accuracy: 49.51%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 202/2000, Loss: 0.0126, Test Accuracy: 50.10%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 203/2000, Loss: 0.0129, Test Accuracy: 50.10%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 204/2000, Loss: 0.0124, Test Accuracy: 48.92%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 205/2000, Loss: 0.1346, Test Accuracy: 50.10%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 206/2000, Loss: 0.4116, Test Accuracy: 48.92%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 207/2000, Loss: 0.3463, Test Accuracy: 51.48%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 208/2000, Loss: 0.1572, Test Accuracy: 48.92%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 209/2000, Loss: 0.1010, Test Accuracy: 50.10%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 210/2000, Loss: 0.0561, Test Accuracy: 49.70%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 211/2000, Loss: 0.0330, Test Accuracy: 49.51%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 212/2000, Loss: 0.0251, Test Accuracy: 49.70%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 213/2000, Loss: 0.0226, Test Accuracy: 49.51%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 214/2000, Loss: 0.0218, Test Accuracy: 49.70%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 215/2000, Loss: 0.0190, Test Accuracy: 49.51%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 216/2000, Loss: 0.0178, Test Accuracy: 49.51%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 217/2000, Loss: 0.0170, Test Accuracy: 50.10%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 218/2000, Loss: 0.0163, Test Accuracy: 50.30%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 219/2000, Loss: 0.0155, Test Accuracy: 49.70%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 220/2000, Loss: 0.0149, Test Accuracy: 49.90%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 221/2000, Loss: 0.0148, Test Accuracy: 49.31%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 222/2000, Loss: 0.0139, Test Accuracy: 50.30%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 223/2000, Loss: 0.0169, Test Accuracy: 49.70%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 224/2000, Loss: 0.0139, Test Accuracy: 48.92%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 225/2000, Loss: 0.0125, Test Accuracy: 49.31%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 226/2000, Loss: 0.0121, Test Accuracy: 49.51%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 227/2000, Loss: 0.0116, Test Accuracy: 49.51%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 228/2000, Loss: 0.0113, Test Accuracy: 49.70%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 229/2000, Loss: 0.0110, Test Accuracy: 49.70%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 230/2000, Loss: 0.0107, Test Accuracy: 49.90%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 231/2000, Loss: 0.0103, Test Accuracy: 49.11%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 232/2000, Loss: 0.0102, Test Accuracy: 49.11%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 233/2000, Loss: 0.0096, Test Accuracy: 49.51%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 234/2000, Loss: 0.0093, Test Accuracy: 49.11%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 235/2000, Loss: 0.0091, Test Accuracy: 49.11%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 236/2000, Loss: 0.0088, Test Accuracy: 48.92%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 237/2000, Loss: 0.0086, Test Accuracy: 48.72%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 238/2000, Loss: 0.0083, Test Accuracy: 48.72%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 239/2000, Loss: 0.0080, Test Accuracy: 48.92%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 240/2000, Loss: 0.0082, Test Accuracy: 48.92%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# Epoch 241/2000, Loss: 0.0076, Test Accuracy: 49.11%, Best accuracy: 55.23%, Epoch best accuracy: 41, seed: 64
# 🛑 Early stopping at epoch 241
#
# 🔹 Loading best model for final evaluation...
# 🏆 Final Test Accuracy: 55.23%

# %% [markdown]
# 🔹 Как использовать модель для предсказания?
# После загрузки модели можно предсказать направление следующей свечи:

# %%
# Загружаем модель
model.load_state_dict(torch.load("best_model_first.pth"))
model.eval()

# Берем последние 20 свечей из df_fut
last_sequence = torch.tensor(
    df_fut['CANDLE_INT'].iloc[-20:].values, dtype=torch.long
    ).unsqueeze(0).to(device)

# Предсказание
with torch.no_grad():
    probability_up = model(last_sequence).item()  # Вероятность роста
    probability_down = 1 - probability_up  # Вероятность падения

    direction = "📈 UP" if probability_up >= 0.5 else "📉 DOWN"

    print(f"Prediction: {direction}")
    print(
        f"UP Probability: {probability_up:.2%}, \n"
        f"DOWN Probability: {probability_down:.2%}"
        )
# Out:
# Prediction: 📉 DOWN
# UP Probability: 46.10%,
# DOWN Probability: 53.90%
